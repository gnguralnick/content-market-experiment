# %%
from agents import ConsumerProducer, Influencer, ImperfectConsumerProducer
from content_market import ContentMarket
import numpy as np
from stats import TestStats
from util import exponential_decay, inverse_decay, tanh_decay
import matplotlib.pyplot as plt
import visualize

# %%
num_influencers = 1
num_consumer_producers = 25

production_rate = 1
external_production_rate = 1

topics = [[-1, 1]]
topics = np.array(topics)

# %%
perfect_market = ContentMarket(topics, production_rate, external_production_rate)
imperfect_market = ContentMarket(topics, production_rate, external_production_rate)

# %%
agent_colors = dict()

for i in range(num_consumer_producers):
    cons_func = lambda x: inverse_decay(x, 0.75, 2)
    prod_func = lambda x: inverse_decay(x, 0.75, 2)
    perfect_consumer_producer = ConsumerProducer(prod_func, cons_func, 30, 3, 1, init_following_rates_method='equal')
    imperfect_consumer_producer = ImperfectConsumerProducer(prod_func, cons_func, 30, 3, 1, init_following_rates_method='equal')
    perfect_market.add_agent(perfect_consumer_producer)
    imperfect_market.add_agent(imperfect_consumer_producer)

    color = np.random.rand(3,)
    agent_colors[perfect_consumer_producer.index] = color

for i in range(num_influencers):
    perfect_influencer = Influencer(60, 1, init_following_rates_method='equal')
    imperfect_influencer = Influencer(60, 1, init_following_rates_method='equal')
    perfect_market.add_agent(perfect_influencer)
    imperfect_market.add_agent(imperfect_influencer)

    color = np.random.rand(3,)
    agent_colors[perfect_influencer.index] = color

# %%
perfect_market.finalize(method='even')
imperfect_market.finalize(method='even')

# %%
visualize.plot_topic_distribution_histogram("Consumer/Producer Topic Distribution (Perfect)", perfect_market.consumers, -1, 1)
visualize.plot_topic_distribution_histogram("Consumer/Producer Topic Distribution (Imperfect)", imperfect_market.consumers, -1, 1)

# %%
visualize.plot_consumer_topic_interest_distributions("Consumer Topic Interest Distributions (Perfect)", perfect_market.consumers, -1, 1, agent_colors)
visualize.plot_consumer_topic_interest_distributions("Consumer Topic Interest Distributions (Imperfect)", imperfect_market.consumers, -1, 1, agent_colors)

# %%
visualize.plot_producer_topic_probability_distributions("Producer Topic Probability Distributions (Perfect)", perfect_market.producers, -1, 1, agent_colors)
visualize.plot_producer_topic_probability_distributions("Producer Topic Probability Distributions (Imperfect)", imperfect_market.producers, -1, 1, agent_colors)

# %%
perfect_stats: TestStats = perfect_market.optimize(100)
imperfect_stats: TestStats = imperfect_market.optimize(100)
# Out:
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing consumer 20
# Optimizing consumer 21
# Optimizing consumer 22
# Optimizing consumer 23
# Optimizing consumer 24
# Optimizing influencer 25
# Optimizing producer 0
# Optimization succeeded (overall 0.012245584046468139s): nit=5, nfev=14, njev=7.
# Optimizing producer 1
# Optimization succeeded (overall 0.011633208021521568s): nit=5, nfev=14, njev=7.
# Optimizing producer 2
# Optimization succeeded (overall 0.01099066692404449s): nit=5, nfev=14, njev=7.
# Optimizing producer 3
# Optimization succeeded (overall 0.011147624929435551s): nit=5, nfev=14, njev=7.
# Optimizing producer 4
# Optimization succeeded (overall 0.009498541941866279s): nit=4, nfev=12, njev=6.
# Optimizing producer 5
# Optimization succeeded (overall 0.009648125036619604s): nit=4, nfev=12, njev=6.
# Optimizing producer 6
# Optimization succeeded (overall 0.009605875005945563s): nit=4, nfev=12, njev=6.
# Optimizing producer 7
# Optimization succeeded (overall 0.009756791056133807s): nit=4, nfev=12, njev=6.
# Optimizing producer 8
# Optimization succeeded (overall 0.009641459095291793s): nit=4, nfev=12, njev=6.
# Optimizing producer 9
# Optimization succeeded (overall 0.008046625065617263s): nit=3, nfev=10, njev=5.
# Optimizing producer 10
# Optimization succeeded (overall 0.008034000056795776s): nit=3, nfev=10, njev=5.
# Optimizing producer 11
# Optimization succeeded (overall 0.007991124992258847s): nit=3, nfev=10, njev=5.
# Optimizing producer 12
# Optimization succeeded (overall 0.0016758749261498451s): nit=0, nfev=2, njev=1.
# Optimizing producer 13
# Optimization succeeded (overall 0.008024625014513731s): nit=3, nfev=10, njev=5.
# Optimizing producer 14
# Optimization succeeded (overall 0.008010666933842003s): nit=3, nfev=10, njev=5.
# Optimizing producer 15
# Optimization succeeded (overall 0.008138375007547438s): nit=3, nfev=10, njev=5.
# Optimizing producer 16
# Optimization succeeded (overall 0.009714332991279662s): nit=4, nfev=12, njev=6.
# Optimizing producer 17
# Optimization succeeded (overall 0.009630916989408433s): nit=4, nfev=12, njev=6.
# Optimizing producer 18
# Optimization succeeded (overall 0.0096614999929443s): nit=4, nfev=12, njev=6.
# Optimizing producer 19
# Optimization succeeded (overall 0.010798541945405304s): nit=4, nfev=12, njev=6.
# Optimizing producer 20
# Optimization succeeded (overall 0.009820207953453064s): nit=4, nfev=12, njev=6.
# Optimizing producer 21
# Optimization succeeded (overall 0.01133450004272163s): nit=5, nfev=14, njev=7.
# Optimizing producer 22
# Optimization succeeded (overall 0.025171249988488853s): nit=5, nfev=14, njev=7.
# Optimizing producer 23
# Optimization succeeded (overall 0.01866724994033575s): nit=5, nfev=14, njev=7.
# Optimizing producer 24
# Optimization succeeded (overall 0.021415416966192424s): nit=5, nfev=14, njev=7.
# Iteration 0 / 100 done in 11.72555066703353 seconds.
# Total Social Welfare: 418.37844065605873
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing consumer 20
# Optimizing consumer 21
# Optimizing consumer 22
# Optimizing consumer 23
# Optimizing consumer 24
# Optimizing influencer 25
# Optimizing producer 0
# Optimization succeeded (overall 0.009164375020191073s): nit=3, nfev=10, njev=5.
# Optimizing producer 1
# Optimization succeeded (overall 0.008144582970999181s): nit=3, nfev=10, njev=5.
# Optimizing producer 2
# Optimization succeeded (overall 0.010073667042888701s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.014759167097508907s): nit=4, nfev=12, njev=6.
# Optimizing producer 4
# Optimization succeeded (overall 0.012216457980684936s): nit=4, nfev=12, njev=6.
# Optimizing producer 5
# Optimization succeeded (overall 0.011918833944946527s): nit=4, nfev=12, njev=6.
# Optimizing producer 6
# Optimization succeeded (overall 0.010050541954115033s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.012639792053960264s): nit=3, nfev=10, njev=5.
# Optimizing producer 8
# Optimization succeeded (overall 0.00881483405828476s): nit=3, nfev=10, njev=5.
# Optimizing producer 9
# Optimization succeeded (overall 0.00897462503053248s): nit=3, nfev=10, njev=5.
# Optimizing producer 10
# Optimization succeeded (overall 0.009419666952453554s): nit=3, nfev=10, njev=5.
# Optimizing producer 11
# Optimization succeeded (overall 0.010112958028912544s): nit=3, nfev=10, njev=5.
# Optimizing producer 12
# Optimization succeeded (overall 0.001829707995057106s): nit=0, nfev=2, njev=1.
# Optimizing producer 13
# Optimization succeeded (overall 0.00695620896294713s): nit=2, nfev=8, njev=4.
# Optimizing producer 14
# Optimization succeeded (overall 0.008818708010949194s): nit=3, nfev=10, njev=5.
# Optimizing producer 15
# Optimization succeeded (overall 0.008783458033576608s): nit=3, nfev=10, njev=5.
# Optimizing producer 16
# Optimization succeeded (overall 0.008473708992823958s): nit=3, nfev=10, njev=5.
# Optimizing producer 17
# Optimization succeeded (overall 0.008320667082443833s): nit=3, nfev=10, njev=5.
# Optimizing producer 18
# Optimization succeeded (overall 0.00817383301910013s): nit=3, nfev=10, njev=5.
# Optimizing producer 19
# Optimization succeeded (overall 0.010223916033282876s): nit=4, nfev=12, njev=6.
# Optimizing producer 20
# Optimization succeeded (overall 0.010543707991018891s): nit=4, nfev=12, njev=6.
# Optimizing producer 21
# Optimization succeeded (overall 0.017598874983377755s): nit=4, nfev=12, njev=6.
# Optimizing producer 22
# Optimization succeeded (overall 0.011647833976894617s): nit=4, nfev=12, njev=6.
# Optimizing producer 23
# Optimization succeeded (overall 0.008424291969276965s): nit=3, nfev=10, njev=5.
# Optimizing producer 24
# Optimization succeeded (overall 0.009611207991838455s): nit=3, nfev=10, njev=5.
# Iteration 1 / 100 done in 6.4965344169177115 seconds.
# Total Social Welfare: 419.136884314924
# Consumer rate change: 0.29437296549435404
# Consumer utility change: 0.0018095367933713016%
# Influencer rate change: 0.2572291719102838
# Influencer utility change: -0.0005340376400949882%
# Producer topic change: 0.02938140430954642
# Producer utility change: 0.0026350195216731163%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing consumer 20
# Optimizing consumer 21
# Optimizing consumer 22
# Optimizing consumer 23
# Optimizing consumer 24
# Optimizing influencer 25
# Optimizing producer 0
# Optimization succeeded (overall 0.007612957968376577s): nit=2, nfev=8, njev=4.
# Optimizing producer 1
# Optimization succeeded (overall 0.0056440000189468265s): nit=2, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.005853500100784004s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.005594999995082617s): nit=2, nfev=8, njev=4.
# Optimizing producer 4
# Optimization succeeded (overall 0.005768792005255818s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.0056928329868242145s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.00622162502259016s): nit=2, nfev=8, njev=4.
# Optimizing producer 7
# Optimization succeeded (overall 0.005890208994969726s): nit=2, nfev=8, njev=4.
# Optimizing producer 8
# Optimization succeeded (overall 0.006416624994017184s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.006289415992796421s): nit=2, nfev=8, njev=4.
# Optimizing producer 10
# Optimization succeeded (overall 0.006216541980393231s): nit=2, nfev=8, njev=4.
# Optimizing producer 11
# Optimization succeeded (overall 0.0064454160165041685s): nit=2, nfev=8, njev=4.
# Optimizing producer 12
# Optimization succeeded (overall 0.0015825839946046472s): nit=0, nfev=2, njev=1.
# Optimizing producer 13
# Optimization succeeded (overall 0.006159208016470075s): nit=2, nfev=8, njev=4.
# Optimizing producer 14
# Optimization succeeded (overall 0.006155916955322027s): nit=2, nfev=8, njev=4.
# Optimizing producer 15
# Optimization succeeded (overall 0.006321458960883319s): nit=2, nfev=8, njev=4.
# Optimizing producer 16
# Optimization succeeded (overall 0.006330291973426938s): nit=2, nfev=8, njev=4.
# Optimizing producer 17
# Optimization succeeded (overall 0.006185124977491796s): nit=2, nfev=8, njev=4.
# Optimizing producer 18
# Optimization succeeded (overall 0.006396458949893713s): nit=2, nfev=8, njev=4.
# Optimizing producer 19
# Optimization succeeded (overall 0.005682958988472819s): nit=2, nfev=8, njev=4.
# Optimizing producer 20
# Optimization succeeded (overall 0.005421417066827416s): nit=2, nfev=8, njev=4.
# Optimizing producer 21
# Optimization succeeded (overall 0.005970250000245869s): nit=2, nfev=8, njev=4.
# Optimizing producer 22
# Optimization succeeded (overall 0.005381709081120789s): nit=2, nfev=8, njev=4.
# Optimizing producer 23
# Optimization succeeded (overall 0.005655667046085s): nit=2, nfev=8, njev=4.
# Optimizing producer 24
# Optimization succeeded (overall 0.005487082991749048s): nit=2, nfev=8, njev=4.
# Iteration 2 / 100 done in 3.9900564160197973 seconds.
# Total Social Welfare: 419.15276845217505
# Consumer rate change: 0.07677169602940913
# Consumer utility change: 3.7895816273178054e-05%
# Influencer rate change: 0.00853014625586612
# Influencer utility change: 0.00022018005446030768%
# Producer topic change: 0.002544566657284935
# Producer utility change: 4.438134574338732e-05%
# Converged. Optimization took 22.41097854101099 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing consumer 20
# Optimizing consumer 21
# Optimizing consumer 22
# Optimizing consumer 23
# Optimizing consumer 24
# Optimizing influencer 25
# Optimizing producer 0
# Optimization succeeded (overall 1.948956249980256s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 81.29279933299404s): nit=1, nfev=40, njev=20.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 201.42647333303466s): nit=2, nfev=80, njev=40.
# Optimizing producer 3
# Optimization succeeded (overall 59.29915062501095s): nit=3, nfev=56, njev=28.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 330.3166574999923s): nit=1, nfev=116, njev=58.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 271.8315726250876s): nit=1, nfev=76, njev=38.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 234.4669092920376s): nit=2, nfev=134, njev=67.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 184.26399170805234s): nit=1, nfev=70, njev=35.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 404.4551229160279s): nit=2, nfev=194, njev=97.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 132.34169804200064s): nit=1, nfev=42, njev=21.
# Optimizing producer 10
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 163.12634579103906s): nit=1, nfev=66, njev=33.
# Optimizing producer 11
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 353.3404764169827s): nit=2, nfev=110, njev=55.
# Optimizing producer 12
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 214.6023376249941s): nit=1, nfev=64, njev=32.
# Optimizing producer 13
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 379.5205953749828s): nit=1, nfev=80, njev=40.
# Optimizing producer 14
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 148.25730366702192s): nit=1, nfev=80, njev=40.
# Optimizing producer 15
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 260.67317020799965s): nit=3, nfev=188, njev=94.
# Optimizing producer 16
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 105.36301416694187s): nit=1, nfev=66, njev=33.
# Optimizing producer 17
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 196.44820258300751s): nit=1, nfev=72, njev=36.
# Optimizing producer 18
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 165.8274507089518s): nit=1, nfev=56, njev=28.
# Optimizing producer 19
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 111.98778095806483s): nit=2, nfev=76, njev=38.
# Optimizing producer 20
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 226.93787695793435s): nit=1, nfev=92, njev=46.
# Optimizing producer 21
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 105.13882662495598s): nit=1, nfev=68, njev=34.
# Optimizing producer 22
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 186.98214358300902s): nit=3, nfev=156, njev=78.
# Optimizing producer 23
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 432.7601779999677s): nit=3, nfev=186, njev=93.
# Optimizing producer 24
# Optimization succeeded (overall 1.907612624927424s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 4964.083790541976 seconds.
# Total Social Welfare: 413.9742757529521
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing consumer 20
# Optimizing consumer 21
# Optimizing consumer 22
# Optimizing consumer 23
# Optimizing consumer 24
# Optimizing influencer 25
# Optimizing producer 0
# Optimization succeeded (overall 1.3977410000516102s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 56.60666416690219s): nit=6, nfev=80, njev=40.
# Optimizing producer 2
# Optimization succeeded (overall 50.83395158406347s): nit=3, nfev=72, njev=36.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 218.1154689580435s): nit=1, nfev=100, njev=50.
# Optimizing producer 4
# Optimization succeeded (overall 45.30746933305636s): nit=4, nfev=64, njev=32.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 175.03691287501715s): nit=2, nfev=110, njev=55.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 99.13812762498856s): nit=1, nfev=66, njev=33.
# Optimizing producer 7
# Optimization succeeded (overall 117.48624683299568s): nit=10, nfev=164, njev=82.
# Optimizing producer 8
# Optimization succeeded (overall 37.84807275002822s): nit=2, nfev=52, njev=26.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 87.22867987502832s): nit=1, nfev=80, njev=40.
# Optimizing producer 10
# Optimization succeeded (overall 30.230997874983586s): nit=2, nfev=42, njev=21.
# Optimizing producer 11
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 149.7632941249758s): nit=2, nfev=104, njev=52.
# Optimizing producer 12
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 163.53903595800512s): nit=1, nfev=96, njev=48.
# Optimizing producer 13
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 131.4737171670422s): nit=1, nfev=52, njev=26.
# Optimizing producer 14
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 141.90282583399676s): nit=1, nfev=86, njev=43.
# Optimizing producer 15
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 100.15845445799641s): nit=2, nfev=92, njev=46.
# Optimizing producer 16
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 259.28314637509175s): nit=3, nfev=196, njev=98.
# Optimizing producer 17
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 90.10578087496106s): nit=1, nfev=50, njev=25.
# Optimizing producer 18
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 143.0574730829103s): nit=1, nfev=50, njev=25.
# Optimizing producer 19
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 134.61063654196914s): nit=1, nfev=48, njev=24.
# Optimizing producer 20
# Optimization succeeded (overall 37.22537029196974s): nit=2, nfev=52, njev=26.
# Optimizing producer 21
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 183.01056187495124s): nit=3, nfev=132, njev=66.
# Optimizing producer 22
# Optimization succeeded (overall 48.89666320802644s): nit=4, nfev=68, njev=34.
# Optimizing producer 23
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 135.7925170409726s): nit=1, nfev=88, njev=44.
# Optimizing producer 24
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 163.5022730419878s): nit=1, nfev=96, njev=48.
# Iteration 1 / 100 done in 2805.484726625029 seconds.
# Total Social Welfare: 417.38701914528593
# Consumer rate change: 0.18721892477808244
# Consumer utility change: 0.008176447832304558%
# Influencer rate change: 0.1505756182999174
# Influencer utility change: 0.013868473780003034%
# Producer topic change: 0.0423268833601231
# Producer utility change: 0.0005242653211978281%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing consumer 20
# Optimizing consumer 21
# Optimizing consumer 22
# Optimizing consumer 23
# Optimizing consumer 24
# Optimizing influencer 25
# Optimizing producer 0
# Optimization succeeded (overall 1.4881878750165924s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 155.7424163329415s): nit=1, nfev=72, njev=36.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 251.10459341702517s): nit=1, nfev=102, njev=51.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 130.98356883297674s): nit=1, nfev=92, njev=46.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 192.69367754203267s): nit=1, nfev=76, njev=38.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 217.97114329098258s): nit=3, nfev=190, njev=95.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 191.89948791707866s): nit=2, nfev=168, njev=84.
# Optimizing producer 7
# Optimization succeeded (overall 70.77353245799895s): nit=4, nfev=96, njev=48.
# Optimizing producer 8
# Optimization succeeded (overall 55.06045108300168s): nit=3, nfev=76, njev=38.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 167.82882608403452s): nit=2, nfev=192, njev=96.
# Optimizing producer 10
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 72.13272150000557s): nit=1, nfev=56, njev=28.
# Optimizing producer 11
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 139.8669713329291s): nit=1, nfev=92, njev=46.
# Optimizing producer 12
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 140.0850784999784s): nit=1, nfev=62, njev=31.
# Optimizing producer 13
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 200.66701450000983s): nit=2, nfev=164, njev=82.
# Optimizing producer 14
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 200.6196507080458s): nit=1, nfev=88, njev=44.
# Optimizing producer 15
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 98.64725945901591s): nit=2, nfev=92, njev=46.
# Optimizing producer 16
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 277.7794066249626s): nit=2, nfev=130, njev=65.
# Optimizing producer 17
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 171.76409391697962s): nit=1, nfev=86, njev=43.
# Optimizing producer 18
# Optimization succeeded (overall 83.29191466700286s): nit=6, nfev=110, njev=55.
# Optimizing producer 19
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 226.87616420793347s): nit=3, nfev=178, njev=89.
# Optimizing producer 20
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 117.2796269999817s): nit=1, nfev=54, njev=27.
# Optimizing producer 21
# Optimization succeeded (overall 46.93927133397665s): nit=3, nfev=62, njev=31.
# Optimizing producer 22
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 187.34252812503837s): nit=2, nfev=98, njev=49.
# Optimizing producer 23
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 151.02833433297928s): nit=1, nfev=72, njev=36.
# Optimizing producer 24
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 157.6098364999052s): nit=2, nfev=110, njev=55.
# Iteration 2 / 100 done in 3711.595561208087 seconds.
# Total Social Welfare: 417.7792218406863
# Consumer rate change: 0.19530002448046532
# Consumer utility change: 0.0009387797464003993%
# Influencer rate change: 0.20985234262050725
# Influencer utility change: 0.0025024893888175217%
# Producer topic change: 0.012243547367080516
# Producer utility change: 1.965772300622725e-05%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing consumer 20
# Optimizing consumer 21
# Optimizing consumer 22
# Optimizing consumer 23
# Optimizing consumer 24
# Optimizing influencer 25
# Optimizing producer 0
# Optimization succeeded (overall 1.0244782499503344s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 129.22512775007635s): nit=1, nfev=96, njev=48.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 154.6872456249548s): nit=2, nfev=112, njev=56.
# Optimizing producer 3
# Optimization succeeded (overall 47.083096375106834s): nit=5, nfev=92, njev=46.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 107.34734029194806s): nit=2, nfev=90, njev=45.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 132.69475283299107s): nit=1, nfev=92, njev=46.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 56.28134225006215s): nit=1, nfev=66, njev=33.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 116.37368616601452s): nit=1, nfev=88, njev=44.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 72.46554516605102s): nit=1, nfev=58, njev=29.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 140.00984941702336s): nit=3, nfev=164, njev=82.
# Optimizing producer 10
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 95.26822916697711s): nit=2, nfev=134, njev=67.
# Optimizing producer 11
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 74.53723433392588s): nit=2, nfev=98, njev=49.
# Optimizing producer 12
# Optimization succeeded (overall 33.826688708039s): nit=3, nfev=66, njev=33.
# Optimizing producer 13
# Optimization succeeded (overall 36.81450729095377s): nit=3, nfev=72, njev=36.
# Optimizing producer 14
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 88.51861041691154s): nit=1, nfev=50, njev=25.
# Optimizing producer 15
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 155.50502312497701s): nit=1, nfev=76, njev=38.
# Optimizing producer 16
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 132.88308399997186s): nit=2, nfev=152, njev=76.
# Optimizing producer 17
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 147.27455454098526s): nit=1, nfev=68, njev=34.
# Optimizing producer 18
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 121.95589762495365s): nit=2, nfev=144, njev=72.
# Optimizing producer 19
# Optimization succeeded (overall 38.65412020799704s): nit=3, nfev=74, njev=37.
# Optimizing producer 20
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 89.57541995798238s): nit=1, nfev=62, njev=31.
# Optimizing producer 21
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 95.44706966704689s): nit=1, nfev=48, njev=24.
# Optimizing producer 22
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 59.97956412495114s): nit=1, nfev=50, njev=25.
# Optimizing producer 23
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 77.82300412491895s): nit=1, nfev=50, njev=25.
# Optimizing producer 24
# Optimization succeeded (overall 31.648830124991946s): nit=2, nfev=64, njev=32.
# Iteration 3 / 100 done in 2239.792745332932 seconds.
# Total Social Welfare: 417.85521192797415
# Consumer rate change: 0.081232875339
# Consumer utility change: 0.00018185744863844473%
# Influencer rate change: 0.045024882107484406
# Influencer utility change: 0.000522594053359018%
# Producer topic change: 0.00433411366405942
# Producer utility change: -4.5855582220281885e-06%
# Converged. Optimization took 13781.405221416964 seconds.

# %%
plt.figure()
plt.title("Total Social Welfare by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Total Social Welfare")
plt.plot(perfect_stats.total_social_welfare, label="Perfect Information")
plt.plot(imperfect_stats.total_social_welfare, label="Imperfect Information")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Cost of Influence by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Cost of Influence (%)")
costs = []
for i in range(1, max(len(perfect_stats.total_social_welfare), len(imperfect_stats.total_social_welfare))):
    perfect_welfare = perfect_stats.total_social_welfare[i] + 1e-10 if i < len(perfect_stats.total_social_welfare) else perfect_stats.total_social_welfare[-1]
    imperfect_welfare = imperfect_stats.total_social_welfare[i] if i < len(imperfect_stats.total_social_welfare) else imperfect_stats.total_social_welfare[-1]
    costs.append((perfect_welfare - imperfect_welfare) / perfect_welfare * 100)
plt.plot(list(range(1, max(len(perfect_stats.total_social_welfare), len(imperfect_stats.total_social_welfare)))), costs)
plt.show()

# %%
plt.figure()
plt.title("Average Consumer Utility By Iteration")
plt.plot(perfect_stats.average_consumer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_consumer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Producer Utility By Iteration")
plt.plot(perfect_stats.average_producer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_producer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Influencer Utility By Iteration")
plt.plot(perfect_stats.average_influencer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_influencer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
perfect_influencer = perfect_market.influencers[0]
perfect_influencer_stats = perfect_stats.influencer_stats[perfect_influencer.index]
imperfect_influencer = imperfect_market.influencers[0]
imperfect_influencer_stats = imperfect_stats.influencer_stats[imperfect_influencer.index]

perfect_producers = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producers = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.figure()
plt.title("Influencer Ending Following Rate By Producer Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Following Rate (%)")
plt.xlim(topics[0][0], topics[0][1])

plt.plot([p.agent.main_interest for p in perfect_producers], [perfect_influencer_stats.following_rates[-1][p.agent.index] / perfect_influencer.attention_bound * 100 for p in perfect_producers], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producers], [imperfect_influencer_stats.following_rates[-1][p.agent.index] / imperfect_influencer.attention_bound * 100 for p in imperfect_producers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

plt.figure()
plt.title("Influencer Ending Following Rate By Producer Topic Produced")
plt.xlabel("Producer Topic Produced")
plt.ylabel("Following Rate (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_producers = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.topics[-1])
imperfect_producers = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.topics[-1])

plt.plot([p.topics[-1] for p in perfect_producers], [perfect_influencer_stats.following_rates[-1][p.agent.index] / perfect_influencer.attention_bound * 100 for p in perfect_producers], label="Perfect Information", marker='o')
plt.plot([p.topics[-1] for p in imperfect_producers], [imperfect_influencer_stats.following_rates[-1][p.agent.index] / imperfect_influencer.attention_bound * 100 for p in imperfect_producers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
perfect_influencer_stats = list(perfect_stats.influencer_stats.values())[0]
perfect_influencer = perfect_market.influencers[0]
imperfect_influencer_stats = list(imperfect_stats.influencer_stats.values())[0]
imperfect_influencer = imperfect_market.influencers[0]

perfect_consumers: list[ConsumerProducer] = sorted(perfect_market.consumers, key=lambda x: x.main_interest)
imperfect_consumers: list[ConsumerProducer] = sorted(imperfect_market.consumers, key=lambda x: x.main_interest)

plt.figure()
plt.title("Influencer Ending Followers by Consumer Main Interest")
plt.xlabel("Consumer Main Interest")
plt.ylabel("Followers (% of consumer bound)")
plt.xlim(topics[0][0], topics[0][1])

plt.plot([c.main_interest for c in perfect_consumers], [perfect_stats.consumer_stats[c.index].following_rates[-1][perfect_influencer.index] / c.attention_bound * 100 for c in perfect_consumers], label="Perfect Information", marker='o')
plt.plot([c.main_interest for c in imperfect_consumers], [imperfect_stats.consumer_stats[c.index].following_rates[-1][imperfect_influencer.index] / c.attention_bound * 100 for c in imperfect_consumers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Ending Topic Produced by Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Topic Produced")
plt.xlim(topics[0][0], topics[0][1])
plt.ylim(topics[0][0], topics[0][1])

perfect_producer_stats = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producer_stats = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([p.agent.main_interest for p in perfect_producer_stats], [p.topics[-1] for p in perfect_producer_stats], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producer_stats], [p.topics[-1] for p in imperfect_producer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Topic Standard Deviation by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Standard Deviation")
plt.plot(perfect_stats.producer_topic_standard_deviation, label="Perfect Information")
plt.plot(imperfect_stats.producer_topic_standard_deviation, label="Imperfect Information")

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Topic Distance From Main Interest By Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Ending Topic Distance From Main Interest (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_producer_stats = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producer_stats = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([p.agent.main_interest for p in perfect_producer_stats], [np.linalg.norm(p.topics[-1] - p.agent.main_interest) / (np.linalg.norm(p.agent.main_interest) + 1e-3) * 100 for p in perfect_producer_stats], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producer_stats], [np.linalg.norm(p.topics[-1] - p.agent.main_interest) / (np.linalg.norm(p.agent.main_interest) + 1e-3) * 100 for p in imperfect_producer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Following Rate by Main Interest Closeness")
plt.xlabel("Main Interest Closeness")
plt.ylabel("Average Following Rate (%)")

perfect_rates_by_closeness = dict()
imperfect_rates_by_closeness = dict()

for consumer_stat in perfect_stats.consumer_stats.values():
    for producer in perfect_market.producers:
        if producer == consumer_stat.agent:
            continue
        closeness = np.linalg.norm(producer.main_interest - consumer_stat.agent.main_interest)
        if closeness not in perfect_rates_by_closeness:
            perfect_rates_by_closeness[closeness] = []
        perfect_rates_by_closeness[closeness].append(consumer_stat.following_rates[-1][producer.index] / consumer_stat.agent.attention_bound * 100)
perfect_rates_by_closeness = {k: np.mean(v) for k, v in perfect_rates_by_closeness.items()}
plt.plot(list(perfect_rates_by_closeness.keys()), list(perfect_rates_by_closeness.values()), label="Perfect Information")

for consumer_stat in imperfect_stats.consumer_stats.values():
    for producer in imperfect_market.producers:
        if producer == consumer_stat.agent:
            continue
        closeness = np.linalg.norm(producer.main_interest - consumer_stat.agent.main_interest)
        if closeness not in imperfect_rates_by_closeness:
            imperfect_rates_by_closeness[closeness] = []
        imperfect_rates_by_closeness[closeness].append(consumer_stat.following_rates[-1][producer.index] / consumer_stat.agent.attention_bound * 100)
imperfect_rates_by_closeness = {k: np.mean(v) for k, v in imperfect_rates_by_closeness.items()}
plt.plot(list(imperfect_rates_by_closeness.keys()), list(imperfect_rates_by_closeness.values()), label="Imperfect Information")

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Percentage of Producers Followed by Main Interest")
plt.xlabel("Main Interest")
plt.ylabel("Percentage of Producers Followed (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_consumer_stats = sorted(perfect_stats.consumer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_consumer_stats = sorted(imperfect_stats.consumer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([c.agent.main_interest for c in perfect_consumer_stats], [len([p for p in perfect_market.producers if c.following_rates[-1][p.index] > 0]) / len(perfect_market.producers) * 100 for c in perfect_consumer_stats], label="Perfect Information", marker='o')
plt.plot([c.agent.main_interest for c in imperfect_consumer_stats], [len([p for p in imperfect_market.producers if c.following_rates[-1][p.index] > 0]) / len(imperfect_market.producers) * 100 for c in imperfect_consumer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
perfect_producers = sorted(perfect_market.producers, key=lambda x: x.main_interest)
imperfect_producers = sorted(imperfect_market.producers, key=lambda x: x.main_interest)

for consumer in perfect_market.consumers:
    perfect_stat = perfect_stats.consumer_stats[consumer.index]
    imperfect_stat = imperfect_stats.consumer_stats[consumer.index]

    plt.figure()
    plt.title(f"Following rates for consumer {consumer.index}")
    plt.xlabel("Producer Main Interest")
    plt.ylabel("Following Rate (%)")
    plt.xlim(topics[0][0] - 0.05, topics[0][1] + 0.05)

    plt.plot([p.main_interest for p in perfect_producers if p != perfect_stat.agent], [perfect_stat.following_rates[-1][p.index] / consumer.attention_bound * 100 for p in perfect_producers if p != perfect_stat.agent], label="Perfect Information", marker='o', color='blue')
    plt.plot([p.main_interest for p in imperfect_producers if p != imperfect_stat.agent], [imperfect_stat.following_rates[-1][p.index] / consumer.attention_bound * 100 for p in imperfect_producers if p != imperfect_stat.agent], label="Imperfect Information", marker='o', color='orange')

    # vertical line at consumer main interest
    plt.axvline(x=consumer.main_interest, color='r', linestyle='--', label="Consumer Main Interest")

    # horizontal line at influencer following rate
    plt.axhline(y=perfect_stat.following_rates[-1][-2] / consumer.attention_bound * 100, color='blue', linestyle='--', label="Influencer (Perfect)")
    plt.axhline(y=imperfect_stat.following_rates[-1][-2] / consumer.attention_bound * 100, color='orange', linestyle='--', label="Influencer (Imperfect)")

    # horizontal line at external following rate
    plt.axhline(y=perfect_stat.following_rates[-1][-1] / consumer.attention_bound * 100, color='blue', linestyle='-.', label="External (Perfect)")
    plt.axhline(y=imperfect_stat.following_rates[-1][-1] / consumer.attention_bound * 100, color='orange', linestyle='-.', label="External (Imperfect)")

    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()
