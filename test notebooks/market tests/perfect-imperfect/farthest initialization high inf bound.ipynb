# %%
from agents import ConsumerProducer, Influencer, ImperfectConsumerProducer
from content_market import ContentMarket
import numpy as np
from stats import TestStats
from util import exponential_decay, inverse_decay, tanh_decay
import matplotlib.pyplot as plt
import visualize

# %%
num_influencers = 1
num_consumer_producers = 10

production_rate = 1
external_production_rate = 1

topics = [[-1, 1]]
topics = np.array(topics)

# %%
perfect_market = ContentMarket(topics, production_rate, external_production_rate)
imperfect_market = ContentMarket(topics, production_rate, external_production_rate)

# %%
agent_colors = dict()

for i in range(num_consumer_producers):
    cons_func = lambda x: inverse_decay(x, 0.5, 2)
    prod_func = lambda x: inverse_decay(x, 0.5, 2)
    perfect_consumer_producer = ConsumerProducer(prod_func, cons_func, 10, 3, 5, init_following_rates_method='equal')
    imperfect_consumer_producer = ImperfectConsumerProducer(prod_func, cons_func, 10, 3, 5, init_following_rates_method='equal')
    perfect_market.add_agent(perfect_consumer_producer)
    imperfect_market.add_agent(imperfect_consumer_producer)

    color = np.random.rand(3,)
    agent_colors[perfect_consumer_producer.index] = color

for i in range(num_influencers):
    perfect_influencer = Influencer(80, 1, init_following_rates_method='equal')
    imperfect_influencer = Influencer(80, 1, init_following_rates_method='equal')
    perfect_market.add_agent(perfect_influencer)
    imperfect_market.add_agent(imperfect_influencer)

    color = np.random.rand(3,)
    agent_colors[perfect_influencer.index] = color

# %%
perfect_market.finalize(method='even')
imperfect_market.finalize(method='even')

# %%
visualize.plot_topic_distribution_histogram("Consumer/Producer Topic Distribution (Perfect)", perfect_market.consumers, -1, 1)
visualize.plot_topic_distribution_histogram("Consumer/Producer Topic Distribution (Imperfect)", imperfect_market.consumers, -1, 1)

# %%
visualize.plot_consumer_topic_interest_distributions("Consumer Topic Interest Distributions (Perfect)", perfect_market.consumers, -1, 1, agent_colors)
visualize.plot_consumer_topic_interest_distributions("Consumer Topic Interest Distributions (Imperfect)", imperfect_market.consumers, -1, 1, agent_colors)

# %%
visualize.plot_producer_topic_probability_distributions("Producer Topic Probability Distributions (Perfect)", perfect_market.producers, -1, 1, agent_colors)
visualize.plot_producer_topic_probability_distributions("Producer Topic Probability Distributions (Imperfect)", imperfect_market.producers, -1, 1, agent_colors)

# %%
perfect_stats: TestStats = perfect_market.optimize(100, topic_position='farthest')
imperfect_stats: TestStats = imperfect_market.optimize(100, topic_position='farthest')
# Out:
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.006845167023129761s): nit=5, nfev=18, njev=9.
# Optimizing producer 1
# Optimization succeeded (overall 0.004480500007048249s): nit=5, nfev=14, njev=7.
# Optimizing producer 2
# Optimization succeeded (overall 0.003897958085872233s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.00466620794031769s): nit=3, nfev=14, njev=7.
# Optimizing producer 4
# Optimization succeeded (overall 0.0058387500466778874s): nit=5, nfev=18, njev=9.
# Optimizing producer 5
# Optimization succeeded (overall 0.006117625045590103s): nit=5, nfev=18, njev=9.
# Optimizing producer 6
# Optimization succeeded (overall 0.0042309589916840196s): nit=3, nfev=14, njev=7.
# Optimizing producer 7
# Optimization succeeded (overall 0.0042233329731971025s): nit=4, nfev=12, njev=6.
# Optimizing producer 8
# Optimization succeeded (overall 0.004428667016327381s): nit=5, nfev=14, njev=7.
# Optimizing producer 9
# Optimization succeeded (overall 0.010828375001437962s): nit=5, nfev=18, njev=9.
# Iteration 0 / 100 done in 0.9456050409935415 seconds.
# Total Social Welfare: 34.59659472093906
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.005859958007931709s): nit=2, nfev=8, njev=4.
# Optimizing producer 1
# Optimization succeeded (overall 0.006906541064381599s): nit=2, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.0031987919937819242s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.0021940829465165734s): nit=2, nfev=8, njev=4.
# Optimizing producer 4
# Optimization succeeded (overall 0.0013831250835210085s): nit=1, nfev=6, njev=3.
# Optimizing producer 5
# Optimization succeeded (overall 0.001776584074832499s): nit=1, nfev=6, njev=3.
# Optimizing producer 6
# Optimization succeeded (overall 0.0019475839799270034s): nit=2, nfev=8, njev=4.
# Optimizing producer 7
# Optimization succeeded (overall 0.0023950409376993775s): nit=2, nfev=8, njev=4.
# Optimizing producer 8
# Optimization succeeded (overall 0.0021810419857501984s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.0021354579366743565s): nit=2, nfev=8, njev=4.
# Iteration 1 / 100 done in 0.48275162500794977 seconds.
# Total Social Welfare: 37.68987350379099
# Consumer rate change: 6.026991418888491
# Consumer utility change: 0.08207185842165819%
# Influencer rate change: 2.6161680818158426
# Influencer utility change: 0.07243817170311453%
# Producer topic change: 0.0012282108259532563
# Producer utility change: 0.07243815808224047%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0018243750091642141s): nit=1, nfev=6, njev=3.
# Optimizing producer 1
# Optimization succeeded (overall 0.0015799589455127716s): nit=1, nfev=6, njev=3.
# Optimizing producer 2
# Optimization succeeded (overall 0.0020832919981330633s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.0014215409755706787s): nit=1, nfev=6, njev=3.
# Optimizing producer 4
# Optimization succeeded (overall 0.002464666962623596s): nit=1, nfev=6, njev=3.
# Optimizing producer 5
# Optimization succeeded (overall 0.0019923329818993807s): nit=1, nfev=6, njev=3.
# Optimizing producer 6
# Optimization succeeded (overall 0.0016486250096932054s): nit=1, nfev=6, njev=3.
# Optimizing producer 7
# Optimization succeeded (overall 0.002049292088486254s): nit=2, nfev=8, njev=4.
# Optimizing producer 8
# Optimization succeeded (overall 0.001305874902755022s): nit=1, nfev=6, njev=3.
# Optimizing producer 9
# Optimization succeeded (overall 0.0027012500213459134s): nit=1, nfev=6, njev=3.
# Iteration 2 / 100 done in 0.08207579201553017 seconds.
# Total Social Welfare: 37.69019833318241
# Consumer rate change: 0.0
# Consumer utility change: 8.618402651261765e-06%
# Influencer rate change: 0.0
# Influencer utility change: 4.406860037567832e-06%
# Producer topic change: 0.0018527902860375242
# Producer utility change: 4.406859208410236e-06%
# Converged. Optimization took 1.535828125081025 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 45.40065104200039s): nit=1, nfev=90, njev=45.
# Optimizing producer 1
# Optimization succeeded (overall 0.2279337920481339s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 16.07676566601731s): nit=4, nfev=66, njev=33.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 37.094758540974s): nit=1, nfev=52, njev=26.
# Optimizing producer 4
# Optimization succeeded (overall 0.2431200840510428s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.2915738330921158s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 63.12191229197197s): nit=1, nfev=58, njev=29.
# Optimizing producer 7
# Optimization succeeded (overall 29.215361082926393s): nit=8, nfev=108, njev=54.
# Optimizing producer 8
# Optimization succeeded (overall 0.22942583390977234s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.7231358330463991s): nit=1, nfev=4, njev=2.
# Iteration 0 / 100 done in 193.5027345829876 seconds.
# Total Social Welfare: 29.501986172988506
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 35.489186999970116s): nit=1, nfev=44, njev=22.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 84.58710808295291s): nit=2, nfev=174, njev=87.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 64.0373021659907s): nit=1, nfev=78, njev=39.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 37.48260016704444s): nit=1, nfev=54, njev=27.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 89.4687052910449s): nit=2, nfev=148, njev=74.
# Optimizing producer 5
# Optimization succeeded (overall 0.6491882499540225s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 28.21999366604723s): nit=4, nfev=96, njev=48.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 35.085659082978964s): nit=3, nfev=76, njev=38.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 59.636174167040735s): nit=1, nfev=56, njev=28.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 46.404860167065635s): nit=1, nfev=46, njev=23.
# Iteration 1 / 100 done in 481.60657279205043 seconds.
# Total Social Welfare: 32.899588959186
# Consumer rate change: 3.814396867940123
# Consumer utility change: 0.10327186025618217%
# Influencer rate change: 7.88834981904585
# Influencer utility change: 0.23056939172428903%
# Producer topic change: 0.31759607005870216
# Producer utility change: 0.0069196972576859314%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 88.20394383301027s): nit=1, nfev=90, njev=45.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 72.97865787509363s): nit=2, nfev=178, njev=89.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 122.77444904099684s): nit=1, nfev=84, njev=42.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 69.25026095891371s): nit=1, nfev=90, njev=45.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 67.17317570897285s): nit=2, nfev=72, njev=36.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 84.753683750052s): nit=1, nfev=92, njev=46.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 60.23461620800663s): nit=1, nfev=74, njev=37.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 58.22582637495361s): nit=1, nfev=66, njev=33.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 80.63228633289691s): nit=3, nfev=154, njev=77.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 65.77443179197144s): nit=1, nfev=58, njev=29.
# Iteration 2 / 100 done in 770.5279404160101 seconds.
# Total Social Welfare: 35.03465464654664
# Consumer rate change: 0.8989183835648159
# Consumer utility change: 0.06094151917538341%
# Influencer rate change: 7.013099279579245
# Influencer utility change: 0.11896749545567804%
# Producer topic change: 0.22704745817495403
# Producer utility change: 0.003308370236482024%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 49.495298916939646s): nit=1, nfev=70, njev=35.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 49.22791987506207s): nit=2, nfev=200, njev=100.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 21.31323741597589s): nit=1, nfev=62, njev=31.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 57.06960337492637s): nit=2, nfev=166, njev=83.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 55.27281745802611s): nit=1, nfev=96, njev=48.
# Optimizing producer 5
# Optimization succeeded (overall 23.00017045903951s): nit=5, nfev=110, njev=55.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 46.45290670800023s): nit=1, nfev=76, njev=38.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 45.756433041067794s): nit=1, nfev=104, njev=52.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 20.94925325002987s): nit=1, nfev=42, njev=21.
# Optimizing producer 9
# Optimization succeeded (overall 20.22520733298734s): nit=5, nfev=100, njev=50.
# Iteration 3 / 100 done in 389.1099633750273 seconds.
# Total Social Welfare: 35.97128699316828
# Consumer rate change: 0.6608969964765843
# Consumer utility change: 0.026038325690606205%
# Influencer rate change: 2.553022664978148
# Influencer utility change: 0.061209572953482914%
# Producer topic change: 0.07996253839805137
# Producer utility change: 0.0003425386733706472%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 19.96391216700431s): nit=1, nfev=102, njev=51.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 22.02774937497452s): nit=1, nfev=82, njev=41.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 22.410310042090714s): nit=1, nfev=70, njev=35.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 20.895976416999474s): nit=1, nfev=78, njev=39.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 16.335091624991037s): nit=1, nfev=58, njev=29.
# Optimizing producer 5
# Optimization succeeded (overall 36.108434707974084s): nit=8, nfev=194, njev=97.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 21.774405290954746s): nit=1, nfev=58, njev=29.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 23.022194750024937s): nit=1, nfev=50, njev=25.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 23.137981415959075s): nit=1, nfev=56, njev=28.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 28.82469004194718s): nit=3, nfev=170, njev=85.
# Iteration 4 / 100 done in 234.72442404192407 seconds.
# Total Social Welfare: 36.16022659900874
# Consumer rate change: 0.2534479394386684
# Consumer utility change: 0.0052250655308387454%
# Influencer rate change: 2.402002937769126
# Influencer utility change: 0.008139174234295457%
# Producer topic change: 0.005507640500704648
# Producer utility change: 9.929911781337054e-05%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 13.313112291041762s): nit=1, nfev=60, njev=30.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 22.381639834027737s): nit=4, nfev=176, njev=88.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 15.711909375037067s): nit=2, nfev=114, njev=57.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 11.601808000006713s): nit=2, nfev=90, njev=45.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 18.72027208295185s): nit=1, nfev=66, njev=33.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 13.015021292027086s): nit=1, nfev=50, njev=25.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 23.322699000011198s): nit=2, nfev=174, njev=87.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 27.459951582946815s): nit=3, nfev=116, njev=58.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 16.921082749962807s): nit=1, nfev=74, njev=37.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 17.846434875042178s): nit=2, nfev=134, njev=67.
# Iteration 5 / 100 done in 180.43569137505256 seconds.
# Total Social Welfare: 36.68593029914671
# Consumer rate change: 0.02832874931902596
# Consumer utility change: 0.014329841237576323%
# Influencer rate change: 0.25009501396381284
# Influencer utility change: 0.030011384810426294%
# Producer topic change: 0.05703515740970172
# Producer utility change: 0.00022274071160400348%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 9.534214291954413s): nit=4, nfev=94, njev=47.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 17.750963625032455s): nit=1, nfev=60, njev=30.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 17.38173295801971s): nit=1, nfev=76, njev=38.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 35.08841695904266s): nit=2, nfev=182, njev=91.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 25.027296041953377s): nit=3, nfev=162, njev=81.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 32.407444249955006s): nit=4, nfev=160, njev=80.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 17.639269375009462s): nit=1, nfev=82, njev=41.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 10.79288633307442s): nit=2, nfev=70, njev=35.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 21.740651040920056s): nit=1, nfev=112, njev=56.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 11.744088124949485s): nit=1, nfev=76, njev=38.
# Iteration 6 / 100 done in 199.3354942080332 seconds.
# Total Social Welfare: 37.24735315079616
# Consumer rate change: 0.17927633033138396
# Consumer utility change: 0.015072821380040359%
# Influencer rate change: 0.9993563165442884
# Influencer utility change: 0.0313533417648906%
# Producer topic change: 0.05639326572398397
# Producer utility change: 4.819403720179629e-05%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 24.561218208051287s): nit=2, nfev=116, njev=58.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 12.877350624999963s): nit=1, nfev=84, njev=42.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 25.59658691601362s): nit=2, nfev=94, njev=47.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 22.819029958103783s): nit=1, nfev=68, njev=34.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 18.50578420900274s): nit=1, nfev=56, njev=28.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 15.945856292033568s): nit=1, nfev=58, njev=29.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 21.96827316598501s): nit=2, nfev=168, njev=84.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 23.914114415994845s): nit=2, nfev=128, njev=64.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 15.676813500002027s): nit=2, nfev=84, njev=42.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 21.459775042021647s): nit=3, nfev=150, njev=75.
# Iteration 7 / 100 done in 203.5453381249681 seconds.
# Total Social Welfare: 37.37500298639601
# Consumer rate change: 0.1850772181003196
# Consumer utility change: 0.0034153790300036724%
# Influencer rate change: 1.2834186930620655
# Influencer utility change: 0.006128796166332308%
# Producer topic change: 0.01368240470714072
# Producer utility change: 7.2216010296123225e-06%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 15.719541916972958s): nit=1, nfev=38, njev=19.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 22.16074349998962s): nit=2, nfev=152, njev=76.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 13.015877541038208s): nit=1, nfev=54, njev=27.
# Optimizing producer 3
# Optimization succeeded (overall 3.937823250074871s): nit=3, nfev=44, njev=22.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 11.756361957988702s): nit=2, nfev=88, njev=44.
# Optimizing producer 5
# Optimization succeeded (overall 5.500503999995999s): nit=3, nfev=62, njev=31.
# Optimizing producer 6
# Optimization succeeded (overall 4.78445495897904s): nit=2, nfev=56, njev=28.
# Optimizing producer 7
# Optimization succeeded (overall 5.951150916982442s): nit=3, nfev=64, njev=32.
# Optimizing producer 8
# Optimization succeeded (overall 4.822862415923737s): nit=3, nfev=56, njev=28.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 14.633869208046235s): nit=3, nfev=144, njev=72.
# Iteration 8 / 100 done in 102.42214333405718 seconds.
# Total Social Welfare: 37.37555382675911
# Consumer rate change: 0.02333247996538716
# Consumer utility change: 1.4737981362735075e-05%
# Influencer rate change: 0.19236890185620958
# Influencer utility change: 5.885768000424179e-05%
# Producer topic change: 2.015653664695638e-06
# Producer utility change: 0.0%
# Converged. Optimization took 2768.8218589160824 seconds.

# %%
plt.figure()
plt.title("Total Social Welfare by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Total Social Welfare")
plt.plot(perfect_stats.total_social_welfare, label="Perfect Information")
plt.plot(imperfect_stats.total_social_welfare, label="Imperfect Information")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Cost of Influence by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Cost of Influence (%)")
costs = []
for i in range(1, max(len(perfect_stats.total_social_welfare), len(imperfect_stats.total_social_welfare))):
    perfect_welfare = perfect_stats.total_social_welfare[i] + 1e-10 if i < len(perfect_stats.total_social_welfare) else perfect_stats.total_social_welfare[-1]
    imperfect_welfare = imperfect_stats.total_social_welfare[i] if i < len(imperfect_stats.total_social_welfare) else imperfect_stats.total_social_welfare[-1]
    costs.append((perfect_welfare - imperfect_welfare) / perfect_welfare * 100)
plt.plot(list(range(1, max(len(perfect_stats.total_social_welfare), len(imperfect_stats.total_social_welfare)))), costs)
plt.show()

# %%
plt.figure()
plt.title("Average Consumer Utility By Iteration")
plt.plot(perfect_stats.average_consumer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_consumer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Producer Utility By Iteration")
plt.plot(perfect_stats.average_producer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_producer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Influencer Utility By Iteration")
plt.plot(perfect_stats.average_influencer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_influencer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
perfect_influencer = perfect_market.influencers[0]
perfect_influencer_stats = perfect_stats.influencer_stats[perfect_influencer.index]
imperfect_influencer = imperfect_market.influencers[0]
imperfect_influencer_stats = imperfect_stats.influencer_stats[imperfect_influencer.index]

perfect_producers = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producers = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.figure()
plt.title("Influencer Ending Following Rate By Producer Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Following Rate (%)")
plt.xlim(topics[0][0], topics[0][1])

plt.plot([p.agent.main_interest for p in perfect_producers], [perfect_influencer_stats.following_rates[-1][p.agent.index] / perfect_influencer.attention_bound * 100 for p in perfect_producers], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producers], [imperfect_influencer_stats.following_rates[-1][p.agent.index] / imperfect_influencer.attention_bound * 100 for p in imperfect_producers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

plt.figure()
plt.title("Influencer Ending Following Rate By Producer Topic Produced")
plt.xlabel("Producer Topic Produced")
plt.ylabel("Following Rate (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_producers = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.topics[-1])
imperfect_producers = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.topics[-1])

plt.plot([p.topics[-1] for p in perfect_producers], [perfect_influencer_stats.following_rates[-1][p.agent.index] / perfect_influencer.attention_bound * 100 for p in perfect_producers], label="Perfect Information", marker='o')
plt.plot([p.topics[-1] for p in imperfect_producers], [imperfect_influencer_stats.following_rates[-1][p.agent.index] / imperfect_influencer.attention_bound * 100 for p in imperfect_producers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
perfect_influencer_stats = list(perfect_stats.influencer_stats.values())[0]
perfect_influencer = perfect_market.influencers[0]
imperfect_influencer_stats = list(imperfect_stats.influencer_stats.values())[0]
imperfect_influencer = imperfect_market.influencers[0]

perfect_consumers: list[ConsumerProducer] = sorted(perfect_market.consumers, key=lambda x: x.main_interest)
imperfect_consumers: list[ConsumerProducer] = sorted(imperfect_market.consumers, key=lambda x: x.main_interest)

plt.figure()
plt.title("Influencer Ending Followers by Consumer Main Interest")
plt.xlabel("Consumer Main Interest")
plt.ylabel("Followers (% of consumer bound)")
plt.xlim(topics[0][0], topics[0][1])

plt.plot([c.main_interest for c in perfect_consumers], [perfect_stats.consumer_stats[c.index].following_rates[-1][perfect_influencer.index] / c.attention_bound * 100 for c in perfect_consumers], label="Perfect Information", marker='o')
plt.plot([c.main_interest for c in imperfect_consumers], [imperfect_stats.consumer_stats[c.index].following_rates[-1][imperfect_influencer.index] / c.attention_bound * 100 for c in imperfect_consumers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Ending Topic Produced by Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Topic Produced")
plt.xlim(topics[0][0], topics[0][1])
plt.ylim(topics[0][0], topics[0][1])

perfect_producer_stats = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producer_stats = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([p.agent.main_interest for p in perfect_producer_stats], [p.topics[-1] for p in perfect_producer_stats], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producer_stats], [p.topics[-1] for p in imperfect_producer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Topic Standard Deviation by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Standard Deviation")
plt.plot(perfect_stats.producer_topic_standard_deviation, label="Perfect Information")
plt.plot(imperfect_stats.producer_topic_standard_deviation, label="Imperfect Information")

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Topic Distance From Main Interest By Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Ending Topic Distance From Main Interest (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_producer_stats = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producer_stats = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([p.agent.main_interest for p in perfect_producer_stats], [np.linalg.norm(p.topics[-1] - p.agent.main_interest) / (np.linalg.norm(p.agent.main_interest) + 1e-3) * 100 for p in perfect_producer_stats], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producer_stats], [np.linalg.norm(p.topics[-1] - p.agent.main_interest) / (np.linalg.norm(p.agent.main_interest) + 1e-3) * 100 for p in imperfect_producer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Following Rate by Main Interest Closeness")
plt.xlabel("Main Interest Closeness")
plt.ylabel("Average Following Rate (%)")

perfect_rates_by_closeness = dict()
imperfect_rates_by_closeness = dict()

for consumer_stat in perfect_stats.consumer_stats.values():
    for producer in perfect_market.producers:
        if producer == consumer_stat.agent:
            continue
        closeness = np.linalg.norm(producer.main_interest - consumer_stat.agent.main_interest)
        if closeness not in perfect_rates_by_closeness:
            perfect_rates_by_closeness[closeness] = []
        perfect_rates_by_closeness[closeness].append(consumer_stat.following_rates[-1][producer.index] / consumer_stat.agent.attention_bound * 100)
perfect_rates_by_closeness = {k: np.mean(v) for k, v in perfect_rates_by_closeness.items()}
plt.plot(list(perfect_rates_by_closeness.keys()), list(perfect_rates_by_closeness.values()), label="Perfect Information")

for consumer_stat in imperfect_stats.consumer_stats.values():
    for producer in imperfect_market.producers:
        if producer == consumer_stat.agent:
            continue
        closeness = np.linalg.norm(producer.main_interest - consumer_stat.agent.main_interest)
        if closeness not in imperfect_rates_by_closeness:
            imperfect_rates_by_closeness[closeness] = []
        imperfect_rates_by_closeness[closeness].append(consumer_stat.following_rates[-1][producer.index] / consumer_stat.agent.attention_bound * 100)
imperfect_rates_by_closeness = {k: np.mean(v) for k, v in imperfect_rates_by_closeness.items()}
plt.plot(list(imperfect_rates_by_closeness.keys()), list(imperfect_rates_by_closeness.values()), label="Imperfect Information")

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Percentage of Producers Followed by Main Interest")
plt.xlabel("Main Interest")
plt.ylabel("Percentage of Producers Followed (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_consumer_stats = sorted(perfect_stats.consumer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_consumer_stats = sorted(imperfect_stats.consumer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([c.agent.main_interest for c in perfect_consumer_stats], [len([p for p in perfect_market.producers if c.following_rates[-1][p.index] > 0]) / len(perfect_market.producers) * 100 for c in perfect_consumer_stats], label="Perfect Information", marker='o')
plt.plot([c.agent.main_interest for c in imperfect_consumer_stats], [len([p for p in imperfect_market.producers if c.following_rates[-1][p.index] > 0]) / len(imperfect_market.producers) * 100 for c in imperfect_consumer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
perfect_producers = sorted(perfect_market.producers, key=lambda x: x.main_interest)
imperfect_producers = sorted(imperfect_market.producers, key=lambda x: x.main_interest)

for consumer in perfect_market.consumers:
    perfect_stat = perfect_stats.consumer_stats[consumer.index]
    imperfect_stat = imperfect_stats.consumer_stats[consumer.index]

    plt.figure()
    plt.title(f"Following rates for consumer {consumer.index}")
    plt.xlabel("Producer Main Interest")
    plt.ylabel("Following Rate (%)")
    plt.xlim(topics[0][0] - 0.05, topics[0][1] + 0.05)

    plt.plot([p.main_interest for p in perfect_producers if p != perfect_stat.agent], [perfect_stat.following_rates[-1][p.index] / consumer.attention_bound * 100 for p in perfect_producers if p != perfect_stat.agent], label="Perfect Information", marker='o', color='blue')
    plt.plot([p.main_interest for p in imperfect_producers if p != imperfect_stat.agent], [imperfect_stat.following_rates[-1][p.index] / consumer.attention_bound * 100 for p in imperfect_producers if p != imperfect_stat.agent], label="Imperfect Information", marker='o', color='orange')

    # vertical line at consumer main interest
    plt.axvline(x=consumer.main_interest, color='r', linestyle='--', label="Consumer Main Interest")

    # horizontal line at influencer following rate
    plt.axhline(y=perfect_stat.following_rates[-1][-2] / consumer.attention_bound * 100, color='blue', linestyle='--', label="Influencer (Perfect)")
    plt.axhline(y=imperfect_stat.following_rates[-1][-2] / consumer.attention_bound * 100, color='orange', linestyle='--', label="Influencer (Imperfect)")

    # horizontal line at external following rate
    plt.axhline(y=perfect_stat.following_rates[-1][-1] / consumer.attention_bound * 100, color='blue', linestyle='-.', label="External (Perfect)")
    plt.axhline(y=imperfect_stat.following_rates[-1][-1] / consumer.attention_bound * 100, color='orange', linestyle='-.', label="External (Imperfect)")

    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()
