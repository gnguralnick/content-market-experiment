# %%
from agents import ConsumerProducer, Influencer, ImperfectConsumerProducer
from content_market import ContentMarket
import numpy as np
from stats import TestStats
from util import exponential_decay, inverse_decay, tanh_decay
import matplotlib.pyplot as plt
import visualize

# %%
num_influencers = 1
num_consumer_producers = 10

production_rate = 1
external_production_rate = 1

topics = [[-1, 1]]
topics = np.array(topics)

# %%
perfect_market = ContentMarket(topics, production_rate, external_production_rate)
imperfect_market = ContentMarket(topics, production_rate, external_production_rate)

# %%
agent_colors = dict()

for i in range(num_consumer_producers):
    cons_func = lambda x: inverse_decay(x, 1, 2)
    prod_func = lambda x: inverse_decay(x, 1, 2)
    perfect_consumer_producer = ConsumerProducer(prod_func, cons_func, 20, 3, 1, init_following_rates_method='equal')
    imperfect_consumer_producer = ImperfectConsumerProducer(prod_func, cons_func, 20, 3, 1, init_following_rates_method='equal')
    perfect_market.add_agent(perfect_consumer_producer)
    imperfect_market.add_agent(imperfect_consumer_producer)

    color = np.random.rand(3,)
    agent_colors[perfect_consumer_producer.index] = color

for i in range(num_influencers):
    perfect_influencer = Influencer(40, 1, init_following_rates_method='equal')
    imperfect_influencer = Influencer(40, 1, init_following_rates_method='equal')
    perfect_market.add_agent(perfect_influencer)
    imperfect_market.add_agent(imperfect_influencer)

    color = np.random.rand(3,)
    agent_colors[perfect_influencer.index] = color

# %%
perfect_market.finalize(method='even')
imperfect_market.finalize(method='even')

# %%
visualize.plot_topic_distribution_histogram("Consumer/Producer Topic Distribution (Perfect)", perfect_market.consumers, -1, 1)
visualize.plot_topic_distribution_histogram("Consumer/Producer Topic Distribution (Imperfect)", imperfect_market.consumers, -1, 1)

# %%
visualize.plot_consumer_topic_interest_distributions("Consumer Topic Interest Distributions (Perfect)", perfect_market.consumers, -1, 1, agent_colors)
visualize.plot_consumer_topic_interest_distributions("Consumer Topic Interest Distributions (Imperfect)", imperfect_market.consumers, -1, 1, agent_colors)

# %%
visualize.plot_producer_topic_probability_distributions("Producer Topic Probability Distributions (Perfect)", perfect_market.producers, -1, 1, agent_colors)
visualize.plot_producer_topic_probability_distributions("Producer Topic Probability Distributions (Imperfect)", imperfect_market.producers, -1, 1, agent_colors)

# %%
perfect_stats: TestStats = perfect_market.optimize(100, topic_position='farthest')
imperfect_stats: TestStats = imperfect_market.optimize(100, topic_position='farthest')
# Out:
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0043550829868763685s): nit=4, nfev=14, njev=7.
# Optimizing producer 1
# Optimization succeeded (overall 0.0052429999923333526s): nit=4, nfev=18, njev=9.
# Optimizing producer 2
# Optimization succeeded (overall 0.00575224997010082s): nit=5, nfev=20, njev=10.
# Optimizing producer 3
# Optimization succeeded (overall 0.004748707986436784s): nit=4, nfev=16, njev=8.
# Optimizing producer 4
# Optimization succeeded (overall 0.005984958028420806s): nit=5, nfev=18, njev=9.
# Optimizing producer 5
# Optimization succeeded (overall 0.006169624975882471s): nit=5, nfev=18, njev=9.
# Optimizing producer 6
# Optimization succeeded (overall 0.005907624959945679s): nit=4, nfev=16, njev=8.
# Optimizing producer 7
# Optimization succeeded (overall 0.006770375068299472s): nit=5, nfev=20, njev=10.
# Optimizing producer 8
# Optimization succeeded (overall 0.006428457912988961s): nit=4, nfev=18, njev=9.
# Optimizing producer 9
# Optimization succeeded (overall 0.00505862501449883s): nit=4, nfev=14, njev=7.
# Iteration 0 / 100 done in 1.0605139170074835 seconds.
# Total Social Welfare: 80.29078970582057
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0027486669132485986s): nit=3, nfev=10, njev=5.
# Optimizing producer 1
# Optimization succeeded (overall 0.002935666940174997s): nit=3, nfev=10, njev=5.
# Optimizing producer 2
# Optimization succeeded (overall 0.0028140839422121644s): nit=3, nfev=10, njev=5.
# Optimizing producer 3
# Optimization succeeded (overall 0.0029132500058040023s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.0028996249893680215s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.0027703330852091312s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.0027737499913200736s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.002770208055153489s): nit=3, nfev=10, njev=5.
# Optimizing producer 8
# Optimization succeeded (overall 0.0026522079715505242s): nit=3, nfev=10, njev=5.
# Optimizing producer 9
# Optimization succeeded (overall 0.0026342920027673244s): nit=3, nfev=10, njev=5.
# Iteration 1 / 100 done in 0.7573016249807552 seconds.
# Total Social Welfare: 84.00867246913901
# Consumer rate change: 3.2103680180793654
# Consumer utility change: 0.044255934672993276%
# Influencer rate change: 1.3833510717715511
# Influencer utility change: 0.04947198487911272%
# Producer topic change: 0.05703645281202766
# Producer utility change: 0.09777196265230698%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0024185420479625463s): nit=2, nfev=8, njev=4.
# Optimizing producer 1
# Optimization succeeded (overall 0.002133166999556124s): nit=2, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.0027744999388232827s): nit=3, nfev=10, njev=5.
# Optimizing producer 3
# Optimization succeeded (overall 0.0029198749689385295s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.0029241660377010703s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.0028180829249322414s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.0027760829543694854s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0027725830441340804s): nit=3, nfev=10, njev=5.
# Optimizing producer 8
# Optimization succeeded (overall 0.002120874938555062s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.002109041903167963s): nit=2, nfev=8, njev=4.
# Iteration 2 / 100 done in 0.28497070900630206 seconds.
# Total Social Welfare: 84.0555421391997
# Consumer rate change: 0.11868423107699318
# Consumer utility change: 0.0005576034999218754%
# Influencer rate change: 0.010077999225414124
# Influencer utility change: 0.0011450518882037772%
# Producer topic change: 0.017042985500379346
# Producer utility change: 0.0012258017645208525%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0016869170358404517s): nit=1, nfev=6, njev=3.
# Optimizing producer 1
# Optimization succeeded (overall 0.0016974169993773103s): nit=1, nfev=6, njev=3.
# Optimizing producer 2
# Optimization succeeded (overall 0.001687707961536944s): nit=1, nfev=6, njev=3.
# Optimizing producer 3
# Optimization succeeded (overall 0.002263750066049397s): nit=2, nfev=8, njev=4.
# Optimizing producer 4
# Optimization succeeded (overall 0.002345958026126027s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.0023340419866144657s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.002109499997459352s): nit=2, nfev=8, njev=4.
# Optimizing producer 7
# Optimization succeeded (overall 0.001603499986231327s): nit=1, nfev=6, njev=3.
# Optimizing producer 8
# Optimization succeeded (overall 0.001681333058513701s): nit=1, nfev=6, njev=3.
# Optimizing producer 9
# Optimization succeeded (overall 0.0015971669927239418s): nit=1, nfev=6, njev=3.
# Iteration 3 / 100 done in 0.21105333301238716 seconds.
# Total Social Welfare: 84.05713506608883
# Consumer rate change: 0.05443498377267295
# Consumer utility change: 1.8950523335880175e-05%
# Influencer rate change: 0.010779028858355659
# Influencer utility change: 4.408003056629353e-05%
# Producer topic change: 0.001198903952747625
# Producer utility change: -3.815081543146826e-05%
# Converged. Optimization took 2.341653790907003 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.3171845000470057s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.33714120904915035s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.3185481249820441s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 57.64974433404859s): nit=1, nfev=64, njev=32.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 48.54002370801754s): nit=3, nfev=122, njev=61.
# Optimizing producer 5
# Optimization succeeded (overall 30.642548499978147s): nit=6, nfev=168, njev=84.
# Optimizing producer 6
# Optimization succeeded (overall 0.7068102499470115s): nit=1, nfev=4, njev=2.
# Optimizing producer 7
# Optimization succeeded (overall 0.31439870805479586s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.31448958290275186s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.3105917919892818s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 140.47064225003123 seconds.
# Total Social Welfare: 53.20308838646897
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.5165478750132024s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.49101233307737857s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.5074480000184849s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 43.20884420804214s): nit=2, nfev=82, njev=41.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 56.00020379200578s): nit=1, nfev=88, njev=44.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 50.09704424999654s): nit=1, nfev=58, njev=29.
# Optimizing producer 6
# Optimization succeeded (overall 0.5187179580098018s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 35.446161665953696s): nit=1, nfev=54, njev=27.
# Optimizing producer 8
# Optimization succeeded (overall 0.9665295000886545s): nit=1, nfev=4, njev=2.
# Optimizing producer 9
# Optimization succeeded (overall 0.5384243750013411s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 189.17270370805636 seconds.
# Total Social Welfare: 63.10043769827077
# Consumer rate change: 2.149075715200685
# Consumer utility change: 0.156850698732412%
# Influencer rate change: 3.4653445558205984
# Influencer utility change: 0.2852607093774756%
# Producer topic change: 0.39338316721443634
# Producer utility change: -0.008339207588271403%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 100.85486920899712s): nit=2, nfev=94, njev=47.
# Optimizing producer 1
# Optimization succeeded (overall 0.6338896669913083s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.6199377500452101s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 57.47410704207141s): nit=1, nfev=60, njev=30.
# Optimizing producer 4
# Optimization succeeded (overall 18.305543749942444s): nit=3, nfev=62, njev=31.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 62.46829570794944s): nit=1, nfev=80, njev=40.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 59.63041733298451s): nit=1, nfev=62, njev=31.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 182.64730499999132s): nit=1, nfev=96, njev=48.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 60.66835275001358s): nit=1, nfev=94, njev=47.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 79.1388187080156s): nit=2, nfev=140, njev=70.
# Iteration 2 / 100 done in 623.2622598749585 seconds.
# Total Social Welfare: 74.61182241492612
# Consumer rate change: 1.2951650809315935
# Consumer utility change: 0.15428363496876796%
# Influencer rate change: 3.120417523548393
# Influencer utility change: 0.2829402105441884%
# Producer topic change: 0.5302666132385091
# Producer utility change: 0.013910875456165888%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 49.86338654207066s): nit=1, nfev=96, njev=48.
# Optimizing producer 1
# Optimization succeeded (overall 0.4769900409737602s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.4795962090138346s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 40.846975125023164s): nit=1, nfev=76, njev=38.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 48.02489199989941s): nit=1, nfev=86, njev=43.
# Optimizing producer 5
# Optimization succeeded (overall 20.89482499996666s): nit=5, nfev=94, njev=47.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 51.281195332994685s): nit=1, nfev=70, njev=35.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 60.1125608329894s): nit=1, nfev=64, njev=32.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 56.89705450006295s): nit=3, nfev=208, njev=104.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 43.90826087503228s): nit=1, nfev=86, njev=43.
# Iteration 3 / 100 done in 373.5023091660114 seconds.
# Total Social Welfare: 76.05637620939096
# Consumer rate change: 1.146644841128143
# Consumer utility change: 0.018993195265521248%
# Influencer rate change: 3.762138809620425
# Influencer utility change: 0.04123417278828764%
# Producer topic change: 0.010528344866987834
# Producer utility change: -3.37786427446314e-05%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 24.50196533300914s): nit=2, nfev=148, njev=74.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 27.731548959040083s): nit=1, nfev=84, njev=42.
# Optimizing producer 2
# Optimization succeeded (overall 0.11592266603838652s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 17.336222333018668s): nit=3, nfev=156, njev=78.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 12.653918209020048s): nit=1, nfev=96, njev=48.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 6.984387082979083s): nit=1, nfev=72, njev=36.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 15.955100291990675s): nit=2, nfev=126, njev=63.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 12.943541249958798s): nit=1, nfev=98, njev=49.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 12.180452874978073s): nit=2, nfev=102, njev=51.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 17.059784332988784s): nit=1, nfev=102, njev=51.
# Iteration 4 / 100 done in 147.7482062500203 seconds.
# Total Social Welfare: 77.6319740111835
# Consumer rate change: 0.12366284012676927
# Consumer utility change: 0.020295730192410797%
# Influencer rate change: 0.019206909611496407
# Influencer utility change: 0.043031597771579284%
# Producer topic change: 0.10168604891724595
# Producer utility change: 0.01313088229769%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 42.2053671249887s): nit=1, nfev=52, njev=26.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 45.649988709017634s): nit=1, nfev=86, njev=43.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 26.447169457911514s): nit=1, nfev=48, njev=24.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 32.25597862503491s): nit=1, nfev=100, njev=50.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 36.89205387502443s): nit=1, nfev=56, njev=28.
# Optimizing producer 5
# Optimization succeeded (overall 7.223426792072132s): nit=3, nfev=48, njev=24.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 30.17867383302655s): nit=1, nfev=82, njev=41.
# Optimizing producer 7
# Optimization succeeded (overall 21.72496575000696s): nit=8, nfev=144, njev=72.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 29.986553209018894s): nit=1, nfev=92, njev=46.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 26.54975737503264s): nit=1, nfev=88, njev=44.
# Iteration 5 / 100 done in 299.4861283749342 seconds.
# Total Social Welfare: 79.88325625252668
# Consumer rate change: 0.17642336159074426
# Consumer utility change: 0.028182150617457675%
# Influencer rate change: 1.8892178314503738
# Influencer utility change: 0.057721246122317646%
# Producer topic change: 0.1197536940617389
# Producer utility change: 0.01000451594670673%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 28.73229483398609s): nit=1, nfev=92, njev=46.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 33.78187258390244s): nit=1, nfev=90, njev=45.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 45.550722207990475s): nit=2, nfev=146, njev=73.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 26.003418083069846s): nit=1, nfev=48, njev=24.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 23.77058912499342s): nit=1, nfev=70, njev=35.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 43.8397869579494s): nit=2, nfev=172, njev=86.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 40.88528437493369s): nit=2, nfev=182, njev=91.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 13.968065124936402s): nit=1, nfev=58, njev=29.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 35.37665091594681s): nit=3, nfev=136, njev=68.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 27.665338082937524s): nit=1, nfev=110, njev=55.
# Iteration 6 / 100 done in 320.0434207080398 seconds.
# Total Social Welfare: 81.89302993613549
# Consumer rate change: 0.37453426639185594
# Consumer utility change: 0.024541446808863568%
# Influencer rate change: 1.2157438835590286
# Influencer utility change: 0.0482020176004476%
# Producer topic change: 0.08112470925418658
# Producer utility change: 0.0023265516549996913%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 25.582194791990332s): nit=1, nfev=90, njev=45.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 45.20668737497181s): nit=3, nfev=152, njev=76.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 18.515128125087358s): nit=1, nfev=48, njev=24.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 22.093469082959928s): nit=1, nfev=74, njev=37.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 37.14316412503831s): nit=1, nfev=90, njev=45.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 20.597203458077274s): nit=1, nfev=64, njev=32.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 25.38358387502376s): nit=1, nfev=96, njev=48.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 27.08534904103726s): nit=1, nfev=64, njev=32.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 33.633661166997626s): nit=1, nfev=70, njev=35.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 21.350697875022888s): nit=1, nfev=94, njev=47.
# Iteration 7 / 100 done in 276.92497658298817 seconds.
# Total Social Welfare: 82.00620170272072
# Consumer rate change: 0.1829041863926099
# Consumer utility change: 0.0013800389535794705%
# Influencer rate change: 1.2031808589584012
# Influencer utility change: 0.0053058561100147545%
# Producer topic change: 0.0005949598323065728
# Producer utility change: 0.0%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.03128804103471339s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.035207000095397234s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.03501350001897663s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.03517016698606312s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.04050083295442164s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.038863791967742145s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.029447500011883676s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.03039562504272908s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.03040337492711842s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.030468415934592485s): nit=0, nfev=2, njev=1.
# Iteration 8 / 100 done in 0.3926088330335915 seconds.
# Total Social Welfare: 82.00621522674106
# Consumer rate change: 0.0023728931397344532
# Consumer utility change: 1.6491455735756413e-07%
# Influencer rate change: 0.0
# Influencer utility change: -7.093486560155412e-05%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 2383.997566999984 seconds.

# %%
plt.figure()
plt.title("Total Social Welfare by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Total Social Welfare")
plt.plot(perfect_stats.total_social_welfare, label="Perfect Information")
plt.plot(imperfect_stats.total_social_welfare, label="Imperfect Information")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Cost of Influence by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Cost of Influence (%)")
costs = []
for i in range(1, max(len(perfect_stats.total_social_welfare), len(imperfect_stats.total_social_welfare))):
    perfect_welfare = perfect_stats.total_social_welfare[i] + 1e-10 if i < len(perfect_stats.total_social_welfare) else perfect_stats.total_social_welfare[-1]
    imperfect_welfare = imperfect_stats.total_social_welfare[i] if i < len(imperfect_stats.total_social_welfare) else imperfect_stats.total_social_welfare[-1]
    costs.append((perfect_welfare - imperfect_welfare) / perfect_welfare * 100)
plt.plot(list(range(1, max(len(perfect_stats.total_social_welfare), len(imperfect_stats.total_social_welfare)))), costs)
plt.show()

# %%
plt.figure()
plt.title("Average Consumer Utility By Iteration")
plt.plot(perfect_stats.average_consumer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_consumer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Producer Utility By Iteration")
plt.plot(perfect_stats.average_producer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_producer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Influencer Utility By Iteration")
plt.plot(perfect_stats.average_influencer_utility, label="Perfect Information")
plt.plot(imperfect_stats.average_influencer_utility, label="Imperfect Information")
plt.xlabel("Iteration")
plt.ylabel("Utility")
plt.legend()
plt.show()

# %%
perfect_influencer = perfect_market.influencers[0]
perfect_influencer_stats = perfect_stats.influencer_stats[perfect_influencer.index]
imperfect_influencer = imperfect_market.influencers[0]
imperfect_influencer_stats = imperfect_stats.influencer_stats[imperfect_influencer.index]

perfect_producers = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producers = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.figure()
plt.title("Influencer Ending Following Rate By Producer Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Following Rate (%)")
plt.xlim(topics[0][0], topics[0][1])

plt.plot([p.agent.main_interest for p in perfect_producers], [perfect_influencer_stats.following_rates[-1][p.agent.index] / perfect_influencer.attention_bound * 100 for p in perfect_producers], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producers], [imperfect_influencer_stats.following_rates[-1][p.agent.index] / imperfect_influencer.attention_bound * 100 for p in imperfect_producers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

plt.figure()
plt.title("Influencer Ending Following Rate By Producer Topic Produced")
plt.xlabel("Producer Topic Produced")
plt.ylabel("Following Rate (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_producers = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.topics[-1])
imperfect_producers = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.topics[-1])

plt.plot([p.topics[-1] for p in perfect_producers], [perfect_influencer_stats.following_rates[-1][p.agent.index] / perfect_influencer.attention_bound * 100 for p in perfect_producers], label="Perfect Information", marker='o')
plt.plot([p.topics[-1] for p in imperfect_producers], [imperfect_influencer_stats.following_rates[-1][p.agent.index] / imperfect_influencer.attention_bound * 100 for p in imperfect_producers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
perfect_influencer_stats = list(perfect_stats.influencer_stats.values())[0]
perfect_influencer = perfect_market.influencers[0]
imperfect_influencer_stats = list(imperfect_stats.influencer_stats.values())[0]
imperfect_influencer = imperfect_market.influencers[0]

perfect_consumers: list[ConsumerProducer] = sorted(perfect_market.consumers, key=lambda x: x.main_interest)
imperfect_consumers: list[ConsumerProducer] = sorted(imperfect_market.consumers, key=lambda x: x.main_interest)

plt.figure()
plt.title("Influencer Ending Followers by Consumer Main Interest")
plt.xlabel("Consumer Main Interest")
plt.ylabel("Followers (% of consumer bound)")
plt.xlim(topics[0][0], topics[0][1])

plt.plot([c.main_interest for c in perfect_consumers], [perfect_stats.consumer_stats[c.index].following_rates[-1][perfect_influencer.index] / c.attention_bound * 100 for c in perfect_consumers], label="Perfect Information", marker='o')
plt.plot([c.main_interest for c in imperfect_consumers], [imperfect_stats.consumer_stats[c.index].following_rates[-1][imperfect_influencer.index] / c.attention_bound * 100 for c in imperfect_consumers], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Ending Topic Produced by Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Topic Produced")
plt.xlim(topics[0][0], topics[0][1])
plt.ylim(topics[0][0], topics[0][1])

perfect_producer_stats = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producer_stats = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([p.agent.main_interest for p in perfect_producer_stats], [p.topics[-1] for p in perfect_producer_stats], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producer_stats], [p.topics[-1] for p in imperfect_producer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Topic Standard Deviation by Iteration")
plt.xlabel("Iteration")
plt.ylabel("Standard Deviation")
plt.plot(perfect_stats.producer_topic_standard_deviation, label="Perfect Information")
plt.plot(imperfect_stats.producer_topic_standard_deviation, label="Imperfect Information")

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Producer Topic Distance From Main Interest By Main Interest")
plt.xlabel("Producer Main Interest")
plt.ylabel("Ending Topic Distance From Main Interest (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_producer_stats = sorted(perfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_producer_stats = sorted(imperfect_stats.producer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([p.agent.main_interest for p in perfect_producer_stats], [np.linalg.norm(p.topics[-1] - p.agent.main_interest) / (np.linalg.norm(p.agent.main_interest) + 1e-3) * 100 for p in perfect_producer_stats], label="Perfect Information", marker='o')
plt.plot([p.agent.main_interest for p in imperfect_producer_stats], [np.linalg.norm(p.topics[-1] - p.agent.main_interest) / (np.linalg.norm(p.agent.main_interest) + 1e-3) * 100 for p in imperfect_producer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Average Following Rate by Main Interest Closeness")
plt.xlabel("Main Interest Closeness")
plt.ylabel("Average Following Rate (%)")

perfect_rates_by_closeness = dict()
imperfect_rates_by_closeness = dict()

for consumer_stat in perfect_stats.consumer_stats.values():
    for producer in perfect_market.producers:
        if producer == consumer_stat.agent:
            continue
        closeness = np.linalg.norm(producer.main_interest - consumer_stat.agent.main_interest)
        if closeness not in perfect_rates_by_closeness:
            perfect_rates_by_closeness[closeness] = []
        perfect_rates_by_closeness[closeness].append(consumer_stat.following_rates[-1][producer.index] / consumer_stat.agent.attention_bound * 100)
perfect_rates_by_closeness = {k: np.mean(v) for k, v in perfect_rates_by_closeness.items()}
plt.plot(list(perfect_rates_by_closeness.keys()), list(perfect_rates_by_closeness.values()), label="Perfect Information")

for consumer_stat in imperfect_stats.consumer_stats.values():
    for producer in imperfect_market.producers:
        if producer == consumer_stat.agent:
            continue
        closeness = np.linalg.norm(producer.main_interest - consumer_stat.agent.main_interest)
        if closeness not in imperfect_rates_by_closeness:
            imperfect_rates_by_closeness[closeness] = []
        imperfect_rates_by_closeness[closeness].append(consumer_stat.following_rates[-1][producer.index] / consumer_stat.agent.attention_bound * 100)
imperfect_rates_by_closeness = {k: np.mean(v) for k, v in imperfect_rates_by_closeness.items()}
plt.plot(list(imperfect_rates_by_closeness.keys()), list(imperfect_rates_by_closeness.values()), label="Imperfect Information")

plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Percentage of Producers Followed by Main Interest")
plt.xlabel("Main Interest")
plt.ylabel("Percentage of Producers Followed (%)")
plt.xlim(topics[0][0], topics[0][1])

perfect_consumer_stats = sorted(perfect_stats.consumer_stats.values(), key=lambda x: x.agent.main_interest)
imperfect_consumer_stats = sorted(imperfect_stats.consumer_stats.values(), key=lambda x: x.agent.main_interest)

plt.plot([c.agent.main_interest for c in perfect_consumer_stats], [len([p for p in perfect_market.producers if c.following_rates[-1][p.index] > 0]) / len(perfect_market.producers) * 100 for c in perfect_consumer_stats], label="Perfect Information", marker='o')
plt.plot([c.agent.main_interest for c in imperfect_consumer_stats], [len([p for p in imperfect_market.producers if c.following_rates[-1][p.index] > 0]) / len(imperfect_market.producers) * 100 for c in imperfect_consumer_stats], label="Imperfect Information", marker='o')

plt.legend()
plt.show()

# %%
perfect_producers = sorted(perfect_market.producers, key=lambda x: x.main_interest)
imperfect_producers = sorted(imperfect_market.producers, key=lambda x: x.main_interest)

for consumer in perfect_market.consumers:
    perfect_stat = perfect_stats.consumer_stats[consumer.index]
    imperfect_stat = imperfect_stats.consumer_stats[consumer.index]

    plt.figure()
    plt.title(f"Following rates for consumer {consumer.index}")
    plt.xlabel("Producer Main Interest")
    plt.ylabel("Following Rate (%)")
    plt.xlim(topics[0][0] - 0.05, topics[0][1] + 0.05)

    plt.plot([p.main_interest for p in perfect_producers if p != perfect_stat.agent], [perfect_stat.following_rates[-1][p.index] / consumer.attention_bound * 100 for p in perfect_producers if p != perfect_stat.agent], label="Perfect Information", marker='o', color='blue')
    plt.plot([p.main_interest for p in imperfect_producers if p != imperfect_stat.agent], [imperfect_stat.following_rates[-1][p.index] / consumer.attention_bound * 100 for p in imperfect_producers if p != imperfect_stat.agent], label="Imperfect Information", marker='o', color='orange')

    # vertical line at consumer main interest
    plt.axvline(x=consumer.main_interest, color='r', linestyle='--', label="Consumer Main Interest")

    # horizontal line at influencer following rate
    plt.axhline(y=perfect_stat.following_rates[-1][-2] / consumer.attention_bound * 100, color='blue', linestyle='--', label="Influencer (Perfect)")
    plt.axhline(y=imperfect_stat.following_rates[-1][-2] / consumer.attention_bound * 100, color='orange', linestyle='--', label="Influencer (Imperfect)")

    # horizontal line at external following rate
    plt.axhline(y=perfect_stat.following_rates[-1][-1] / consumer.attention_bound * 100, color='blue', linestyle='-.', label="External (Perfect)")
    plt.axhline(y=imperfect_stat.following_rates[-1][-1] / consumer.attention_bound * 100, color='orange', linestyle='-.', label="External (Imperfect)")

    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()
