# %%
from agents import ConsumerProducer, Influencer, ImperfectConsumerProducer
from content_market import ContentMarket
import numpy as np
from stats import TestStats

# %%
num_influencers = 1
num_consumer_producers = 10

production_rate = 1
external_production_rate = 1

topics = [[-1, 1]]
topics = np.array(topics)

# %%
content_market = ContentMarket(topics, production_rate, external_production_rate)

# %%
from util import exponential_decay, inverse_decay, tanh_decay

# %%
agent_colors = dict()

for i in range(num_consumer_producers):
    cons_func = lambda x: inverse_decay(x, 1, 2)
    prod_func = lambda x: inverse_decay(x, 1, 2)
    #consumer_producer = ConsumerProducer(prod_func, cons_func, 20, 3, 1, init_following_rates_method='equal')
    consumer_producer = ImperfectConsumerProducer(prod_func, cons_func, 10, 3, 1, init_following_rates_method='equal')
    content_market.add_agent(consumer_producer)

    color = np.random.rand(3,)
    agent_colors[consumer_producer.index] = color

for i in range(num_influencers):
    influencer = Influencer(20, 1, init_following_rates_method='equal')
    content_market.add_agent(influencer)

    color = np.random.rand(3,)
    agent_colors[influencer.index] = color

# %%
import matplotlib.pyplot as plt
import visualize

# %%
content_market.finalize(method='even')

# %%
visualize.plot_topic_distribution_histogram("Consumer/Producer Topic Distribution", content_market.consumers, -1, 1)

# %%
visualize.plot_consumer_topic_interest_distributions("Consumer Topic Interest Distributions", content_market.consumers, -1, 1, agent_colors)

# %%
visualize.plot_producer_topic_probability_distributions("Producer Topic Probability Distributions", content_market.producers, -1, 1, agent_colors)

# %%
stats: TestStats = content_market.optimize(100)
# Out:
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.16384379199007526s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 8.952846166968811s): nit=4, nfev=78, njev=39.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 33.202969459001906s): nit=1, nfev=104, njev=52.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 20.901264250045642s): nit=2, nfev=130, njev=65.
# Optimizing producer 4
# Optimization succeeded (overall 3.2467285419697873s): nit=2, nfev=42, njev=21.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 14.712205292016733s): nit=1, nfev=110, njev=55.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 11.331311541958712s): nit=1, nfev=54, njev=27.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 15.844162916997448s): nit=1, nfev=68, njev=34.
# Optimizing producer 8
# Optimization succeeded (overall 3.4625965420273133s): nit=2, nfev=50, njev=25.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 12.422984207980335s): nit=1, nfev=62, njev=31.
# Iteration 0 / 100 done in 124.77110016602091 seconds.
# Total Social Welfare: 58.9188985770613
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.15194816602161154s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 13.234834417002276s): nit=1, nfev=56, njev=28.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 18.566396332986187s): nit=1, nfev=86, njev=43.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 13.120732082985342s): nit=1, nfev=66, njev=33.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 11.979643041966483s): nit=1, nfev=60, njev=30.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 14.453692791983485s): nit=1, nfev=88, njev=44.
# Optimizing producer 6
# Optimization succeeded (overall 9.872852750006132s): nit=9, nfev=136, njev=68.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 16.182119000004604s): nit=4, nfev=138, njev=69.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 10.891969832999166s): nit=1, nfev=52, njev=26.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 6.749885375029407s): nit=1, nfev=54, njev=27.
# Iteration 1 / 100 done in 115.5239613330341 seconds.
# Total Social Welfare: 58.94590850445506
# Consumer rate change: 0.14887891104253304
# Consumer utility change: 0.0004582153960621458%
# Influencer rate change: 0.12790200243964298
# Influencer utility change: 0.005273294191600525%
# Producer topic change: 0.018787092526074793
# Producer utility change: -4.125180405456728e-05%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall

# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 15.512450291018467s): nit=1, nfev=94, njev=47.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 13.234532208996825s): nit=1, nfev=84, njev=42.
# Optimizing producer 7
# Optimization succeeded (overall 2.20305787504185s): nit=4, nfev=42, njev=21.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 7.77020425000228s): nit=1, nfev=70, njev=35.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 10.266884749988094s): nit=1, nfev=86, njev=43.
# Iteration 5 / 100 done in 87.27565137500642 seconds.
# Total Social Welfare: 59.301754096218815
# Consumer rate change: 0.011490097917032016
# Consumer utility change: -8.416746577281602e-05%
# Influencer rate change: 0.0326037579643653
# Influencer utility change: 0.0006029341277009396%
# Producer topic change: 0.003955739994621771
# Producer utility change: 1.5580340408859175e-05%
# Converged. Optimization took 638.186651750002 seconds.

# %%
visualize.plot_agent_utility_by_iteration("Consumer Utility by Iteration", content_market.consumers, agent_colors, stats.consumer_stats, stats.average_consumer_utility)

# %%
visualize.plot_agent_utility_change_by_iteration("Consumer Utility Change by Iteration", content_market.consumers, agent_colors, stats.consumer_stats, stats.average_consumer_utility_change)

# %%
visualize.plot_agent_utility_by_iteration("Producer Utility by Iteration", content_market.producers, agent_colors, stats.producer_stats, stats.average_producer_utility)

# %%
visualize.plot_agent_utility_change_by_iteration("Producer Utility Change by Iteration", content_market.producers, agent_colors, stats.producer_stats, stats.average_producer_utility_change)

# %%
visualize.plot_agent_utility_by_iteration("Influencer Utility by Iteration", content_market.influencers, agent_colors, stats.influencer_stats, stats.average_influencer_utility)

# %%
visualize.plot_following_rate_change_by_iteration("Consumer Average following rate change by Iteration", content_market.consumers, agent_colors, stats.consumer_stats, stats.average_consumer_rate_change)

# %%
visualize.plot_following_rate_change_by_iteration("Influencer Average following rate change by Iteration", content_market.influencers, agent_colors, stats.influencer_stats, stats.average_influencer_rate_change)

# %%
visualize.plot_following_rates_by_iteration(content_market.influencers, content_market.producers, agent_colors, stats.influencer_stats)

# %%
visualize.plot_agent_following_rates(content_market.influencers, stats.influencer_stats, agent_colors)

# %%
visualize.plot_follows_by_iteration(content_market.influencers, content_market.consumers, agent_colors, stats.consumer_stats)

# %%
visualize.plot_producer_topic_produced_by_iteration("Producer Topic Produced by Iteration", content_market.producers, content_market.consumers, agent_colors, stats.producer_stats, False)

# %%
visualize.plot_value_by_iteration("Producer Topic Standard Deviation by Iteration", stats, "producer_topic_standard_deviation", "Topic Standard Deviation")

# %%
visualize.plot_producer_topic_change_by_iteration("Producer Average topic change by Iteration", content_market.producers, agent_colors, stats.producer_stats, stats.average_producer_topic_change)

# %%
visualize.plot_total_social_welfare_by_iteration("Total Social Welfare by Iteration", stats)

# %%
visualize.plot_following_rate_by_main_interest_closeness("Following rate by Main Interest Closeness", content_market.consumers, content_market.producers, agent_colors, stats.consumer_stats)

# %%
visualize.plot_producer_topic_distance_from_main_interest_by_iteration("Producer topic distance from main interest by Iteration", content_market.producers, agent_colors, stats.producer_stats, stats.average_producer_topic_distance_from_main_interest)

# %%
visualize.plot_value_by_agent_by_iteration("Number of Producers Followed by Iteration", stats.consumer_stats, "num_producers_followed", "Number of Producers Followed", stats.average_consumer_num_producers_followed)

# %%
num_prods_by_main_interest_magnitude = []
topic_center = np.array([(bound[0] + bound[1]) / 2 for bound in content_market.topics_bounds])

for consumer in content_market.consumers:
    main_interest_mag = np.linalg.norm(consumer.main_interest - topic_center)
    num_prods_by_main_interest_magnitude.append((main_interest_mag, stats.consumer_stats[consumer.index].num_producers_followed[-1]))

num_prods_by_main_interest_magnitude.sort(key=lambda x: x[0])
plt.figure()
plt.plot([x[0] for x in num_prods_by_main_interest_magnitude], [x[1] for x in num_prods_by_main_interest_magnitude])
plt.xlabel("Main Interest Distance from Topic Space Center")
plt.ylabel("Number of Producers Followed")
plt.title("Number of Producers Followed by Main Interest Distance from Topic Space Center")
plt.show()

# %%
visualize.plot_following_rates_by_iteration(content_market.consumers, sorted(list(set(content_market.producers + content_market.influencers)), key=lambda x: x.index), agent_colors, stats.consumer_stats)

# %%
import importlib
importlib.reload(visualize)
# Out:
# <module 'visualize' from '/Users/gabeguralnick/git/content-market-experiment/visualize.py'>

# %%
visualize.visualize_influencer(content_market, stats.influencer_stats[content_market.influencers[0].index], agent_colors)

# %%
visualize.visualize_market(content_market, stats, agent_colors)
# Out:
# {0: (1.0, 0), 1: (0.7777777777777777, 0), 2: (0.5555555555555554, 0), 3: (0.33333333333333326, 0), 4: (0.11111111111111116, 0), 5: (-0.11111111111111116, 0), 6: (-0.33333333333333337, 0), 7: (-0.5555555555555556, 0), 8: (-0.7777777777777778, 0), 9: (-1.0, 0), 10: (0, 1), 'External': (1, 1)}

# %%
for consumer in content_market.consumers:
    visualize.visualize_consumer(content_market, stats.consumer_stats[consumer.index], agent_colors)

# %%
visualize.plot_agent_following_rates(content_market.consumers, stats.consumer_stats, agent_colors)

# %%
stats.to_dict()
# Out:
# {'num_iterations': 6,
#  'total_consumer_utility': [0,
#   58.9188985770613,
#   58.94590850445506,
#   59.17071622125283,
#   59.25765886161686,
#   59.30674537541865,
#   59.301754096218815],
#  'total_producer_utility': [0,
#   6.051864485466221,
#   6.051614845023903,
#   6.055631401542521,
#   6.056152482739422,
#   6.056981555199644,
#   6.057075926660269],
#  'total_influencer_utility': [0,
#   24.755845064424012,
#   24.887081974519425,
#   25.094511162042174,
#   25.15821764897338,
#   25.213840692090614,
#   25.229052149243874],
#  'total_social_welfare': [0,
#   58.9188985770613,
#   58.94590850445506,
#   59.17071622125283,
#   59.25765886161686,
#   59.30674537541865,
#   59.301754096218815],
#  'average_consumer_rate_change': [0,
#   3.060439374085625,
#   0.14887891104253304,
#   0.06702596057866311,
#   0.04527463790974976,
#   0.030693883348558187,
#   0.011490097917032016],
#  'average_producer_topic_change': [0,
#   0.09096305391169662,
#   0.018787092526074793,
#   0.033557222499494034,
#   0.013861331538571154,
#   0.010876533686014116,
#   0.003955739994621771],
#  'average_influencer_rate_change': [0,
#   0.533756448590611,
#   0.12790200243964298,
#   0.01100456514919667,
+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000000101,
#     9.999999999999998,
#     9.999999999999998,
#     10.0,
#     10.0,
#     10.0],
#    'rate_change': [0,
#     2.8342012207288634,
#     0.0838001980420692,
#     0.11848811859082918,
#     0.12434062246661706,
#     0.037600749900564626,
#     0.04092310012700509]},
#   4: {'utilities': [0,
#     6.405922676470941,
#     6.465059648595817,
#     6.507568303999077,
#     6.500870631967308,
#     6.5158865927559,
#     6.520036713045372],
#    'utility_change': [0,
#     6.405922676470941,
#     0.05913697212487623,
#     0.04250865540325943,
#     -0.006697672031768853,
#     0.015015960788592686,
#     0.004150120289471815],
#    'optimization_times': [0.04816583398496732,
#     0.020743833971209824,
#     0.010131541988812387,
#     0.010626707982737571,
#     0.0112163340090774,
#     0.010281333001330495],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.        ,
#            0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([0.        , 0.62257896, 0.8443802 , 0.97843769, 0.        ,
#            0.97843774, 0.8443802 , 0.62257902, 0.        , 0.        ,
#            2.77611516, 2.33309104]),
#     array([2.85647116e-16, 7.49872607e-01, 8.66727754e-01, 9.45048842e-01,
#            0.00000000e+00, 9.23948467e-01, 7.87123987e-01, 6.97479166e-01,
#            0.00000000e+00, 7.37541767e-17, 2.77269310e+00, 2.25710608e+00]),
#     array([0.00000000e+00, 7.38102967e-01, 8.55401807e-01, 9.35669157e-01,
#            0.00000000e+00, 9.22949341e-01, 8.46955134e-01, 6.85231442e-01,
#            1.20473494e-16, 0.00000000e+00, 2.77247421e+00, 2.24321594e+00]),
#     array([5.43235789e-16, 7.29591459e-01, 8.54383695e-01, 9.34818478e-01,
#            0.00000000e+00, 9.21842814e-01, 8.44976587e-01, 6.82117286e-01,
#            2.67410811e-16, 6.03595322e-17, 2.79406306e+00, 2.23820662e+00]),
#     array([1.34216864e-16, 7.24529906e-01, 8.56896273e-01, 9.37284321e-01,
#            0.00000000e+00, 9.24377039e-01, 8.34108065e-01, 6.84901751e-01,
#            0.00000000e+00, 1.15764532e-16, 2.79699415e+00, 2.24090849e+00]),
#     array([0.        , 0.72303085, 0.85561828, 0.93595584, 0.        ,
#            0.92304757, 0.83338161, 0.68401224, 0.        , 0.        ,
#            2.80472444, 2.24022917])],
#    'attention_used': [9.999999999999998,
#     10.000000000000426,
#     10.0,
#     9.999999999999998,
#     9.999999999999998,
#     10.000000000000002,
#     9.999999999999998],
#    'rate_change': [0,
#     2.859207203384955,
#     0.1883101523919864,
#     0.06541050977700183,
#     0.02408764969497141,
#     0.013645676193579528,
#     0.008303644042885146]},
#   5: {'utilities': [0,
#     6.422133175576264,
#     6.438383530575745,
#     6.476081387253787,
#     6.484506107395141,
#     6.498051321505153,
#     6.501806163674169],
#    'utility_change': [0,
#     6.422133175576264,
#     0.0162503549994808,
#     0.03769785667804193,
#     0.008424720141354314,
#     0.013545214110012083,
#     0.0037548421690152267],
#    'optimization_times': [0.0488403330091387,
#     0.02352745900861919,
#     0.010604957991745323,
#     0.010697457997594029,
#     0.010334999999031425,
#     0.010684625012800097],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0
+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000010026,
#     10.0,
#     9.999999999999998,
#     10.0,
#     10.000000000000002,
#     10.0],
#    'rate_change': [0,
#     3.049145989626474,
#     0.09200368275929646,
#     0.07479149990528702,
#     0.0234060634993966,
#     0.032423097087613095,
#     0.0054178848400724235]},
#   8: {'utilities': [0,
#     5.69662378794313,
#     5.611301396537842,
#     5.539857137736158,
#     5.576790021370328,
#     5.582695805178914,
#     5.583800929930822],
#    'utility_change': [0,
#     5.69662378794313,
#     -0.0853223914052883,
#     -0.0714442588016837,
#     0.03693288363416958,
#     0.005905783808586307,
#     0.0011051247519082708],
#    'optimization_times': [0.02770133299054578,
#     0.020593790977727622,
#     0.020278083044104278,
#     0.01991220802301541,
#     0.01664329197956249,
#     0.0035476249759085476],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091, 0.90909091, 0.        , 0.90909091,
#            0.90909091, 0.90909091]),
#     array([2.33062303e-14, 2.59197110e-14, 3.81129723e-14, 6.01664433e-14,
#            5.33720472e-01, 8.28592985e-01, 1.01725457e+00, 1.14953341e+00,
#            0.00000000e+00, 1.14953365e+00, 2.72127983e+00, 2.60008508e+00]),
#     array([2.81134846e-16, 0.00000000e+00, 6.86342255e-17, 8.88890641e-17,
#            5.43678848e-01, 8.33384663e-01, 1.02274698e+00, 1.05124516e+00,
#            0.00000000e+00, 1.17368205e+00, 2.76471348e+00, 2.61054882e+00]),
#     array([3.83892978e-17, 0.00000000e+00, 3.16890864e-17, 0.00000000e+00,
#            5.87477704e-01, 8.22853717e-01, 9.25510300e-01, 1.06804318e+00,
#            0.00000000e+00, 1.19211498e+00, 2.76325578e+00, 2.64074434e+00]),
#     array([0.        , 0.        , 0.        , 0.        , 0.61352226,
#            0.83781199, 0.93895577, 1.08287692, 0.        , 1.1015297 ,
#            2.76289454, 2.66240881]),
#     array([1.66979253e-16, 0.00000000e+00, 0.00000000e+00, 4.44160852e-17,
#            6.42483266e-01, 8.25655571e-01, 9.62275423e-01, 1.07139007e+00,
#            0.00000000e+00, 1.09593998e+00, 2.75824902e+00, 2.64400667e+00]),
#     array([1.66979253e-16, 0.00000000e+00, 0.00000000e+00, 4.44160852e-17,
#            6.42483266e-01, 8.25655571e-01, 9.62275423e-01, 1.07139007e+00,
#            0.00000000e+00, 1.09593998e+00, 2.75824902e+00, 2.64400667e+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000000021,
#     10.0,
#     10.0,
#     9.999999999999998,
#     10.000000000000002,
#     10.000000000000002],
#    'rate_change': [0,
#     3.1183301080118406,
#     0.11131933016632653,
#     0.11410544556655494,
#     0.09989024781404265,
#     0.04531817741299277,
#     0.0]},
#   9: {'utilities': [0,
#     5.2660671215705985,
#     5.174848517402065,
#     5.182192512262862,
#     5.203366876501175,
#     5.207522564337171,
#     5.2081674931755035],
#    'utility_change': [0,
#     5.2660671215705985,
#     -0.09121860416853345,
#     0.007343994860796954,
#     0.02117436423831265,
#     0.004155687835996069,
#     0.0006449288383327811],
#    'optimization_times': [0.047953291970770806,
#     0.021631166979204863,
#     0.019885416026227176,
#     0.003162833978421986,
#     0.009288209024816751,
#     0.003176167025230825],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.        ,
#            0.90909091, 0.90909091]),
#     array([3.28092441e-14, 2.61643171e-14, 3.28650419e-14, 2.73791868e-13,
#            2.75708961e-12, 7.89181619e-01, 1.00851225e+00, 1.19780729e+00,
#            1.33624582e+00, 0.00000000e+00, 2.76782716e+00, 2.90042586e+00]),
#     array([0.00000000e+00, 1.26104418e-16, 9.59672995e-17, 0.00000000e+00,
#            0.00000000e+00, 8.06873040e-01, 1.02444551e+00, 1.06820410e+00,
#            1.35360628e+00, 0.00000000e+00, 2.81790671e+00, 2.92896436e+00]),
#     array([0.00000000e+00, 0.00000000e+00, 2.65911527e-17, 0.00000000e+00,
#            0.00000000e+00, 8.04817735e-01, 9.19556972e-01, 1.09433017e+00,
#            1.38367184e+00, 0.00000000e+00, 2.81990798e+00, 2.97771531e+00]),
#     array([0.00000000e+00, 0.00000000e+00, 2.65911527e-17, 0.00000000e+00,
#            0.00000000e+00, 8.04817735e-01, 9.19556972e-01, 1.09433017e+00,
#            1.38367184e+00, 0.00000000e+00, 2.81990798e+00, 2.97771531e+00]),
#     array([0.00000000e+00, 4.63414982e-17, 0.00000000e+00, 0.00000000e+00,
#            0.00000000e+00, 7.96628386e-01, 9.49669107e-01, 1.08700873e+00,
#            1.37563884e+00, 0.00000000e+00, 2.82111485e+00, 2.96994010e+00]),
#     array([0.00000000e+00, 4.63414982e-17, 0.00000000e+00, 0.00000000e+00,
#            0.00000000e+00, 7.96628386e-01, 9.49669107e-01, 1.08700873e+00,
#            1.37563884e+00, 0.00000000e+00, 2.82111485e+00, 2.96994010e+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000000183,
#     10.0,
#     10.0,
#     10.0,
#     10.0,
#     10.0],
#    'rate_change': [0,
#     3.4413119653023725,
#     0.14487110263005334,
#     0.12236420913187848,
#     0.0,
#     0.03396835562749335,
#     0.0]}},
#  'producer_stats': {0: {'utilities': [0,
#     0.5537802677443192,
#     0.5533563739486488,
#     0.5688790876892393,
#     0.5718607509450495,
#     0.5773169045157238,
#     0.5779107482740501],
#    'utility_change': [0,
#     0.5537802677443192,
#     -0.00042389379567042695,
#     0.015522713740590555,
#     0.002981663255810174,
#     0.005456153570674305,
#     0.0005938437583262735],
#    'optimization_times': [0.16384379199007526,
#     0.15194816602161154,
#     2.007012208981905,
#     5.775919542007614,
#     2.5899540829705074,
#     8.89891141699627],
#    'topics': [array([1.]),
#     array([1.]),
#     array([1.]),
#     array([0.87847871]),
#     array([0.84318415]),
#     array([0.73450299]),
#     array([0.69498356])],
#    'topic_change': [0,
#     0.0,
#     0.0,
#     0.12152128646749571,
#     0.03529456361661598,
#     0.10868115817864188,
#     0.03951943343043396],
#    'topic_distance': [0.0,
#     0.0,
#     0.0,
#     0.12152128646749571,
#     0.1568158500841117,
#     0.2654970082627536,
#     0.30501644169318753]},
#   1: {'utilities': [0,
#     0.6008171803439792,
#     0.6005274674363388,
#     0.599092795102261,
#     0.598953221160139,
#     0.5984229291899413,
#     0.5983655233685943],
#    'utility_change': [0,
#     0.6008171803439792,
#     -0.0002897129076404603,
#     -0.0014346723340777912,
#     -0.00013957394212193996,
#     -0.000530291970197716,
#     -5.7405821347056296e-05],
#    'optimization_times': [8.952846166968811,
#     13.234834417002276,
#     7.347863041970413,
#     13.485216999950353,
#     9.535920833004639,
#     4.7983907500165515],
#    'topics': [array([0.77777778]),
#     array([0.48957957]),
#     array([0.48957957]),
#     array([0.51667646]),
#     array([0.5483742]),
#     array([0.54837889]),
#     array([0.54837889])],
#    'topic_change': [0,
#     0.288198209654781,
#     8.987255384340642e-14,
#     0.027096889463239404,
#     0.031697740839832456,
#     4.695064535931159e-06,
#     4.440892098500626e-16],
#    'topic_distance': [0.0,
#     0.288198209654781,
#     0.28819820965487086,
#     0.26110132019163146,
#     0.229403579351799,
#     0.22939888428726307,
#     0.22939888428726263]},
#   2: {'utilities': [0,
#     0.6153791428463856,
#     0.6151145211031388,
#     0.613179295934026,
#     0.6128262031721644,
#     0.6123223724520612,
#     0.6122660185414921],
#    'utility_change': [0,
#     0.6153791428463856,
#     -0.00026462174324681786,
#     -0.0019352251691128197,
#     -0.0003530927618615731,
#     -0.0005038307201031822,
#     -5.6353910569129084e-05],
#    'optimization_times': [33.202969459001906,
#     18.566396332986187,
#     9.590428332972806,
#     10.761765250004828,
#     10.486336541944183,
#     8.645882042008452],
#    'topics': [array([0.55555556]),
#     array([0.39866174]),
#     array([0.39866169]),
#     array([0.39866169]),
#     array([0.39867128]),
#     array([0.3986213]),
#     array([0.39858821])],
#    'topic_change': [0,
#     0.15689381498502392,
#     4.6208750048570835e-08,
#     8.892886427247504e-14,
#     9.58100703635223e-06,
#     4.997606471085492e-05,
#     3.3090187179174446e-05],
#    'topic_distance': [0.0,
#     0.15689381498502392,
#     0.15689386119377396,
#     0.1568938611938629,
#     0.15688428018682654,
#     0.1569342562515374,
#     0.15696734643871657]},
#   3: {'utilities': [0,
#     0.623692836296319,
#     0.6239832466283985,
#     0.6221638148423929,
#     0.6218427920412662,
#     0.6213522767292438,
#     0.6213041075130085],
#    'utility_change': [0,
#     0.623692836296319,
#     0.00029041033207954925,
#     -0.001819431786005632,
#     -0.00032102280112666914,
#     -0.0004905153120224881,
#     -4.816921623529424e-05],
#    'optimization_times': [20.901264250045642,
#     13.120732082985342,
#     8.224648125004023,
#     11.174641666992102,
#     13.919584291987121,
#     12.578268708020914],
#    'topics': [array([0.33333333]),
#     array([0.18656642]),
#     array([0.22002572]),
#     array([0.22002551]),
#     array([0.22003521]),
#     array([0.22003354]),
#     array([0.22003357])],
#    'topic_change': [0,
#     0.1467669123079958,
#     0.03345930389689464,
#     2.1337743180693813e-07,
#     9.70070514394461e-06,
#     1.6683802433192785e-06,
#     2.3505686508329404e-08],
#    'topic_distance': [0.0,
#     0.1467669123079958,
#     0.11330760841110116,
#     0.11330782178853296,
#     0.11329812108338902,
#     0.11329978946363234,
#     0.11329976595794583]},
#   4: {'utilities': [0,
#     0.6283244796761478,
#     0.6281659498249685,
#     0.6263453121109712,
#     0.6261257445461356,
#     0.6256364240559872,
#     0.6255583346971768],
#    'utility_change': [0,
#     0.6283244796761478,
#     -0.00015852985117925655,
#     -0.0018206377139973196,
#     -0.00021956756483565432,
#     -0.0004893204901483816,
#     -7.808935881037371e-05],
#    'optimization_times': [3.2467285419697873,
#     11.979643041966483,
#     14.127531666017603,
#     10.459196708980016,
#     15.223687625024468,
#     3.226194457965903],
#    'topics': [array([0.11111111]),
#     array([0.11111199]),
#     array([0.11111265]),
#     array([0.11111265]),
#     array([0.08012827]),
#     array([0.08012344]),
#     array([0.08012242])],
#    'topic_change': [0,
#     8.78698189127336e-07,
#     6.574246530360872e-07,
#     1.9888955621327753e-09,
#     0.030984380639931697,
#     4.829059394056978e-06,
#     1.0207411465512628e-06],
#    'topic_distance': [0.0,
#     8.78698189127336e-07,
#     1.5361228421634232e-06,
#     1.538111737725556e-06,
#     0.03098284252819397,
#     0.030987671587588028,
#     0.03098869232873458]},
#   5: {'utilities': [0,
#     0.6283245312002137,
#     0.6282291980205088,
#     0.6263963176650383,
#     0.6260017511382487,
#     0.6255091215680915,
#     0.6254334841586836],
#    'utility_change': [0,
#     0.6283245312002137,
#     -9.533317970489286e-05,
#     -0.0018328803554704676,
#     -0.00039456652678959703,
#     -0.0004926295701572769,
#     -7.563740940785824e-05],
#    'optimization_times': [14.712205292016733,
#     14.453692791983485,
#     12.651576291013043,
#     14.094670417020097,
#     2.6654028340126388,
#     15.512450291018467],
#    'topics': [array([-0.11111111]),
#     array([-0.11111155]),
#     array([-0.08175912]),
#     array([-0.0817599]),
#     array([-0.0817603]),
#     array([-0.08175997]),
#     array([-0.0817614])],
#    'topic_change': [0,
#     4.397861348981458e-07,
#     0.029352426932413717,
#     7.806191620746139e-07,
#     3.9111858332607774e-07,
#     3.2630211115047825e-07,
#     1.433161874953015e-06],
#    'topic_distance': [0.0,
#     4.397861348981458e-07,
#     0.02935198714627882,
#     0.029351206527116744,
#     0.029350815408533418,
#     0.029351141710644568,
#     0.029349708548769615]},
#   6: {'utilities': [0,
#     0.6225520844211331,
#     0.6239255326359687,
#     0.6220642480300195,
#     0.6219750040588786,
#     0.6214902355529992,
#     0.6214265281330783],
#    'utility_change': [0,
#     0.6225520844211331,
#     0.0013734482148356486,
#     -0.0018612846059492538,
#     -8.924397114085103e-05,
#     -0.0004847685058794182,
#     -6.370741992089979e-05],
#    'optimization_times': [11.331311541958712,
#     9.872852750006132,
#     8.534560625033919,
#     19.075859375006985,
#     10.344110667007044,
#     13.234532208996825],
#    'topics': [array([-0.33333333]),
#     array([-0.33333333]),
#     array([-0.20828508]),
#     array([-0.20828518]),
#     array([-0.24101499]),
#     array([-0.24101461]),
#     array([-0.24101373])],
#    'topic_change': [0,
#     3.4466607345962075e-10,
#     0.12504825233313538,
#     9.443239706863338e-08,
#     0.03272981524223498,
#     3.8521623180187703e-07,
#     8.767981654056456e-07],
#    'topic_distance': [0.0,
#     3.4466607345962075e-10,
#     0.1250482519884693,
#     0.12504815755607224,
#     0.09231834231383726,
#     0.09231872753006906,
#     0.09231960432823447]},
#   7: {'utilities': [0,
#     0.6153705962046239,
#     0.6151419912895237,
#     0.6132201359002182,
#     0.612861966059387,
#     0.6123515470847576,
#     0.6122960821376537],
#    'utility_change': [0,
#     0.6153705962046239,
#     -0.00022860491510012793,
#     -0.00192185538930556,
#     -0.0003581698408311462,
#     -0.0005104189746294452,
#     -5.5464947103844864e-05],
#    'optimization_times': [15.844162916997448,
#     16.182119000004604,
#     8.093499165959656,
#     8.676145458011888,
#     7.546448541979771,
#     2.20305787504185],
#    'topics': [array([-0.55555556]),
#     array([-0.40477646]),
#     array([-0.40478645]),
#     array([-0.40479016]),
#     array([-0.40479016]),
#     array([-0.40477146]),
#     array([-0.40477262])],
#    'topic_change': [0,
#     0.15077909397186134,
#     9.989180426106525e-06,
#     3.71401154192208e-06,
#     2.0786705690056806e-10,
#     1.8703345248116676e-05,
#     1.1551128387687903e-06],
#    'topic_distance': [0.0,
#     0.15077909397186134,
#     0.15076910479143524,
#     0.15076539077989332,
#     0.15076539057202626,
#     0.15078409391727438,
#     0.1507829388044356]},
#   8: {'utilities': [0,
#     0.5878973849789921,
#     0.5877303729439923,
#     0.5856240621237035,
#     0.5852527166581655,
#     0.5847085398637852,
#     0.5846744577778726],
#    'utility_change': [0,
#     0.5878973849789921,
#     -0.00016701203499980277,
#     -0.0021063108202887815,
#     -0.00037134546553807546,
#     -0.0005441767943802356,
#     -3.40820859126012e-05],
#    'optimization_times': [3.4625965420273133,
#     10.891969832999166,
#     16.124887208046857,
#     10.464943625032902,
#     9.307355750002898,
#     7.77020425000228],
#    'topics': [array([-0.77777778]),
#     array([-0.77777801]),
#     array([-0.77777826]),
#     array([-0.7777786]),
#     array([-0.7777786]),
#     array([-0.7777786]),
#     array([-0.7777788])],
#    'topic_change': [0,
#     2.3561315520836956e-07,
#     2.492843851342741e-07,
#     3.342802977757131e-07,
#     1.1102230246251565e-15,
#     3.729953568232247e-09,
#     1.9677866647249687e-07],
#    'topic_distance': [0.0,
#     2.3561315520836956e-07,
#     4.848975403426437e-07,
#     8.191778381183568e-07,
#     8.191778392285798e-07,
#     8.22907792796812e-07,
#     1.019686459269309e-06]},
#   9: {'utilities': [0,
#     0.575725981754107,
#     0.575440191192415,
#     0.5786663321446505,
#     0.5784523329599874,
#     0.5778712041870542,
#     0.577840642058658],
#    'utility_change': [0,
#     0.575725981754107,
#     -0.0002857905616920897,
#     0.003226140952235501,
#     -0.00021399918466302736,
#     -0.0005811287729332593,
#     -3.056212839613881e-05],
#    'optimization_times': [12.422984207980335,
#     6.749885375029407,
#     9.94885579199763,
#     15.661495249951258,
#     8.701711541973054,
#     10.266884749988094],
#    'topics': [array([-1.]),
#     array([-0.83300905]),
#     array([-0.83300905]),
#     array([-0.64606014]),
#     array([-0.65394728]),
#     array([-0.65394369]),
#     array([-0.65394352])],
#    'topic_change': [0,
#     0.16699095375515893,
#     0.0,
#     0.1869489103543901,
#     0.007887142008464632,
#     3.5915190704782773e-06,
#     1.7023022547135724e-07],
#    'topic_distance': [0.0,
#     0.16699095375515893,
#     0.16699095375515893,
#     0.35393986410954903,
#     0.3460527221010844,
#     0.3460563136201549,
#     0.34605648385038035]}},
#  'influencer_stats': {10: {'utilities': [0,
#     24.755845064424012,
#     24.887081974519425,
#     25.094511162042174,
#     25.15821764897338,
#     25.213840692090614,
#     25.229052149243874],
#    'utility_change': [0,
#     24.755845064424012,
#     0.1312369100954136,
#     0.20742918752274875,
#     0.06370648693120629,
#     0.055623043117233095,
#     0.01521145715326],
#    'optimization_times': [0.09508016600739211,
#     0.11173029203200713,
#     0.05797649995656684,
#     0.04992220795247704,
#     0.04986054199980572,
#     0.048776542011182755],
#    'following_rates': [array([2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 0.]),
#     array([1.72011302, 1.90796445, 2.04847538, 2.13956861, 2.18387807,
#            2.18387896, 2.13956905, 2.04847548, 1.9079641 , 1.72011288,
#            0.        , 0.        ]),
#     array([1.69208374, 1.96284498, 2.05966135, 2.1182075 , 2.15193265,
#            2.15193303, 2.11002522, 2.05960243, 1.88251998, 1.81118912,
#            0.        , 0.        ]),
#     array([1.68989413, 1.9609885 , 2.05783837, 2.12029826, 2.15076475,
#            2.15123059, 2.11988251, 2.05802749, 1.88151362, 1.80956179,
#            0.        , 0.        ]),
#     array([1.77277503, 1.95183353, 2.04458046, 2.10725128, 2.13742148,
#            2.13779357, 2.10654084, 2.04485891, 1.8688891 , 1.82805581,
#            0.        , 0.        ]),
#     array([1.78935767, 1.95094627, 2.04217541, 2.10496198, 2.13582087,
#            2.13491779, 2.10590436, 2.04241881, 1.86667627, 1.82682058,
#            0.        , 0.        ]),
#     array([1.82028695, 1.94758073, 2.03875102, 2.10147129, 2.13226041,
#            2.1313356 , 2.10245216, 2.03894907, 1.86344046, 1.82347232,
#            0.        , 0.        ])],
#    'attention_used': [20.0,
#     19.999999999999993,
#     19.999999999999996,
#     20.00000000000001,
#     20.0,
#     19.999999999999996,
#     19.999999999999993],
#    'rate_change': [0,
#     0.533756448590611,
#     0.12790200243964298,
#     0.01100456514919667,
#     0.09225220472589975,
#     0.017618459831898622,
#     0.0326037579643653]}},
#  'optimization_time': 638.186651750002,
#  'optimization_times': [124.77110016602091,
#   115.5239613330341,
#   96.87196154199773,
#   119.8084227090003,
#   90.4836615830427,
#   87.27565137500642]}

# %%
sorted([c.main_interest for c in content_market.consumers])
# Out:
# [array([-1.]),
#  array([-0.77777778]),
#  array([-0.55555556]),
#  array([-0.33333333]),
#  array([-0.11111111]),
#  array([0.11111111]),
#  array([0.33333333]),
#  array([0.55555556]),
#  array([0.77777778]),
#  array([1.])]
