# %%
import numpy as np
from test import test
from util import exponential_decay, inverse_decay, tanh_decay
import matplotlib.pyplot as plt
import visualize
from stats import *

# %%
topics = np.array([[-1, 1]])

# %%
varied_param = 'init_topic_produced_method'
varied_param_legend_label = 'Producer Topic Produced Initialization'
varied_param_x_label = 'Producer Topic Produced Initialization'

# %%
num_influencers = 1
num_agents = 10

methods = ['main', 'center', 'opposite', 'farthest', 'random']
varied_param_values = [1, 2, 3, 4, 5]

# %%
test_imperfect = True

# %%
perfect_info_stats, imperfect_info_stats = test(
    topics=topics,
    varied_param=varied_param,
    num_influencers=num_influencers,
    num_agents=num_agents,
    producer_topic_interest_func=None,
    consumer_topic_interest_func=None,
    agent_topic_interest_func=lambda x: inverse_decay(x, 0.75, 2),
    consumer_attention_bound=20,
    consumer_external_interest_prob=3,
    consumer_delay_sensitivity=1,
    delay_sensitivity=None,
    influencer_attention_bound=40,
    influencer_delay_sensitivity=1,
    init_following_rates_method='equal',
    init_interest_method='even',
    init_topic_produced_method=methods,
    production_rate=1,
    external_production_rate=1,
    use_imperfect_information=test_imperfect,
    basinhop=True
)
# Out:
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4258899169508368s): nit=100, nfev=1324, njev=662.
# Optimizing producer 1
# Optimization succeeded (overall 0.43598670803476125s): nit=100, nfev=1290, njev=645.
# Optimizing producer 2
# Optimization succeeded (overall 0.44952212495263666s): nit=100, nfev=1256, njev=628.
# Optimizing producer 3
# Optimization succeeded (overall 0.39823349996004254s): nit=100, nfev=1226, njev=613.
# Optimizing producer 4
# Optimization succeeded (overall 0.3988994579995051s): nit=100, nfev=1182, njev=591.
# Optimizing producer 5
# Optimization succeeded (overall 0.3884903339203447s): nit=100, nfev=1168, njev=584.
# Optimizing producer 6
# Optimization succeeded (overall 0.38959633302874863s): nit=100, nfev=1220, njev=610.
# Optimizing producer 7
# Optimization succeeded (overall 0.4163592499680817s): nit=100, nfev=1232, njev=616.
# Optimizing producer 8
# Optimization succeeded (overall 0.41749216604512185s): nit=100, nfev=1282, njev=641.
# Optimizing producer 9
# Optimization succeeded (overall 0.4762525410624221s): nit=100, nfev=1330, njev=665.
# Iteration 0 / 100 done in 75.6161381250713 seconds.
# Total Social Welfare: 84.47010135132442
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.42967541597317904s): nit=100, nfev=1296, njev=648.
# Optimizing producer 1
# Optimization succeeded (overall 0.4145547499647364s): nit=100, nfev=1234, njev=617.
# Optimizing producer 2
# Optimization succeeded (overall 0.4055809999117628s): nit=100, nfev=1216, njev=608.
# Optimizing producer 3
# Optimization succeeded (overall 0.4305243749404326s): nit=100, nfev=1230, njev=615.
# Optimizing producer 4
# Optimization succeeded (overall 0.39520662499126047s): nit=100, nfev=1212, njev=606.
# Optimizing producer 5
# Optimization succeeded (overall 0.41544862498994917s): nit=100, nfev=1164, njev=582.
# Optimizing producer 6
# Optimization succeeded (overall 0.453074041986838s): nit=100, nfev=1244, njev=622.
# Optimizing producer 7
# Optimization succeeded (overall 0.4288590409560129s): nit=100, nfev=1248, njev=624.
# Optimizing producer 8
# Optimization succeeded (overall 0.3910995000042021s): nit=100, nfev=1240, njev=620.
# Optimizing producer 9
# Optimization succeeded (overall 0.4183531659655273s): nit=100, nfev=1320, njev=660.
# Iteration 1 / 100 done in 63.824638165999204 seconds.
# Total Social Welfare: 84.56106494268738
# Consumer rate change: 0.25772212731403926
# Consumer utility change: 0.0010757146999917802%
# Influencer rate change: 0.3218723053631974
# Influencer utility change: 0.0006305459043634237%
# Producer topic change: 0.02371362250794431
# Producer utility change: 0.002833732934455937%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.5213579999981448s): nit=100, nfev=1254, njev=627.
# Optimizing producer 1
# Optimization succeeded (overall 0.5453575839055702s): nit=100, nfev=1254, njev=627.
# Optimizing producer 2
# Optimization succeeded (overall 0.40673549997154623s): nit=100, nfev=1234, njev=617.
# Optimizing producer 3
# Optimization succeeded (overall 0.3985222909832373s): nit=100, nfev=1208, njev=604.
# Optimizing producer 4
# Optimization succeeded (overall 0.3822050829185173s): nit=100, nfev=1184, njev=592.
# Optimizing producer 5
# Optimization succeeded (overall 0.5013386670034379s): nit=100, nfev=1178, njev=589.
# Optimizing producer 6
# Optimization succeeded (overall 0.5095388749614358s): nit=100, nfev=1228, njev=614.
# Optimizing producer 7
# Optimization succeeded (overall 0.4144817909691483s): nit=100, nfev=1248, njev=624.
# Optimizing producer 8
# Optimization succeeded (overall 0.3578375419601798s): nit=100, nfev=1248, njev=624.
# Optimizing producer 9
# Optimization succeeded (overall 0.3517522079637274s): nit=100, nfev=1242, njev=621.
# Iteration 2 / 100 done in 66.46623516699765 seconds.
# Total Social Welfare: 84.56260073665237
# Consumer rate change: 0.04728301157432346
# Consumer utility change: 1.8161619557389673e-05%
# Influencer rate change: 0.00509810046877816
# Influencer utility change: 0.00012695457658190272%
# Producer topic change: 0.0023270504550880087
# Producer utility change: 5.513386109393262e-05%
# Converged. Optimization took 205.9478204579791 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4375864170724526s): nit=100, nfev=1324, njev=662.
# Optimizing producer 1
# Optimization succeeded (overall 0.5054973750375211s): nit=100, nfev=1280, njev=640.
# Optimizing producer 2
# Optimization succeeded (overall 0.3973387919832021s): nit=100, nfev=1244, njev=622.
# Optimizing producer 3
# Optimization succeeded (overall 0.4093010419746861s): nit=100, nfev=1236, njev=618.
# Optimizing producer 4
# Optimization succeeded (overall 0.39182316698133945s): nit=100, nfev=1216, njev=608.
# Optimizing producer 5
# Optimization succeeded (overall 0.4258792499313131s): nit=100, nfev=1172, njev=586.
# Optimizing producer 6
# Optimization succeeded (overall 0.4850379580166191s): nit=100, nfev=1226, njev=613.
# Optimizing producer 7
# Optimization succeeded (overall 0.4285854999907315s): nit=100, nfev=1242, njev=621.
# Optimizing producer 8
# Optimization succeeded (overall 0.4663276249775663s): nit=100, nfev=1284, njev=642.
# Optimizing producer 9
# Optimization succeeded (overall 0.49994125007651746s): nit=100, nfev=1306, njev=653.
# Iteration 0 / 100 done in 71.2898291250458 seconds.
# Total Social Welfare: 82.2257864455235
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.5017953750211746s): nit=100, nfev=1248, njev=624.
# Optimizing producer 1
# Optimization succeeded (overall 0.4276759159984067s): nit=100, nfev=1272, njev=636.
# Optimizing producer 2
# Optimization succeeded (overall 0.48794812499545515s): nit=100, nfev=1244, njev=622.
# Optimizing producer 3
# Optimization succeeded (overall 0.5372352080885321s): nit=100, nfev=1270, njev=635.
# Optimizing producer 4
# Optimization succeeded (overall 0.3979889169568196s): nit=100, nfev=1194, njev=597.
# Optimizing producer 5
# Optimization succeeded (overall 0.3887531249783933s): nit=100, nfev=1166, njev=583.
# Optimizing producer 6
# Optimization succeeded (overall 0.4525147919775918s): nit=100, nfev=1226, njev=613.
# Optimizing producer 7
# Optimization succeeded (overall 0.4986210410716012s): nit=100, nfev=1238, njev=619.
# Optimizing producer 8
# Optimization succeeded (overall 0.4849253749707714s): nit=100, nfev=1266, njev=633.
# Optimizing producer 9
# Optimization succeeded (overall 0.4179730420000851s): nit=100, nfev=1246, njev=623.
# Iteration 1 / 100 done in 71.69715350004844 seconds.
# Total Social Welfare: 84.42358556539493
# Consumer rate change: 1.7874609324680613
# Consumer utility change: 0.02603299593143956%
# Influencer rate change: 1.2414896897190526
# Influencer utility change: 0.0072160495655171335%
# Producer topic change: 0.006464895910662685
# Producer utility change: 0.04462017051421382%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.41137950005941093s): nit=100, nfev=1302, njev=651.
# Optimizing producer 1
# Optimization succeeded (overall 0.4156168750487268s): nit=100, nfev=1252, njev=626.
# Optimizing producer 2
# Optimization succeeded (overall 0.43721808306872845s): nit=100, nfev=1246, njev=623.
# Optimizing producer 3
# Optimization succeeded (overall 0.426188041921705s): nit=100, nfev=1212, njev=606.
# Optimizing producer 4
# Optimization succeeded (overall 0.3878245420055464s): nit=100, nfev=1186, njev=593.
# Optimizing producer 5
# Optimization succeeded (overall 0.39485437504481524s): nit=100, nfev=1168, njev=584.
# Optimizing producer 6
# Optimization succeeded (overall 0.41755824990104884s): nit=100, nfev=1224, njev=612.
# Optimizing producer 7
# Optimization succeeded (overall 0.4182382080471143s): nit=100, nfev=1236, njev=618.
# Optimizing producer 8
# Optimization succeeded (overall 0.3933591659879312s): nit=100, nfev=1230, njev=615.
# Optimizing producer 9
# Optimization succeeded (overall 0.46658441703766584s): nit=100, nfev=1314, njev=657.
# Iteration 2 / 100 done in 65.28186149999965 seconds.
# Total Social Welfare: 84.49836917514077
# Consumer rate change: 0.10936818458980083
# Consumer utility change: 0.0008850301091673581%
# Influencer rate change: 0.006003279353036406
# Influencer utility change: 0.00038594434925797995%
# Producer topic change: 0.024293437427629145
# Producer utility change: 0.0009170144337926907%
# Converged. Optimization took 208.30633045802824 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4402322079986334s): nit=100, nfev=1334, njev=667.
# Optimizing producer 1
# Optimization succeeded (overall 0.4027397909667343s): nit=100, nfev=1268, njev=634.
# Optimizing producer 2
# Optimization succeeded (overall 0.42213412502314895s): nit=100, nfev=1250, njev=625.
# Optimizing producer 3
# Optimization succeeded (overall 0.40452379104681313s): nit=100, nfev=1240, njev=620.
# Optimizing producer 4
# Optimization succeeded (overall 0.464424500009045s): nit=100, nfev=1178, njev=589.
# Optimizing producer 5
# Optimization succeeded (overall 0.41279704100452363s): nit=100, nfev=1190, njev=595.
# Optimizing producer 6
# Optimization succeeded (overall 0.49397474993020296s): nit=100, nfev=1238, njev=619.
# Optimizing producer 7
# Optimization succeeded (overall 0.5561735410010442s): nit=100, nfev=1232, njev=616.
# Optimizing producer 8
# Optimization succeeded (overall 0.6011889999499545s): nit=100, nfev=1234, njev=617.
# Optimizing producer 9
# Optimization succeeded (overall 0.6229947910178453s): nit=100, nfev=1320, njev=660.
# Iteration 0 / 100 done in 85.49392058397643 seconds.
# Total Social Welfare: 76.87795160277575
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.34103837504517287s): nit=100, nfev=1192, njev=596.
# Optimizing producer 1
# Optimization succeeded (overall 0.4256670830072835s): nit=100, nfev=1296, njev=648.
# Optimizing producer 2
# Optimization succeeded (overall 0.39061524998396635s): nit=100, nfev=1244, njev=622.
# Optimizing producer 3
# Optimization succeeded (overall 0.39897437498439103s): nit=100, nfev=1216, njev=608.
# Optimizing producer 4
# Optimization succeeded (overall 0.4383870830060914s): nit=100, nfev=1196, njev=598.
# Optimizing producer 5
# Optimization succeeded (overall 0.3987616669619456s): nit=100, nfev=1190, njev=595.
# Optimizing producer 6
# Optimization succeeded (overall 0.4140065829269588s): nit=100, nfev=1260, njev=630.
# Optimizing producer 7
# Optimization succeeded (overall 0.3953475001035258s): nit=100, nfev=1234, njev=617.
# Optimizing producer 8
# Optimization succeeded (overall 0.40755920903757215s): nit=100, nfev=1276, njev=638.
# Optimizing producer 9
# Optimization succeeded (overall 0.3169440000783652s): nit=100, nfev=1214, njev=607.
# Iteration 1 / 100 done in 71.2586502910126 seconds.
# Total Social Welfare: 84.27111593208352
# Consumer rate change: 3.7055568077977092
# Consumer utility change: 0.08773069360988624%
# Influencer rate change: 4.363635753812941
# Influencer utility change: 0.025545020610443475%
# Producer topic change: 0.024956348948484298
# Producer utility change: 0.15125237540870617%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.37856408301740885s): nit=100, nfev=1320, njev=660.
# Optimizing producer 1
# Optimization succeeded (overall 0.38961183407809585s): nit=100, nfev=1250, njev=625.
# Optimizing producer 2
# Optimization succeeded (overall 0.4145704169059172s): nit=100, nfev=1258, njev=629.
# Optimizing producer 3
# Optimization succeeded (overall 0.47321870899759233s): nit=100, nfev=1248, njev=624.
# Optimizing producer 4
# Optimization succeeded (overall 0.4041919580195099s): nit=100, nfev=1188, njev=594.
# Optimizing producer 5
# Optimization succeeded (overall 0.4207638750085607s): nit=100, nfev=1188, njev=594.
# Optimizing producer 6
# Optimization succeeded (overall 0.4484187919879332s): nit=100, nfev=1220, njev=610.
# Optimizing producer 7
# Optimization succeeded (overall 0.41438145795837045s): nit=100, nfev=1248, njev=624.
# Optimizing producer 8
# Optimization succeeded (overall 0.38778983405791223s): nit=100, nfev=1232, njev=616.
# Optimizing producer 9
# Optimization succeeded (overall 0.3642899999395013s): nit=100, nfev=1252, njev=626.
# Iteration 2 / 100 done in 65.12149383302312 seconds.
# Total Social Welfare: 84.50623385682604
# Consumer rate change: 0.11535132254154445
# Consumer utility change: 0.0027822550620148884%
# Influencer rate change: 0.026330457221446245
# Influencer utility change: 0.003830880976842983%
# Producer topic change: 0.043517805422093284
# Producer utility change: 0.004104747767048781%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.41104658390395343s): nit=100, nfev=1288, njev=644.
# Optimizing producer 1
# Optimization succeeded (overall 0.42889512493275106s): nit=100, nfev=1220, njev=610.
# Optimizing producer 2
# Optimization succeeded (overall 0.4368963750312105s): nit=100, nfev=1254, njev=627.
# Optimizing producer 3
# Optimization succeeded (overall 0.43329900002572685s): nit=100, nfev=1250, njev=625.
# Optimizing producer 4
# Optimization succeeded (overall 0.42152808408718556s): nit=100, nfev=1194, njev=597.
# Optimizing producer 5
# Optimization succeeded (overall 0.37882783298846334s): nit=100, nfev=1156, njev=578.
# Optimizing producer 6
# Optimization succeeded (overall 0.40831774997059256s): nit=100, nfev=1216, njev=608.
# Optimizing producer 7
# Optimization succeeded (overall 0.4062012080103159s): nit=100, nfev=1244, njev=622.
# Optimizing producer 8
# Optimization succeeded (overall 0.36638608400244266s): nit=100, nfev=1238, njev=619.
# Optimizing producer 9
# Optimization succeeded (overall 0.3530827920185402s): nit=100, nfev=1234, njev=617.
# Iteration 3 / 100 done in 64.42411208304111 seconds.
# Total Social Welfare: 84.52794053995518
# Consumer rate change: 0.29580303363735133
# Consumer utility change: 0.0002567988812041991%
# Influencer rate change: 0.020450897089624425
# Influencer utility change: 0.001565278487084414%
# Producer topic change: 0.0010068014666779507
# Producer utility change: -0.00030834442329461643%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4301067920168862s): nit=100, nfev=1322, njev=661.
# Optimizing producer 1
# Optimization succeeded (overall 0.37006637500599027s): nit=100, nfev=1242, njev=621.
# Optimizing producer 2
# Optimization succeeded (overall 0.3939844999695197s): nit=100, nfev=1258, njev=629.
# Optimizing producer 3
# Optimization succeeded (overall 0.3994984580203891s): nit=100, nfev=1222, njev=611.
# Optimizing producer 4
# Optimization succeeded (overall 0.4030596249504015s): nit=100, nfev=1168, njev=584.
# Optimizing producer 5
# Optimization succeeded (overall 0.42207254201639444s): nit=100, nfev=1198, njev=599.
# Optimizing producer 6
# Optimization succeeded (overall 0.4071926249889657s): nit=100, nfev=1240, njev=620.
# Optimizing producer 7
# Optimization succeeded (overall 0.4360699999378994s): nit=100, nfev=1246, njev=623.
# Optimizing producer 8
# Optimization succeeded (overall 0.40725649998057634s): nit=100, nfev=1262, njev=631.
# Optimizing producer 9
# Optimization succeeded (overall 0.3966182499425486s): nit=100, nfev=1252, njev=626.
# Iteration 4 / 100 done in 63.53465945809148 seconds.
# Total Social Welfare: 84.54057027181372
# Consumer rate change: 0.2012522645427801
# Consumer utility change: 0.00014939253809165496%
# Influencer rate change: 0.0037284908956082426
# Influencer utility change: 0.0015494936052198002%
# Producer topic change: 0.0027853452801414394
# Producer utility change: -0.0006186307347866957%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.3880526670254767s): nit=100, nfev=1298, njev=649.
# Optimizing producer 1
# Optimization succeeded (overall 0.362120584002696s): nit=100, nfev=1234, njev=617.
# Optimizing producer 2
# Optimization succeeded (overall 0.42686666699592024s): nit=100, nfev=1250, njev=625.
# Optimizing producer 3
# Optimization succeeded (overall 0.43117070803418756s): nit=100, nfev=1222, njev=611.
# Optimizing producer 4
# Optimization succeeded (overall 0.4113390001002699s): nit=100, nfev=1178, njev=589.
# Optimizing producer 5
# Optimization succeeded (overall 0.38182058406528085s): nit=100, nfev=1176, njev=588.
# Optimizing producer 6
# Optimization succeeded (overall 0.4437306660693139s): nit=100, nfev=1240, njev=620.
# Optimizing producer 7
# Optimization succeeded (overall 0.42417266708798707s): nit=100, nfev=1224, njev=612.
# Optimizing producer 8
# Optimization succeeded (overall 0.39441404095850885s): nit=100, nfev=1274, njev=637.
# Optimizing producer 9
# Optimization succeeded (overall 0.379407792002894s): nit=100, nfev=1276, njev=638.
# Iteration 5 / 100 done in 64.81057308299933 seconds.
# Total Social Welfare: 84.55637210048025
# Consumer rate change: 0.10275494450823612
# Consumer utility change: 0.00018687919556149352%
# Influencer rate change: 0.00418317525650112
# Influencer utility change: 0.0008155071327758565%
# Producer topic change: 0.001283026856458172
# Producer utility change: -0.00011743020015714606%
# Converged. Optimization took 414.7203547920799 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4302784580504522s): nit=100, nfev=1324, njev=662.
# Optimizing producer 1
# Optimization succeeded (overall 0.4172302499646321s): nit=100, nfev=1268, njev=634.
# Optimizing producer 2
# Optimization succeeded (overall 0.4303186669712886s): nit=100, nfev=1264, njev=632.
# Optimizing producer 3
# Optimization succeeded (overall 0.43875349999871105s): nit=100, nfev=1234, njev=617.
# Optimizing producer 4
# Optimization succeeded (overall 0.37672650010790676s): nit=100, nfev=1204, njev=602.
# Optimizing producer 5
# Optimization succeeded (overall 0.38442933303304017s): nit=100, nfev=1200, njev=600.
# Optimizing producer 6
# Optimization succeeded (overall 0.4101259580347687s): nit=100, nfev=1222, njev=611.
# Optimizing producer 7
# Optimization succeeded (overall 0.4477212500059977s): nit=100, nfev=1260, njev=630.
# Optimizing producer 8
# Optimization succeeded (overall 0.44698949996382s): nit=100, nfev=1262, njev=631.
# Optimizing producer 9
# Optimization succeeded (overall 0.46739083307329565s): nit=100, nfev=1348, njev=674.
# Iteration 0 / 100 done in 79.33107858302537 seconds.
# Total Social Welfare: 73.39036967033371
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.6360349589958787s): nit=100, nfev=1322, njev=661.
# Optimizing producer 1
# Optimization succeeded (overall 0.5208312920294702s): nit=100, nfev=1268, njev=634.
# Optimizing producer 2
# Optimization succeeded (overall 0.4335208749398589s): nit=100, nfev=1244, njev=622.
# Optimizing producer 3
# Optimization succeeded (overall 0.46986258402466774s): nit=100, nfev=1216, njev=608.
# Optimizing producer 4
# Optimization succeeded (overall 0.7577962080249563s): nit=100, nfev=1236, njev=618.
# Optimizing producer 5
# Optimization succeeded (overall 0.5074064999353141s): nit=100, nfev=1224, njev=612.
# Optimizing producer 6
# Optimization succeeded (overall 0.3829969170037657s): nit=100, nfev=1234, njev=617.
# Optimizing producer 7
# Optimization succeeded (overall 0.3994743749499321s): nit=100, nfev=1244, njev=622.
# Optimizing producer 8
# Optimization succeeded (overall 0.46666333300527185s): nit=100, nfev=1294, njev=647.
# Optimizing producer 9
# Optimization succeeded (overall 0.5227645420236513s): nit=100, nfev=1288, njev=644.
# Iteration 1 / 100 done in 75.9033365000505 seconds.
# Total Social Welfare: 83.94535557697421
# Consumer rate change: 5.623824674778348
# Consumer utility change: 0.12573637429647097%
# Influencer rate change: 1.495474905733099
# Influencer utility change: 0.02697427825935752%
# Producer topic change: 0.05724159913308704
# Producer utility change: 0.22590573697089503%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4327611660119146s): nit=100, nfev=1318, njev=659.
# Optimizing producer 1
# Optimization succeeded (overall 0.46768837491981685s): nit=100, nfev=1244, njev=622.
# Optimizing producer 2
# Optimization succeeded (overall 0.5559935829369351s): nit=100, nfev=1260, njev=630.
# Optimizing producer 3
# Optimization succeeded (overall 0.49060470797121525s): nit=100, nfev=1236, njev=618.
# Optimizing producer 4
# Optimization succeeded (overall 0.43844116700347513s): nit=100, nfev=1176, njev=588.
# Optimizing producer 5
# Optimization succeeded (overall 0.46114129200577736s): nit=100, nfev=1162, njev=581.
# Optimizing producer 6
# Optimization succeeded (overall 0.4743168329587206s): nit=100, nfev=1258, njev=629.
# Optimizing producer 7
# Optimization succeeded (overall 0.519272124976851s): nit=100, nfev=1234, njev=617.
# Optimizing producer 8
# Optimization succeeded (overall 0.5126145409885794s): nit=100, nfev=1248, njev=624.
# Optimizing producer 9
# Optimization succeeded (overall 0.9261792079778388s): nit=100, nfev=1254, njev=627.
# Iteration 2 / 100 done in 73.36361704196315 seconds.
# Total Social Welfare: 84.49551993052054
# Consumer rate change: 0.3396431741607102
# Consumer utility change: 0.006511165194167388%
# Influencer rate change: 0.025806307207974128
# Influencer utility change: 0.0054807435727766175%
# Producer topic change: 0.07580670228659095
# Producer utility change: 0.008723237424684817%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4444379999767989s): nit=100, nfev=1244, njev=622.
# Optimizing producer 1
# Optimization succeeded (overall 0.5390939170029014s): nit=100, nfev=1258, njev=629.
# Optimizing producer 2
# Optimization succeeded (overall 0.4586196660529822s): nit=100, nfev=1234, njev=617.
# Optimizing producer 3
# Optimization succeeded (overall 0.5235685840016231s): nit=100, nfev=1192, njev=596.
# Optimizing producer 4
# Optimization succeeded (overall 0.4711200420279056s): nit=100, nfev=1152, njev=576.
# Optimizing producer 5
# Optimization succeeded (overall 0.4945962500059977s): nit=100, nfev=1178, njev=589.
# Optimizing producer 6
# Optimization succeeded (overall 0.5273666660068557s): nit=100, nfev=1216, njev=608.
# Optimizing producer 7
# Optimization succeeded (overall 0.5276247089495882s): nit=100, nfev=1232, njev=616.
# Optimizing producer 8
# Optimization succeeded (overall 0.5397812079172581s): nit=100, nfev=1242, njev=621.
# Optimizing producer 9
# Optimization succeeded (overall 0.47056695795618s): nit=100, nfev=1246, njev=623.
# Iteration 3 / 100 done in 76.67349391698372 seconds.
# Total Social Welfare: 84.52932402533492
# Consumer rate change: 0.2784223875823519
# Consumer utility change: 0.0003999096314213657%
# Influencer rate change: 0.025231655162865498
# Influencer utility change: 0.0010833910000440932%
# Producer topic change: 0.004015341781927884
# Producer utility change: 0.00042581079394116335%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.3747236670460552s): nit=100, nfev=1238, njev=619.
# Optimizing producer 1
# Optimization succeeded (overall 0.40425895794760436s): nit=100, nfev=1238, njev=619.
# Optimizing producer 2
# Optimization succeeded (overall 0.403462249902077s): nit=100, nfev=1242, njev=621.
# Optimizing producer 3
# Optimization succeeded (overall 0.4011026250664145s): nit=100, nfev=1204, njev=602.
# Optimizing producer 4
# Optimization succeeded (overall 0.3763447079109028s): nit=100, nfev=1138, njev=569.
# Optimizing producer 5
# Optimization succeeded (overall 0.4127390410285443s): nit=100, nfev=1174, njev=587.
# Optimizing producer 6
# Optimization succeeded (overall 0.4185901250457391s): nit=100, nfev=1206, njev=603.
# Optimizing producer 7
# Optimization succeeded (overall 0.3978061249945313s): nit=100, nfev=1244, njev=622.
# Optimizing producer 8
# Optimization succeeded (overall 0.384138916968368s): nit=100, nfev=1240, njev=620.
# Optimizing producer 9
# Optimization succeeded (overall 0.36978333396837115s): nit=100, nfev=1266, njev=633.
# Iteration 4 / 100 done in 66.01383175002411 seconds.
# Total Social Welfare: 84.53104045300896
# Consumer rate change: 0.012468755270414508
# Consumer utility change: 2.0305292136436816e-05%
# Influencer rate change: 0.0034698270944470704
# Influencer utility change: -0.00017868253735558567%
# Producer topic change: 0.0035753325252535955
# Producer utility change: 5.3739932131939955e-05%
# Converged. Optimization took 371.3399746250361 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4589887090260163s): nit=100, nfev=1318, njev=659.
# Optimizing producer 1
# Optimization succeeded (overall 0.43620987504255027s): nit=100, nfev=1288, njev=644.
# Optimizing producer 2
# Optimization succeeded (overall 0.41001250001136214s): nit=100, nfev=1256, njev=628.
# Optimizing producer 3
# Optimization succeeded (overall 0.4231177499750629s): nit=100, nfev=1214, njev=607.
# Optimizing producer 4
# Optimization succeeded (overall 0.40300024999305606s): nit=100, nfev=1170, njev=585.
# Optimizing producer 5
# Optimization succeeded (overall 0.4176144580123946s): nit=100, nfev=1166, njev=583.
# Optimizing producer 6
# Optimization succeeded (overall 0.3977147500263527s): nit=100, nfev=1238, njev=619.
# Optimizing producer 7
# Optimization succeeded (overall 0.42288779199589044s): nit=100, nfev=1224, njev=612.
# Optimizing producer 8
# Optimization succeeded (overall 0.41216241708025336s): nit=100, nfev=1268, njev=634.
# Optimizing producer 9
# Optimization succeeded (overall 0.43690945801790804s): nit=100, nfev=1314, njev=657.
# Iteration 0 / 100 done in 70.71149137499742 seconds.
# Total Social Welfare: 80.8465475919965
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.40102612506598234s): nit=100, nfev=1332, njev=666.
# Optimizing producer 1
# Optimization succeeded (overall 0.4010072499513626s): nit=100, nfev=1284, njev=642.
# Optimizing producer 2
# Optimization succeeded (overall 0.412051499937661s): nit=100, nfev=1228, njev=614.
# Optimizing producer 3
# Optimization succeeded (overall 0.4116633329540491s): nit=100, nfev=1262, njev=631.
# Optimizing producer 4
# Optimization succeeded (overall 0.3870754580711946s): nit=100, nfev=1194, njev=597.
# Optimizing producer 5
# Optimization succeeded (overall 0.33669308305252343s): nit=100, nfev=1188, njev=594.
# Optimizing producer 6
# Optimization succeeded (overall 0.3989553329301998s): nit=100, nfev=1198, njev=599.
# Optimizing producer 7
# Optimization succeeded (overall 0.49507091694977134s): nit=100, nfev=1232, njev=616.
# Optimizing producer 8
# Optimization succeeded (overall 0.5472305829171091s): nit=100, nfev=1250, njev=625.
# Optimizing producer 9
# Optimization succeeded (overall 0.4488884590100497s): nit=100, nfev=1314, njev=657.
# Iteration 1 / 100 done in 64.3516401250381 seconds.
# Total Social Welfare: 84.27583699000057
# Consumer rate change: 2.5670965771625736
# Consumer utility change: 0.0406912480916503%
# Influencer rate change: 2.275426875602322
# Influencer utility change: 0.007725372676699656%
# Producer topic change: 0.031153225522917816
# Producer utility change: 0.07141014541312829%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.4140307499328628s): nit=100, nfev=1314, njev=657.
# Optimizing producer 1
# Optimization succeeded (overall 0.5472197500057518s): nit=100, nfev=1244, njev=622.
# Optimizing producer 2
# Optimization succeeded (overall 0.47638741694390774s): nit=100, nfev=1230, njev=615.
# Optimizing producer 3
# Optimization succeeded (overall 0.41864183300640434s): nit=100, nfev=1218, njev=609.
# Optimizing producer 4
# Optimization succeeded (overall 0.3878270420245826s): nit=100, nfev=1198, njev=599.
# Optimizing producer 5
# Optimization succeeded (overall 0.3902504169382155s): nit=100, nfev=1170, njev=585.
# Optimizing producer 6
# Optimization succeeded (overall 0.45651429204735905s): nit=100, nfev=1210, njev=605.
# Optimizing producer 7
# Optimization succeeded (overall 0.4140097909839824s): nit=100, nfev=1268, njev=634.
# Optimizing producer 8
# Optimization succeeded (overall 0.40089416701812297s): nit=100, nfev=1232, njev=616.
# Optimizing producer 9
# Optimization succeeded (overall 0.4216220829403028s): nit=100, nfev=1300, njev=650.
# Iteration 2 / 100 done in 63.85100975004025 seconds.
# Total Social Welfare: 84.50794722393667
# Consumer rate change: 0.2989953831613293
# Consumer utility change: 0.0027466080303069247%
# Influencer rate change: 0.02797169741166716
# Influencer utility change: 0.0043813310238783485%
# Producer topic change: 0.03751661409446651
# Producer utility change: 0.003005315233517862%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.37928212503902614s): nit=100, nfev=1254, njev=627.
# Optimizing producer 1
# Optimization succeeded (overall 0.46054770797491074s): nit=100, nfev=1246, njev=623.
# Optimizing producer 2
# Optimization succeeded (overall 0.42931533290538937s): nit=100, nfev=1264, njev=632.
# Optimizing producer 3
# Optimization succeeded (overall 0.45843808294739574s): nit=100, nfev=1236, njev=618.
# Optimizing producer 4
# Optimization succeeded (overall 0.5581037920201197s): nit=100, nfev=1190, njev=595.
# Optimizing producer 5
# Optimization succeeded (overall 0.5401712500024587s): nit=100, nfev=1192, njev=596.
# Optimizing producer 6
# Optimization succeeded (overall 0.5358609999530017s): nit=100, nfev=1220, njev=610.
# Optimizing producer 7
# Optimization succeeded (overall 0.5324399580713362s): nit=100, nfev=1264, njev=632.
# Optimizing producer 8
# Optimization succeeded (overall 0.5398635420715436s): nit=100, nfev=1232, njev=616.
# Optimizing producer 9
# Optimization succeeded (overall 0.5426310419570655s): nit=100, nfev=1304, njev=652.
# Iteration 3 / 100 done in 65.22488629200961 seconds.
# Total Social Welfare: 84.52880111725251
# Consumer rate change: 0.21864637827590444
# Consumer utility change: 0.00024670751948610494%
# Influencer rate change: 0.028559623212563355
# Influencer utility change: 0.0005923980115703524%
# Producer topic change: 0.0025630807538495103
# Producer utility change: 0.0001568462553021316%
# Converged. Optimization took 264.1853419999825 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 1135.4124882499455s): nit=100, nfev=11052, njev=5526.
# Optimizing producer 1
# Optimization succeeded (overall 1355.447130125016s): nit=100, nfev=10380, njev=5190.
# Optimizing producer 2
# Optimization succeeded (overall 1788.3810195830883s): nit=100, nfev=13554, njev=6777.
# Optimizing producer 3
# Optimization succeeded (overall 1842.5497477080207s): nit=100, nfev=14672, njev=7336.
# Optimizing producer 4
# Optimization succeeded (overall 2129.8333092499524s): nit=100, nfev=17040, njev=8520.
# Optimizing producer 5
# Optimization succeeded (overall 1486.25346050004s): nit=100, nfev=11916, njev=5958.
# Optimizing producer 6
# Optimization succeeded (overall 1573.2633763329359s): nit=100, nfev=12606, njev=6303.
# Optimizing producer 7
# Optimization succeeded (overall 1569.738996290951s): nit=100, nfev=12724, njev=6362.
# Optimizing producer 8
# Optimization succeeded (overall 785.6084489589557s): nit=100, nfev=6380, njev=3190.
# Optimizing producer 9
# Optimization succeeded (overall 685.7899092499865s): nit=100, nfev=7674, njev=3837.
# Iteration 0 / 100 done in 14429.705093000084 seconds.
# Total Social Welfare: 84.44536474561701
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 1937.0064880420687s): nit=100, nfev=15794, njev=7897.
# Optimizing producer 1
# Optimization succeeded (overall 1017.0331535419682s): nit=100, nfev=8314, njev=4157.
# Optimizing producer 2
# Optimization succeeded (overall 1983.3732028750237s): nit=100, nfev=16002, njev=8001.
# Optimizing producer 3
# Optimization succeeded (overall 1754.7377957500285s): nit=100, nfev=14186, njev=7093.
# Optimizing producer 4
# Optimization succeeded (overall 1687.317280499963s): nit=100, nfev=13452, njev=6726.
# Optimizing producer 5
# Optimization succeeded (overall 1807.3546438330086s): nit=100, nfev=14360, njev=7180.
# Optimizing producer 6
# Optimization succeeded (overall 1750.4942034169799s): nit=100, nfev=14080, njev=7040.
# Optimizing producer 7
# Optimization succeeded (overall 1673.1988290420268s): nit=100, nfev=13442, njev=6721.
# Optimizing producer 8
# Optimization succeeded (overall 1201.190478791017s): nit=100, nfev=9884, njev=4942.
# Optimizing producer 9
# Optimization succeeded (overall 1123.7829083750257s): nit=100, nfev=9204, njev=4602.
# Iteration 1 / 100 done in 15994.790743374964 seconds.
# Total Social Welfare: 84.489197457704
# Consumer rate change: 0.26579583058931
# Consumer utility change: 0.0005187965824974016%
# Influencer rate change: 0.3207599406241563
# Influencer utility change: 0.0013495141385095912%
# Producer topic change: 0.007688782045034139
# Producer utility change: -3.5707199268726803e-06%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 407.9969755419297s): nit=100, nfev=5980, njev=2990.
# Optimizing producer 1
# Optimization succeeded (overall 413.98402979096863s): nit=100, nfev=5930, njev=2965.
# Optimizing producer 2
# Optimization succeeded (overall 526.3873694589129s): nit=100, nfev=7532, njev=3766.
# Optimizing producer 3
# Optimization succeeded (overall 584.1649483750807s): nit=100, nfev=7768, njev=3884.
# Optimizing producer 4
# Optimization succeeded (overall 638.6315212920308s): nit=100, nfev=8546, njev=4273.
# Optimizing producer 5
# Optimization succeeded (overall 562.5336745419772s): nit=100, nfev=7488, njev=3744.
# Optimizing producer 6
# Optimization succeeded (overall 589.0122856659582s): nit=100, nfev=8062, njev=4031.
# Optimizing producer 7
# Optimization succeeded (overall 655.4149658749811s): nit=100, nfev=8618, njev=4309.
# Optimizing producer 8
# Optimization succeeded (overall 455.7415582500398s): nit=100, nfev=6618, njev=3309.
# Optimizing producer 9
# Optimization succeeded (overall 284.4349611669313s): nit=100, nfev=4370, njev=2185.
# Iteration 2 / 100 done in 5177.069207792054 seconds.
# Total Social Welfare: 84.48946079404301
# Consumer rate change: 0.020849416283828553
# Consumer utility change: 3.116794750371355e-06%
# Influencer rate change: 0.0013740727537763842
# Influencer utility change: -1.4020966160195367e-05%
# Producer topic change: 0.0
# Producer utility change: 1.0910871400342588e-06%
# Converged. Optimization took 35603.21710495802 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 1124.5722740839701s): nit=100, nfev=8776, njev=4388.
# Optimizing producer 1
# Optimization succeeded (overall 1951.2362315409118s): nit=100, nfev=12902, njev=6451.
# Optimizing producer 2
# Optimization succeeded (overall 1827.2616630420089s): nit=100, nfev=14102, njev=7051.
# Optimizing producer 3
# Optimization succeeded (overall 2033.105192292016s): nit=100, nfev=14146, njev=7073.
# Optimizing producer 4
# Optimization succeeded (overall 1954.213841165998s): nit=100, nfev=13718, njev=6859.
# Optimizing producer 5
# Optimization succeeded (overall 1948.8560084580677s): nit=100, nfev=14090, njev=7045.
# Optimizing producer 6
# Optimization succeeded (overall 2223.7454320839606s): nit=100, nfev=14110, njev=7055.
# Optimizing producer 7
# Optimization succeeded (overall 1950.3992672499735s): nit=100, nfev=14212, njev=7106.
# Optimizing producer 8
# Optimization succeeded (overall 1204.1819845000282s): nit=100, nfev=7974, njev=3987.
# Optimizing producer 9
# Optimization succeeded (overall 937.3812605419662s): nit=100, nfev=7456, njev=3728.
# Iteration 0 / 100 done in 17217.34959700005 seconds.
# Total Social Welfare: 82.1658414012403
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 1553.5880107909907s): nit=100, nfev=10930, njev=5465.
# Optimizing producer 1
# Optimization succeeded (overall 1291.3991935839877s): nit=100, nfev=8850, njev=4425.
# Optimizing producer 2
# Optimization succeeded (overall 2245.575707750162s): nit=100, nfev=15914, njev=7957.
# Optimizing producer 3
# Optimization succeeded (overall 2345.0422381670214s): nit=100, nfev=15652, njev=7826.
# Optimizing producer 4
# Optimization succeeded (overall 2312.0245706660207s): nit=100, nfev=16154, njev=8077.
# Optimizing producer 5
# Optimization succeeded (overall 1784.5223332501482s): nit=100, nfev=12292, njev=6146.
# Optimizing producer 6
# Optimization succeeded (overall 1945.9159955410287s): nit=100, nfev=14268, njev=7134.
# Optimizing producer 7
# Optimization succeeded (overall 1342.9816350829788s): nit=100, nfev=9760, njev=4880.
# Optimizing producer 8
# Optimization succeeded (overall 1915.5404417919926s): nit=100, nfev=13708, njev=6854.
# Optimizing producer 9
# Optimization succeeded (overall 859.5922026671469s): nit=100, nfev=6294, njev=3147.
# Iteration 1 / 100 done in 17656.331068290863 seconds.
# Total Social Welfare: 84.48456556471663
# Consumer rate change: 1.8694438511981581
# Consumer utility change: 0.02744553248894705%
# Influencer rate change: 1.2401153128120828
# Influencer utility change: 0.006578907353410799%
# Producer topic change: 0.004580283579556839
# Producer utility change: -3.3792114027966016e-07%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 799.2085152498912s): nit=100, nfev=12950, njev=6475.
# Optimizing producer 1
# Optimization succeeded (overall 510.73805699986406s): nit=100, nfev=7310, njev=3655.
# Optimizing producer 2
# Optimization succeeded (overall 603.0844363749493s): nit=100, nfev=8542, njev=4271.
# Optimizing producer 3
# Optimization succeeded (overall 557.5330244170036s): nit=100, nfev=7844, njev=3922.
# Optimizing producer 4
# Optimization succeeded (overall 670.156882832991s): nit=100, nfev=9248, njev=4624.
# Optimizing producer 5
# Optimization succeeded (overall 584.1363433329388s): nit=100, nfev=8076, njev=4038.
# Optimizing producer 6
# Optimization succeeded (overall 450.9290388340596s): nit=100, nfev=6464, njev=3232.
# Optimizing producer 7
# Optimization succeeded (overall 597.0100534579251s): nit=100, nfev=8246, njev=4123.
# Optimizing producer 8
# Optimization succeeded (overall 553.8837322092149s): nit=100, nfev=8078, njev=4039.
# Optimizing producer 9
# Optimization succeeded (overall 356.72789495810866s): nit=100, nfev=5558, njev=2779.
# Iteration 2 / 100 done in 5741.457086374983 seconds.
# Total Social Welfare: 84.49174507287056
# Consumer rate change: 0.11130973013204419
# Consumer utility change: 8.497288460551063e-05%
# Influencer rate change: 0.003930393607827464
# Influencer utility change: 0.0007586702777433919%
# Producer topic change: 0.0
# Producer utility change: -5.6971974724021e-06%
# Converged. Optimization took 40616.86630270805 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 1823.3703522919677s): nit=100, nfev=7574, njev=3787.
# Optimizing producer 1
# Optimization succeeded (overall 3610.577244541142s): nit=100, nfev=14196, njev=7098.
# Optimizing producer 2
# Optimization succeeded (overall 2665.9318655838724s): nit=100, nfev=10496, njev=5248.
# Optimizing producer 3
# Optimization succeeded (overall 2877.8389965000097s): nit=100, nfev=12636, njev=6318.
# Optimizing producer 4
# Optimization succeeded (overall 2890.0043517909944s): nit=100, nfev=11480, njev=5740.
# Optimizing producer 5
# Optimization succeeded (overall 3814.366564666154s): nit=100, nfev=15268, njev=7634.
# Optimizing producer 6
# Optimization succeeded (overall 3273.1059408341534s): nit=100, nfev=14542, njev=7271.
# Optimizing producer 7
# Optimization succeeded (overall 3200.87574649998s): nit=100, nfev=12586, njev=6293.
# Optimizing producer 8
# Optimization succeeded (overall 2536.8527887919918s): nit=100, nfev=9944, njev=4972.
# Optimizing producer 9
# Optimization succeeded (overall 2971.845719124889s): nit=100, nfev=12402, njev=6201.
# Iteration 0 / 100 done in 29738.40248120902 seconds.
# Total Social Welfare: 76.8853594760087
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 2515.6421468749177s): nit=100, nfev=11870, njev=5935.
# Optimizing producer 1
# Optimization succeeded (overall 3413.9803570001386s): nit=100, nfev=15720, njev=7860.
# Optimizing producer 2
# Optimization succeeded (overall 3112.4608117921744s): nit=100, nfev=14524, njev=7262.
# Optimizing producer 3
# Optimization succeeded (overall 3022.422282167012s): nit=100, nfev=14290, njev=7145.
# Optimizing producer 4
# Optimization succeeded (overall 3220.4909340830054s): nit=100, nfev=15222, njev=7611.
# Optimizing producer 5
# Optimization succeeded (overall 2997.5653410409577s): nit=100, nfev=14084, njev=7042.
# Optimizing producer 6
# Optimization succeeded (overall 3095.303545709001s): nit=100, nfev=14606, njev=7303.
# Optimizing producer 7
# Optimization succeeded (overall 2050.75933520915s): nit=100, nfev=9542, njev=4771.
# Optimizing producer 8
# Optimization succeeded (overall 1321.2996825000737s): nit=100, nfev=6058, njev=3029.
# Optimizing producer 9
# Optimization succeeded (overall 1349.2735435829964s): nit=100, nfev=6342, njev=3171.
# Iteration 1 / 100 done in 26157.706093000015 seconds.
# Total Social Welfare: 84.49112906186593
# Consumer rate change: 3.6569047015625538
# Consumer utility change: 0.09001854715543772%
# Influencer rate change: 4.359826705560265
# Influencer utility change: 0.027631801125410593%
# Producer topic change: 0.008077572418359474
# Producer utility change: 1.134585925775413e-06%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 300.05674525001086s): nit=100, nfev=4624, njev=2312.
# Optimizing producer 1
# Optimization succeeded (overall 549.1979518749285s): nit=100, nfev=8170, njev=4085.
# Optimizing producer 2
# Optimization succeeded (overall 623.1882319999859s): nit=100, nfev=9066, njev=4533.
# Optimizing producer 3
# Optimization succeeded (overall 470.61304508312605s): nit=100, nfev=6526, njev=3263.
# Optimizing producer 4
# Optimization succeeded (overall 628.9187321248464s): nit=100, nfev=8698, njev=4349.
# Optimizing producer 5
# Optimization succeeded (overall 738.0299755001906s): nit=100, nfev=10512, njev=5256.
# Optimizing producer 6
# Optimization succeeded (overall 575.8544266661629s): nit=100, nfev=7760, njev=3880.
# Optimizing producer 7
# Optimization succeeded (overall 677.9682117919438s): nit=100, nfev=9778, njev=4889.
# Optimizing producer 8
# Optimization succeeded (overall 483.08952483395115s): nit=100, nfev=7118, njev=3559.
# Optimizing producer 9
# Optimization succeeded (overall 369.1718302499503s): nit=100, nfev=5742, njev=2871.
# Iteration 2 / 100 done in 5473.7371136669535 seconds.
# Total Social Welfare: 84.49278676772666
# Consumer rate change: 0.0662776834044643
# Consumer utility change: 1.9619493307615277e-05%
# Influencer rate change: 0.009703461986446251
# Influencer utility change: 0.0026527243731718194%
# Producer topic change: 0.0
# Producer utility change: -7.887358795540774e-06%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 313.6928216658998s): nit=100, nfev=4598, njev=2299.
# Optimizing producer 1
# Optimization succeeded (overall 418.6391550831031s): nit=100, nfev=5948, njev=2974.
# Optimizing producer 2
# Optimization succeeded (overall 526.9344912089873s): nit=100, nfev=6886, njev=3443.
# Optimizing producer 3
# Optimization succeeded (overall 565.8296204579528s): nit=100, nfev=8022, njev=4011.
# Optimizing producer 4
# Optimization succeeded (overall 629.0112009169534s): nit=100, nfev=8696, njev=4348.
# Optimizing producer 5
# Optimization succeeded (overall 568.7726067909971s): nit=100, nfev=7632, njev=3816.
# Optimizing producer 6
# Optimization succeeded (overall 530.0714990841225s): nit=100, nfev=7676, njev=3838.
# Optimizing producer 7
# Optimization succeeded (overall 540.8241159580648s): nit=100, nfev=7812, njev=3906.
# Optimizing producer 8
# Optimization succeeded (overall 493.96600779215805s): nit=100, nfev=7264, njev=3632.
# Optimizing producer 9
# Optimization succeeded (overall 441.0998834159691s): nit=100, nfev=6758, njev=3379.
# Iteration 3 / 100 done in 5086.614694958087 seconds.
# Total Social Welfare: 84.49944191422763
# Consumer rate change: 0.09655627367121297
# Consumer utility change: 7.875964104146898e-05%
# Influencer rate change: 0.0009588998516916381
# Influencer utility change: 0.0005785404732350104%
# Producer topic change: 0.0
# Producer utility change: 7.663606349328486e-07%
# Converged. Optimization took 66459.14399775001 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 2930.478331417078s): nit=100, nfev=14056, njev=7028.
# Optimizing producer 1
# Optimization succeeded (overall 2868.1021031669807s): nit=100, nfev=13706, njev=6853.
# Optimizing producer 2
# Optimization succeeded (overall 2609.987364416942s): nit=100, nfev=12464, njev=6232.
# Optimizing producer 3
# Optimization succeeded (overall 3066.80194745888s): nit=100, nfev=13516, njev=6758.
# Optimizing producer 4
# Optimization succeeded (overall 3369.219701375114s): nit=100, nfev=15924, njev=7962.
# Optimizing producer 5
# Optimization succeeded (overall 2894.3330734160263s): nit=100, nfev=13710, njev=6855.
# Optimizing producer 6
# Optimization succeeded (overall 2829.522553959163s): nit=100, nfev=12530, njev=6265.
# Optimizing producer 7
# Optimization succeeded (overall 2449.3253679578193s): nit=100, nfev=11636, njev=5818.
# Optimizing producer 8
# Optimization succeeded (overall 1910.2954706670716s): nit=100, nfev=9048, njev=4524.
# Optimizing producer 9
# Optimization succeeded (overall 2520.954239875078s): nit=100, nfev=12124, njev=6062.
# Iteration 0 / 100 done in 27521.96826166706 seconds.
# Total Social Welfare: 73.60122203477562
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 847.3939902500715s): nit=100, nfev=5804, njev=2902.
# Optimizing producer 1
# Optimization succeeded (overall 1756.5372541660909s): nit=100, nfev=10946, njev=5473.
# Optimizing producer 2
# Optimization succeeded (overall 2190.306731333025s): nit=100, nfev=13552, njev=6776.
# Optimizing producer 3
# Optimization succeeded (overall 2234.1562624999788s): nit=100, nfev=14116, njev=7058.
# Optimizing producer 4
# Optimization succeeded (overall 1681.7708958329167s): nit=100, nfev=12808, njev=6404.
# Optimizing producer 5
# Optimization succeeded (overall 1745.50822374993s): nit=100, nfev=14290, njev=7145.
# Optimizing producer 6
# Optimization succeeded (overall 1667.1061479579657s): nit=100, nfev=13338, njev=6669.
# Optimizing producer 7
# Optimization succeeded (overall 1718.6112880830187s): nit=100, nfev=13238, njev=6619.
# Optimizing producer 8
# Optimization succeeded (overall 1470.9414638748858s): nit=100, nfev=11330, njev=5665.
# Optimizing producer 9
# Optimization succeeded (overall 1018.7794610001147s): nit=100, nfev=8338, njev=4169.
# Iteration 1 / 100 done in 16390.0311324168 seconds.
# Total Social Welfare: 84.4592421713233
# Consumer rate change: 5.587319218061704
# Consumer utility change: 0.12855927393866207%
# Influencer rate change: 1.4941853336206679
# Influencer utility change: 0.03213066927119752%
# Producer topic change: 0.014009381490371986
# Producer utility change: 1.222414338690929e-06%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 372.94663895783015s): nit=100, nfev=5574, njev=2787.
# Optimizing producer 1
# Optimization succeeded (overall 515.5717562080827s): nit=100, nfev=7552, njev=3776.
# Optimizing producer 2
# Optimization succeeded (overall 599.0636542080902s): nit=100, nfev=8636, njev=4318.
# Optimizing producer 3
# Optimization succeeded (overall 532.101459832862s): nit=100, nfev=7440, njev=3720.
# Optimizing producer 4
# Optimization succeeded (overall 713.1108040411491s): nit=100, nfev=9288, njev=4644.
# Optimizing producer 5
# Optimization succeeded (overall 712.9200561670586s): nit=100, nfev=8766, njev=4383.
# Optimizing producer 6
# Optimization succeeded (overall 661.4894954168703s): nit=100, nfev=8880, njev=4440.
# Optimizing producer 7
# Optimization succeeded (overall 509.5123792910017s): nit=100, nfev=7240, njev=3620.
# Optimizing producer 8
# Optimization succeeded (overall 409.72971862507984s): nit=100, nfev=6148, njev=3074.
# Optimizing producer 9
# Optimization succeeded (overall 370.6759360001888s): nit=100, nfev=5824, njev=2912.
# Iteration 2 / 100 done in 5455.5287010839675 seconds.
# Total Social Welfare: 84.46718929185955
# Consumer rate change: 0.13193308524046984
# Consumer utility change: 9.408528520978631e-05%
# Influencer rate change: 0.006531059670386369
# Influencer utility change: 0.0008133561525433307%
# Producer topic change: 0.0
# Producer utility change: 1.0740539770063077e-06%
# Converged. Optimization took 49369.12636787491 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 1286.6429956250358s): nit=100, nfev=6964, njev=3482.
# Optimizing producer 1
# Optimization succeeded (overall 2967.010893209139s): nit=100, nfev=14798, njev=7399.
# Optimizing producer 2
# Optimization succeeded (overall 2717.710170999868s): nit=100, nfev=11868, njev=5934.
# Optimizing producer 3
# Optimization succeeded (overall 2200.0671140840277s): nit=100, nfev=11656, njev=5828.
# Optimizing producer 4
# Optimization succeeded (overall 2368.179084124975s): nit=100, nfev=12164, njev=6082.
# Optimizing producer 5
# Optimization succeeded (overall 3096.6515846250113s): nit=100, nfev=13168, njev=6584.
# Optimizing producer 6
# Optimization succeeded (overall 2843.703210416017s): nit=100, nfev=12186, njev=6093.
# Optimizing producer 7
# Optimization succeeded (overall 2089.8041585418396s): nit=100, nfev=9310, njev=4655.
# Optimizing producer 8
# Optimization succeeded (overall 2760.732189666014s): nit=100, nfev=12156, njev=6078.
# Optimizing producer 9
# Optimization succeeded (overall 1802.6241788750049s): nit=100, nfev=8046, njev=4023.
# Iteration 0 / 100 done in 24203.265646416927 seconds.
# Total Social Welfare: 79.72360533156207
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 3059.898410582915s): nit=100, nfev=11860, njev=5930.
# Optimizing producer 1
# Optimization succeeded (overall 2583.2544310831s): nit=100, nfev=9116, njev=4558.
# Optimizing producer 2
# Optimization succeeded (overall 3365.3255605420563s): nit=100, nfev=12596, njev=6298.
# Optimizing producer 3
# Optimization succeeded (overall 3469.528351749992s): nit=100, nfev=13588, njev=6794.
# Optimizing producer 4
# Optimization succeeded (overall 3708.588264165912s): nit=100, nfev=14970, njev=7485.
# Optimizing producer 5
# Optimization succeeded (overall 3086.3085597089957s): nit=100, nfev=13132, njev=6566.
# Optimizing producer 6
# Optimization succeeded (overall 3145.2205739580095s): nit=100, nfev=12968, njev=6484.
# Optimizing producer 7
# Optimization succeeded (overall 2871.018451583106s): nit=100, nfev=12308, njev=6154.
# Optimizing producer 8
# Optimization succeeded (overall 3521.9888116670772s): nit=100, nfev=13972, njev=6986.
# Optimizing producer 9
# Optimization succeeded (overall 1764.5375047908165s): nit=100, nfev=6552, njev=3276.
# Iteration 1 / 100 done in 30645.98858462507 seconds.
# Total Social Welfare: 84.48634351296934
# Consumer rate change: 2.7530117625319748
# Consumer utility change: 0.05637286950343009%
# Influencer rate change: 3.978517206008563
# Influencer utility change: 0.0322767545950858%
# Producer topic change: 0.009094456197059115
# Producer utility change: -1.0107165723204011e-06%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 561.5918188330252s): nit=100, nfev=7828, njev=3914.
# Optimizing producer 1
# Optimization succeeded (overall 502.21964304195717s): nit=100, nfev=6434, njev=3217.
# Optimizing producer 2
# Optimization succeeded (overall 515.2260930831544s): nit=100, nfev=7282, njev=3641.
# Optimizing producer 3
# Optimization succeeded (overall 685.9381169590633s): nit=100, nfev=9602, njev=4801.
# Optimizing producer 4
# Optimization succeeded (overall 478.416031959001s): nit=100, nfev=6822, njev=3411.
# Optimizing producer 5
# Optimization succeeded (overall 692.2153659579344s): nit=100, nfev=9466, njev=4733.
# Optimizing producer 6
# Optimization succeeded (overall 578.1642294169869s): nit=100, nfev=8022, njev=4011.
# Optimizing producer 7
# Optimization succeeded (overall 499.90112670790404s): nit=100, nfev=7074, njev=3537.
# Optimizing producer 8
# Optimization succeeded (overall 395.804467542097s): nit=100, nfev=5944, njev=2972.
# Optimizing producer 9
# Optimization succeeded (overall 350.16153770918027s): nit=100, nfev=5294, njev=2647.
# Iteration 2 / 100 done in 5327.11159504205 seconds.
# Total Social Welfare: 84.48907023251934
# Consumer rate change: 0.08474064410536832
# Consumer utility change: 3.2273040995161666e-05%
# Influencer rate change: 0.005741341276129067
# Influencer utility change: 0.002890780475578539%
# Producer topic change: 0.0
# Producer utility change: -3.511828091854084e-06%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 222.0415152499918s): nit=100, nfev=3432, njev=1716.
# Optimizing producer 1
# Optimization succeeded (overall 559.5925612091087s): nit=100, nfev=8088, njev=4044.
# Optimizing producer 2
# Optimization succeeded (overall 574.2917995410971s): nit=100, nfev=8034, njev=4017.
# Optimizing producer 3
# Optimization succeeded (overall 523.7918684999458s): nit=100, nfev=7052, njev=3526.
# Optimizing producer 4
# Optimization succeeded (overall 705.6438608751632s): nit=100, nfev=9160, njev=4580.
# Optimizing producer 5
# Optimization succeeded (overall 565.6793585829437s): nit=100, nfev=7746, njev=3873.
# Optimizing producer 6
# Optimization succeeded (overall 561.3453610418364s): nit=100, nfev=7774, njev=3887.
# Optimizing producer 7
# Optimization succeeded (overall 562.3033072920516s): nit=100, nfev=7400, njev=3700.
# Optimizing producer 8
# Optimization succeeded (overall 360.3957794168964s): nit=100, nfev=5508, njev=2754.
# Optimizing producer 9
# Optimization succeeded (overall 318.5809780410491s): nit=100, nfev=5020, njev=2510.
# Iteration 3 / 100 done in 5012.636775125051 seconds.
# Total Social Welfare: 84.48907094010526
# Consumer rate change: 0.0009151555978469388
# Consumer utility change: 8.37488011708077e-09%
# Influencer rate change: 0.0021409106217904457
# Influencer utility change: -2.790321154803537e-06%
# Producer topic change: 0.0
# Producer utility change: 2.0401198778643566e-06%
# Converged. Optimization took 65192.132088750135 seconds.

# %%
visualize.plot_ending_value_by_test(f"Total Social Welfare By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'total_social_welfare', varied_param_values, varied_param_x_label, 'Total Social Welfare')

# %%
visualize.plot_cost_of_influence_by_test(f"Cost of Influence By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, varied_param_values, varied_param_x_label, 'Cost of Influence')

# %%
visualize.plot_ending_value_by_test(f"Average Producer Utility By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_producer_utility', varied_param_values, varied_param_x_label, 'Average Producer Utility')

# %%
visualize.plot_ending_value_by_test(f"Average Consumer Utility By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_consumer_utility', varied_param_values, varied_param_x_label, 'Average Consumer Utility')

# %%
visualize.plot_ending_value_by_test(f"Average Influencer Utility By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_influencer_utility', varied_param_values, varied_param_x_label, 'Average Influencer Utility')

# %%
visualize.plot_ending_value_by_test(f"Average Consumer-Influencer Follow Proportion By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_influencer_follow_proportion', varied_param_values, varied_param_x_label, 'Average Influencer Follow Proportion')

# %%
visualize.plot_value_by_test(f"Optimization time by {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'optimization_time', varied_param_values, varied_param_x_label, 'Optimization Time (s)')

# %%
visualize.plot_value_by_test(f"Number of Iterations by {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'num_iterations', varied_param_values, varied_param_x_label, 'Number of Iterations')

# %%
plt.figure()
plt.title(f'Ending Producer Topic Produced by {varied_param_x_label} (perfect)')
plt.xlabel(varied_param_x_label)
plt.ylabel('Ending Producer Topic Produced')
topics_produced = {}
for i in range(len(varied_param_values)):
    stat = perfect_info_stats[i]
    producer_stats = stat.producer_stats
    for index, producer_stat in producer_stats.items():
        if topics_produced.get(index) is None:
            topics_produced[index] = []
        topics_produced[index].append(producer_stat.topics[-1])

for index, topic_produced in topics_produced.items():
    plt.plot(varied_param_values, topic_produced, label=f'Producer {index}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f'Ending Producer Topic Produced by {varied_param_x_label} (imperfect)')
    plt.xlabel(varied_param_x_label)
    plt.ylabel('Ending Producer Topic Produced')
    topics_produced = {}
    for i in range(len(varied_param_values)):
        stat = imperfect_info_stats[i]
        producer_stats = stat.producer_stats
        for index, producer_stat in producer_stats.items():
            if topics_produced.get(index) is None:
                topics_produced[index] = []
            topics_produced[index].append(producer_stat.topics[-1])

    for index, topic_produced in topics_produced.items():
        plt.plot(varied_param_values, topic_produced, label=f'Producer {index}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
visualize.plot_value_by_iteration_by_test(f"Time per iteration by {varied_param_x_label} (Perfect)", perfect_info_stats, 'optimization_times', varied_param_legend_label, varied_param_values, 'Time (s)')

# %%
visualize.plot_ending_value_by_test(f"Average Consumer-External Follow Proportion By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_external_follow_proportion', varied_param_values, varied_param_x_label, 'Average External Follow Proportion')

# %%
plt.figure()
plt.title(f'Average Consumer Follow Proportions By {varied_param_x_label}')
plt.xlabel(varied_param_x_label)
plt.ylabel('Average Consumer Follow Proportions')
avg_producer_proportions = []
avg_max_producer_proportions = []
avg_influencer_proportions = []
avg_external_proportions = []
for i in range(len(varied_param_values)):
    perfect_stat: TestStats = perfect_info_stats[i]
    avg_producer_proportion = 0
    avg_max_producer_proportion = 0
    avg_influencer_proportion = 0
    avg_external_proportion = 0
    for consumer in perfect_stat.consumer_stats.values():
        avg_producer_proportion += sum(consumer.following_rates[-1][:-2]) / consumer.agent.attention_bound
        avg_max_producer_proportion += np.max(consumer.following_rates[-1][:-2]) / consumer.agent.attention_bound
        avg_influencer_proportion += consumer.following_rates[-1][-2] / consumer.agent.attention_bound
        avg_external_proportion += consumer.following_rates[-1][-1] / consumer.agent.attention_bound
    avg_producer_proportion /= len(perfect_stat.consumer_stats)
    avg_max_producer_proportion /= len(perfect_stat.consumer_stats)
    avg_influencer_proportion /= len(perfect_stat.consumer_stats)
    avg_external_proportion /= len(perfect_stat.consumer_stats)

    avg_producer_proportions.append(avg_producer_proportion)
    avg_max_producer_proportions.append(avg_max_producer_proportion)
    avg_influencer_proportions.append(avg_influencer_proportion)
    avg_external_proportions.append(avg_external_proportion)
plt.plot(varied_param_values, avg_producer_proportions, label='All Producers')
plt.plot(varied_param_values, avg_max_producer_proportions, label='Max Producer')
plt.plot(varied_param_values, avg_influencer_proportions, label='Influencer')
plt.plot(varied_param_values, avg_external_proportions, label='External')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
plt.figure()
for i in range(len(perfect_info_stats)):
    perfect_stat: TestStats = perfect_info_stats[i]
    avg_rate_by_main_interest_closeness = perfect_stat.average_following_rate_by_main_interest_closeness
    if len(avg_rate_by_main_interest_closeness) == 0:
        continue
    closenesses = [x[0] for x in avg_rate_by_main_interest_closeness]
    rates = [x[1] for x in avg_rate_by_main_interest_closeness]
    min_rate = min(rates)
    max_rate = max(rates)
    rates = [(x - min_rate) / (max_rate - min_rate) for x in rates]
    plt.plot(closenesses, rates, label=f"{varied_param_legend_label}={varied_param_values[i]}")
plt.title(f"Normalized Average Following Rate By Main Interest Closeness (Perfect)")
plt.xlabel("Closeness")
plt.ylabel("Normalized Average Following Rate")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
plt.figure()
plt.title(f'Average Standard Deviation of Nonzero Agent Following Rates by {varied_param_x_label}')
plt.xlabel(varied_param_x_label)
plt.ylabel('Agent Following Rates (%)')
average_standard_deviations = []
for i in range(len(perfect_info_stats)):
    perfect_stat: TestStats = perfect_info_stats[i]
    avg_standard_deviation = 0
    for index in perfect_stat.consumer_stats:
        stat = perfect_stat.consumer_stats[index]
        following_rate = [x / stat.agent.attention_bound * 100 for x in stat.following_rates[-1][:-2] if x > 1e-3]
        if len(following_rate) == 0:
            continue
        avg_standard_deviation += np.std(following_rate)
    average_standard_deviations.append(avg_standard_deviation / len(perfect_stat.consumer_stats))
plt.plot(varied_param_values, average_standard_deviations)
plt.show()

# %%
plt.figure()
plt.title(f'Average width of consumer following rate distribution by {varied_param_x_label}')
plt.xlabel(varied_param_x_label)
plt.ylabel('Average width of consumer following rate distribution')
average_widths = []
for i in range(len(perfect_info_stats)):
    perfect_stat: TestStats = perfect_info_stats[i]
    avg_width = 0
    for index in perfect_stat.consumer_stats:
        stat = perfect_stat.consumer_stats[index]
        following_rate = [x for x in stat.following_rates[-1][:-2]]
        min_nonzero_index = 0
        max_nonzero_index = len(following_rate) - 1
        while following_rate[min_nonzero_index] < 1e-3 and min_nonzero_index < len(following_rate) - 1:
            min_nonzero_index += 1
        while following_rate[max_nonzero_index] < 1e-3 and max_nonzero_index > 0:
            max_nonzero_index -= 1
        if min_nonzero_index > max_nonzero_index:
            continue
        avg_width += np.linalg.norm(perfect_stat.producer_stats[max_nonzero_index].agent.main_interest - perfect_stat.producer_stats[min_nonzero_index].agent.main_interest)
    average_widths.append(avg_width / len(perfect_stat.consumer_stats))
plt.plot(varied_param_values, average_widths)
plt.show()

# %%
plt.figure()
plt.title(f'Standard Deviation of Nonzero Influencer Following Rates by {varied_param_x_label}')
plt.xlabel(varied_param_x_label)
plt.ylabel('Influencer Following Rates (%)')
standard_deviations = []
for i in range(len(perfect_info_stats)):
    perfect_stat: TestStats = perfect_info_stats[i]
    influencer_stat = [x for x in perfect_stat.influencer_stats.values()][0]
    following_rate = [x / influencer_stat.agent.attention_bound * 100 for x in influencer_stat.following_rates[-1][:-2] if x > 1e-3]
    standard_deviations.append(np.std(following_rate))
plt.plot(varied_param_values, standard_deviations)
plt.show()

# %%
plt.figure()
plt.title(f'Width of Influencer following rate distribution by {varied_param_x_label}')
plt.xlabel(varied_param_x_label)
plt.ylabel('Width of Influencer following rate distribution')
widths = []
for i in range(len(perfect_info_stats)):
    perfect_stat: TestStats = perfect_info_stats[i]
    width = 0
    stat = [x for x in perfect_stat.influencer_stats.values()][0]
    following_rate = [x for x in stat.following_rates[-1][:-2]]
    min_nonzero_index = 0
    max_nonzero_index = len(following_rate) - 1
    while following_rate[min_nonzero_index] < 1e-3 and min_nonzero_index < len(following_rate) - 1:
        min_nonzero_index += 1
    while following_rate[max_nonzero_index] < 1e-3 and max_nonzero_index > 0:
        max_nonzero_index -= 1
    if min_nonzero_index > max_nonzero_index:
            continue
    width = np.linalg.norm(perfect_stat.producer_stats[max_nonzero_index].agent.main_interest - perfect_stat.producer_stats[min_nonzero_index].agent.main_interest)
    widths.append(width)
plt.plot(varied_param_values, widths)
plt.show()

# %%
plt.figure()
plt.title(f'Average Ending Topic Closeness to Main Interest by {varied_param_x_label}')
plt.xlabel(varied_param_x_label)
plt.ylabel('Ending Topic Closeness to Main Interest')
ending_closenesses = []
for i in range(len(perfect_info_stats)):
    perfect_stat: TestStats = perfect_info_stats[i]
    avg_closeness = 0
    for producer_stat in perfect_stat.producer_stats.values():
        avg_closeness += np.linalg.norm(producer_stat.agent.main_interest - producer_stat.agent.topic_produced)
    avg_closeness /= len(perfect_stat.producer_stats)
    ending_closenesses.append(avg_closeness)
plt.plot(varied_param_values, ending_closenesses)
plt.show()

# %%
plt.figure()
plt.title("Ending Topic Closeness to Main Interest by Distance from Topic Center")
plt.xlabel("Distance from Topic Center")
plt.ylabel("Ending Topic Closeness to Main Interest")
for i in range(len(perfect_info_stats)):
    perfect_stat: TestStats = perfect_info_stats[i]
    topic_center = np.mean(perfect_stat.producer_stats[0].agent.market.topics_bounds, axis=1)
    closenesses = []
    distances = []

    producers = sorted(perfect_stat.producer_stats.values(), key=lambda x: np.linalg.norm(x.agent.main_interest - topic_center))
    for producer_stat in producers:
        distances.append(np.linalg.norm(producer_stat.agent.main_interest - topic_center))
        closenesses.append(np.linalg.norm(producer_stat.agent.main_interest - producer_stat.agent.topic_produced))
    plt.plot(distances, closenesses, label=f"{varied_param_legend_label}={varied_param_values[i]}")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title("Ending Topic Closeness to Main Interest by Distance from Topic Center (Imperfect)")
    plt.xlabel("Distance from Topic Center")
    plt.ylabel("Ending Topic Closeness to Main Interest")
    for i in range(len(imperfect_info_stats)):
        imperfect_stat: TestStats = perfect_info_stats[i]
        topic_center = np.mean(imperfect_stat.producer_stats[0].agent.market.topics_bounds, axis=1)
        closenesses = []
        distances = []

        producers = sorted(imperfect_stat.producer_stats.values(), key=lambda x: np.linalg.norm(x.agent.main_interest - topic_center))
        for producer_stat in producers:
            distances.append(np.linalg.norm(producer_stat.agent.main_interest - topic_center))
            closenesses.append(np.linalg.norm(producer_stat.agent.main_interest - producer_stat.agent.topic_produced))
        plt.plot(distances, closenesses, label=f"{varied_param_legend_label}={varied_param_values[i]}")
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
for i in range(num_agents):
    visualize.plot_agent_following_rates_by_test(i, [stat.consumer_stats for stat in perfect_info_stats], varied_param_legend_label, varied_param_values)

# %%
for val, stat in zip(varied_param_values, perfect_info_stats):
    influencer_ind = num_agents
    influencer_stat = stat.influencer_stats[influencer_ind]
    influencer = influencer_stat.agent
    following_rates = influencer_stat.following_rates[-1]
    prod_main_interest_with_rates = [(prod.main_interest[0], following_rates[prod.index] / influencer.attention_bound * 100) for prod in influencer.market.producers]
    prod_main_interest_with_rates.sort(key=lambda x: x[0])
    plt.plot([x[0] for x in prod_main_interest_with_rates], [x[1] for x in prod_main_interest_with_rates], label=f'{varied_param_legend_label} = {val}', marker='o')

plt.title(f"Percentage of Attention Given to Producers by Influencer")
plt.xlabel("Producer Topic")
plt.ylabel("Percentage of Attention Given to Producer")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
for val, stat in zip(varied_param_values, perfect_info_stats):
    influencer_ind = num_agents
    influencer_stat = stat.influencer_stats[influencer_ind]
    influencer = influencer_stat.agent
    following_rates = influencer_stat.following_rates[-1]
    min_rate = min(following_rates)
    max_rate = max(following_rates)
    following_rates = [(rate - min_rate) / (max_rate - min_rate) for rate in following_rates]
    prod_main_interest_with_rates = [(prod.main_interest[0], following_rates[prod.index]) for prod in influencer.market.producers]
    prod_main_interest_with_rates.sort(key=lambda x: x[0])
    plt.plot([x[0] for x in prod_main_interest_with_rates], [x[1] for x in prod_main_interest_with_rates], label=f'{varied_param_legend_label} = {val}', marker='o')

plt.title(f"Normalized Attention Given to Producers by Influencer (Perfect)")
plt.xlabel("Producer Topic")
plt.ylabel("Normalized Attention Given to Producer")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
