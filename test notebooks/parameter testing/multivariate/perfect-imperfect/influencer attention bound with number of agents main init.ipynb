# %%
import numpy as np
from test import test
from util import inverse_decay
import matplotlib.pyplot as plt
import visualize
from stats import *
from agents import *

# %%
topics = np.array([[-1, 1]])

# %%
first_param = 'influencer_attention_bound'
first_param_legend_label = 'Influencer Attention Bound'
first_param_x_label = 'Influencer Attention Bound'
first_param_values = [0, 1, 15, 30, 80, 150]

# %%
second_param = 'num_agents'
second_param_legend_label = 'Number of Agents'
second_param_x_label = 'Number of Agents'
second_param_values = [2, 5, 10, 20]

# %%
num_influencers = 1

# %%
test_imperfect = True

# %%
first_param_stats = {}

for first_param_value in first_param_values:
    perfect_info_stats, imperfect_info_stats = test(
        topics=topics,
        varied_param=second_param,
        num_influencers=num_influencers,
        num_agents=second_param_values,
        producer_topic_interest_func=lambda x: inverse_decay(x, 0.5, 2),
        consumer_topic_interest_func=lambda x: inverse_decay(x, 0.5, 2),
        agent_topic_interest_func=None,
        consumer_attention_bound=10,
        consumer_external_interest_prob=3,
        consumer_delay_sensitivity=1,
        influencer_attention_bound=first_param_value,
        influencer_delay_sensitivity=1,
        init_following_rates_method='equal',
        init_interest_method='even',
        init_topic_produced_method='farthest',
        production_rate=1,
        external_production_rate=1,
        use_imperfect_information=test_imperfect,
        delay_sensitivity=None,
    )
    first_param_stats[first_param_value] = {
        'perfect': perfect_info_stats,
        'imperfect': imperfect_info_stats
    }
# Out:
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing influencer 2
# Optimizing producer 0
# Optimization succeeded (overall 0.0006874999962747097s): nit=4, nfev=10, njev=5.
# Optimizing producer 1
# Optimization succeeded (overall 0.0006305421702563763s): nit=4, nfev=10, njev=5.
# Iteration 0 / 100 done in 0.009985417127609253 seconds.
# Total Social Welfare: 5.463939593177809
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing influencer 2
# Optimizing producer 0
# Optimization succeeded (overall 0.00019554211758077145s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.00015825009904801846s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.003181666135787964 seconds.
# Total Social Welfare: 5.464374189139974
# Consumer rate change: 0.1407315433090931
# Consumer utility change: 7.953258471268876e-05%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0645214316657236%
# Converged. Optimization took 0.013595292111858726 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.0018353750929236412s): nit=5, nfev=20, njev=10.
# Optimizing producer 1
# Optimization succeeded (overall 0.0016219581011682749s): nit=5, nfev=18, njev=9.
# Optimizing producer 2
# Optimization succeeded (overall 0.0011037089861929417s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.001599250128492713s): nit=5, nfev=18, njev=9.
# Optimizing producer 4
# Optimization succeeded (overall 0.0017805411480367184s): nit=5, nfev=20, njev=10.
# Iteration 0 / 100 done in 0.05318670812994242 seconds.
# Total Social Welfare: 14.326904522479255
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.0004010000266134739s): nit=2, nfev=6, njev=3.
# Optimizing producer 1
# Optimization succeeded (overall 0.0009794998914003372s): nit=5, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.0009431671351194382s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.0011100410483777523s): nit=5, nfev=12, njev=6.
# Optimizing producer 4
# Optimization succeeded (overall 0.0008259590249508619s): nit=4, nfev=10, njev=5.
# Iteration 1 / 100 done in 0.022773542208597064 seconds.
# Total Social Welfare: 14.683777323488592
# Consumer rate change: 0.8626830832439122
# Consumer utility change: 0.0243038743797279%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.22480217043944997
# Producer utility change: 0.3259434073919353%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.0002679170574992895s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.00019933399744331837s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.000724750105291605s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.000268709147349s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0007934998720884323s): nit=4, nfev=10, njev=5.
# Iteration 2 / 100 done in 0.02545370883308351 seconds.
# Total Social Welfare: 14.688645803560753
# Consumer rate change: 0.188238400547692
# Consumer utility change: 0.00033144501406364183%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.009493543871006338
# Producer utility change: 0.027383764938688243%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.00024912506341934204s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.00023637502454221249s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0005583330057561398s): nit=1, nfev=6, njev=3.
# Optimizing producer 3
# Optimization succeeded (overall 0.00021891691721975803s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0004259580746293068s): nit=2, nfev=6, njev=3.
# Iteration 3 / 100 done in 0.005862958030775189 seconds.
# Total Social Welfare: 14.688650118166047
# Consumer rate change: 0.0
# Consumer utility change: 2.9373725910681873e-07%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0004007108314691532
# Producer utility change: 2.522123761580898e-06%
# Converged. Optimization took 0.10947279119864106 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0031274589709937572s): nit=4, nfev=18, njev=9.
# Optimizing producer 1
# Optimization succeeded (overall 0.012506958097219467s): nit=5, nfev=22, njev=11.
# Optimizing producer 2
# Optimization succeeded (overall 0.003799875034019351s): nit=6, nfev=18, njev=9.
# Optimizing producer 3
# Optimization succeeded (overall 0.0027300838846713305s): nit=5, nfev=16, njev=8.
# Optimizing producer 4
# Optimization succeeded (overall 0.0023564579896628857s): nit=5, nfev=14, njev=7.
# Optimizing producer 5
# Optimization succeeded (overall 0.0023677079007029533s): nit=5, nfev=14, njev=7.
# Optimizing producer 6
# Optimization succeeded (overall 0.0027101251762360334s): nit=5, nfev=16, njev=8.
# Optimizing producer 7
# Optimization succeeded (overall 0.003077707951888442s): nit=6, nfev=18, njev=9.
# Optimizing producer 8
# Optimization succeeded (overall 0.0036301251966506243s): nit=5, nfev=22, njev=11.
# Optimizing producer 9
# Optimization succeeded (overall 0.0035831660497933626s): nit=4, nfev=18, njev=9.
# Iteration 0 / 100 done in 0.3297405408229679 seconds.
# Total Social Welfare: 30.672440703898584
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.00036891689524054527s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0010410828981548548s): nit=5, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.00188045809045434s): nit=5, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.001509874826297164s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.0013944169040769339s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.0015862919390201569s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.0029669590294361115s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0015662920195609331s): nit=5, nfev=12, njev=6.
# Optimizing producer 8
# Optimization succeeded (overall 0.0011464161798357964s): nit=5, nfev=12, njev=6.
# Optimizing producer 9
# Optimization succeeded (overall 0.00022895797155797482s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.15681279101409018 seconds.
# Total Social Welfare: 32.954750545795875
# Consumer rate change: 1.947494883341323
# Consumer utility change: 0.06925584662421255%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.2223602784300624
# Producer utility change: 0.4169541373044974%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0003969999961555004s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0011226669885218143s): nit=3, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.0011223750188946724s): nit=2, nfev=6, njev=3.
# Optimizing producer 3
# Optimization succeeded (overall 0.001583958975970745s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.001564917154610157s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.0014274579007178545s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.0013920420315116644s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0012069158256053925s): nit=2, nfev=6, njev=3.
# Optimizing producer 8
# Optimization succeeded (overall 0.001256916904821992s): nit=3, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.0004985830746591091s): nit=0, nfev=2, njev=1.
# Iteration 2 / 100 done in 0.14068499999120831 seconds.
# Total Social Welfare: 32.98094745679968
# Consumer rate change: 0.2511229862806538
# Consumer utility change: 0.0007943041386268228%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.017055978454965454
# Producer utility change: 0.02514362329979278%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0005102502182126045s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0008071248885244131s): nit=2, nfev=6, njev=3.
# Optimizing producer 2
# Optimization succeeded (overall 0.0006727499421685934s): nit=1, nfev=4, njev=2.
# Optimizing producer 3
# Optimization succeeded (overall 0.0009567500092089176s): nit=1, nfev=6, njev=3.
# Optimizing producer 4
# Optimization succeeded (overall 0.0012831250205636024s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.001648708013817668s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.0015117910224944353s): nit=1, nfev=6, njev=3.
# Optimizing producer 7
# Optimization succeeded (overall 0.0007780420128256083s): nit=1, nfev=4, njev=2.
# Optimizing producer 8
# Optimization succeeded (overall 0.000849416945129633s): nit=2, nfev=6, njev=3.
# Optimizing producer 9
# Optimization succeeded (overall 0.0003572499845176935s): nit=0, nfev=2, njev=1.
# Iteration 3 / 100 done in 0.07751795812509954 seconds.
# Total Social Welfare: 32.98108168570964
# Consumer rate change: 0.010167922860111575
# Consumer utility change: 4.069874679440072e-06%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0011154528347147787
# Producer utility change: 0.0004873824732175384%
# Converged. Optimization took 0.7333402500953525 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.00629487494006753s): nit=4, nfev=20, njev=10.
# Optimizing producer 1
# Optimization succeeded (overall 0.00573937501758337s): nit=4, nfev=18, njev=9.
# Optimizing producer 2
# Optimization succeeded (overall 0.006622749846428633s): nit=5, nfev=20, njev=10.
# Optimizing producer 3
# Optimization succeeded (overall 0.006435957970097661s): nit=5, nfev=20, njev=10.
# Optimizing producer 4
# Optimization succeeded (overall 0.006230291910469532s): nit=5, nfev=20, njev=10.
# Optimizing producer 5
# Optimization succeeded (overall 0.006402874831110239s): nit=5, nfev=20, njev=10.
# Optimizing producer 6
# Optimization succeeded (overall 0.004625750007107854s): nit=5, nfev=14, njev=7.
# Optimizing producer 7
# Optimization succeeded (overall 0.006348958006128669s): nit=6, nfev=20, njev=10.
# Optimizing producer 8
# Optimization succeeded (overall 0.005099624861031771s): nit=5, nfev=16, njev=8.
# Optimizing producer 9
# Optimization succeeded (overall 0.004269375000149012s): nit=5, nfev=14, njev=7.
# Optimizing producer 10
# Optimization succeeded (overall 0.004581834189593792s): nit=5, nfev=14, njev=7.
# Optimizing producer 11
# Optimization succeeded (overall 0.005534374853596091s): nit=5, nfev=16, njev=8.
# Optimizing producer 12
# Optimization succeeded (overall 0.00630704197101295s): nit=6, nfev=20, njev=10.
# Optimizing producer 13
# Optimization succeeded (overall 0.0044334998819977045s): nit=5, nfev=14, njev=7.
# Optimizing producer 14
# Optimization succeeded (overall 0.006118333898484707s): nit=5, nfev=20, njev=10.
# Optimizing producer 15
# Optimization succeeded (overall 0.006700624944642186s): nit=5, nfev=20, njev=10.
# Optimizing producer 16
# Optimization succeeded (overall 0.008955999976024032s): nit=5, nfev=20, njev=10.
# Optimizing producer 17
# Optimization succeeded (overall 0.00851266598328948s): nit=5, nfev=20, njev=10.
# Optimizing producer 18
# Optimization succeeded (overall 0.006215750006958842s): nit=4, nfev=18, njev=9.
# Optimizing producer 19
# Optimization succeeded (overall 0.007936500012874603s): nit=4, nfev=20, njev=10.
# Iteration 0 / 100 done in 2.3996228331234306 seconds.
# Total Social Welfare: 64.32588248649701
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.0006618751212954521s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0006597498431801796s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0004724999889731407s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.0005580410361289978s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0004594998899847269s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.0038158749230206013s): nit=6, nfev=14, njev=7.
# Optimizing producer 6
# Optimization succeeded (overall 0.0030328750144690275s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0030043330043554306s): nit=3, nfev=10, njev=5.
# Optimizing producer 8
# Optimization succeeded (overall 0.002803624840453267s): nit=3, nfev=10, njev=5.
# Optimizing producer 9
# Optimization succeeded (overall 0.0024449999909847975s): nit=3, nfev=10, njev=5.
# Optimizing producer 10
# Optimization succeeded (overall 0.0028650828171521425s): nit=3, nfev=10, njev=5.
# Optimizing producer 11
# Optimization succeeded (overall 0.0026622500736266375s): nit=3, nfev=10, njev=5.
# Optimizing producer 12
# Optimization succeeded (overall 0.0025445001665502787s): nit=3, nfev=10, njev=5.
# Optimizing producer 13
# Optimization succeeded (overall 0.002415207913145423s): nit=3, nfev=10, njev=5.
# Optimizing producer 14
# Optimization succeeded (overall 0.002704540966078639s): nit=6, nfev=14, njev=7.
# Optimizing producer 15
# Optimization succeeded (overall 0.00042775017209351063s): nit=0, nfev=2, njev=1.
# Optimizing producer 16
# Optimization succeeded (overall 0.00038466695696115494s): nit=0, nfev=2, njev=1.
# Optimizing producer 17
# Optimization succeeded (overall 0.00044408300891518593s): nit=0, nfev=2, njev=1.
# Optimizing producer 18
# Optimization succeeded (overall 0.00041129207238554955s): nit=0, nfev=2, njev=1.
# Optimizing producer 19
# Optimization succeeded (overall 0.00045962492004036903s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.8708577500656247 seconds.
# Total Social Welfare: 70.63403664036741
# Consumer rate change: 2.0513147483892102
# Consumer utility change: 0.08930754446099985%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.15669366646049554
# Producer utility change: 0.4137220165276627%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.00215383293107152s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0004396250005811453s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.00034129107370972633s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.00043008290231227875s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.005671000108122826s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.021594082936644554s): nit=2, nfev=6, njev=3.
# Optimizing producer 6
# Optimization succeeded (overall 0.0031133329030126333s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.005610707914456725s): nit=3, nfev=10, njev=5.
# Optimizing producer 8
# Optimization succeeded (overall 0.006256124936044216s): nit=3, nfev=10, njev=5.
# Optimizing producer 9
# Optimization succeeded (overall 0.007207707967609167s): nit=3, nfev=10, njev=5.
# Optimizing producer 10
# Optimization succeeded (overall 0.0027479580603539944s): nit=3, nfev=10, njev=5.
# Optimizing producer 11
# Optimization succeeded (overall 0.003257500007748604s): nit=3, nfev=10, njev=5.
# Optimizing producer 12
# Optimization succeeded (overall 0.0064717920031398535s): nit=3, nfev=10, njev=5.
# Optimizing producer 13
# Optimization succeeded (overall 0.006408374989405274s): nit=3, nfev=10, njev=5.
# Optimizing producer 14
# Optimization succeeded (overall 0.002576458966359496s): nit=2, nfev=6, njev=3.
# Optimizing producer 15
# Optimization succeeded (overall 0.021042041014879942s): nit=0, nfev=2, njev=1.
# Optimizing producer 16
# Optimization succeeded (overall 0.013137542176991701s): nit=0, nfev=2, njev=1.
# Optimizing producer 17
# Optimization succeeded (overall 0.0034563750959932804s): nit=0, nfev=2, njev=1.
# Optimizing producer 18
# Optimization succeeded (overall 0.010208124993368983s): nit=0, nfev=2, njev=1.
# Optimizing producer 19
# Optimization succeeded (overall 0.0013328329659998417s): nit=0, nfev=2, njev=1.
# Iteration 2 / 100 done in 0.9683882920071483 seconds.
# Total Social Welfare: 70.71693489495972
# Consumer rate change: 0.2690443008201563
# Consumer utility change: 0.0011722543018922618%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.010850476889001964
# Producer utility change: 0.027915527287079536%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.0007679162081331015s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0004936249461025s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.00045849988237023354s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.0004506248515099287s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0004460001364350319s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.0004407081287354231s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.001767416950315237s): nit=1, nfev=6, njev=3.
# Optimizing producer 7
# Optimization succeeded (overall 0.0016010832041501999s): nit=1, nfev=6, njev=3.
# Optimizing producer 8
# Optimization succeeded (overall 0.0028249581810086966s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.0027175829745829105s): nit=2, nfev=8, njev=4.
# Optimizing producer 10
# Optimization succeeded (overall 0.0024765830021351576s): nit=2, nfev=8, njev=4.
# Optimizing producer 11
# Optimization succeeded (overall 0.002394125098362565s): nit=2, nfev=8, njev=4.
# Optimizing producer 12
# Optimization succeeded (overall 0.00174625008367002s): nit=1, nfev=6, njev=3.
# Optimizing producer 13
# Optimization succeeded (overall 0.0014437090139836073s): nit=1, nfev=6, njev=3.
# Optimizing producer 14
# Optimization succeeded (overall 0.00046104216016829014s): nit=0, nfev=2, njev=1.
# Optimizing producer 15
# Optimization succeeded (overall 0.000465666176751256s): nit=0, nfev=2, njev=1.
# Optimizing producer 16
# Optimization succeeded (overall 0.000464125070720911s): nit=0, nfev=2, njev=1.
# Optimizing producer 17
# Optimization succeeded (overall 0.0004229580517858267s): nit=0, nfev=2, njev=1.
# Optimizing producer 18
# Optimization succeeded (overall 0.0004377500154078007s): nit=0, nfev=2, njev=1.
# Optimizing producer 19
# Optimization succeeded (overall 0.0004380829632282257s): nit=0, nfev=2, njev=1.
# Iteration 3 / 100 done in 0.440377457998693 seconds.
# Total Social Welfare: 70.71740699514825
# Consumer rate change: 0.01812484124037551
# Consumer utility change: 6.675867725490347e-06%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0006740091709997922
# Producer utility change: 0.00024860259204359856%
# Converged. Optimization took 4.726336957886815 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing influencer 2
# Optimizing producer 0
# Optimization succeeded (overall 0.0009010829962790012s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0007468340918421745s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 0.006287874886766076 seconds.
# Total Social Welfare: 5.452099172529587
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing influencer 2
# Optimizing producer 0
# Optimization succeeded (overall 0.0007267910987138748s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0007240418344736099s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.002498375019058585 seconds.
# Total Social Welfare: 5.452099172529587
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.010292459046468139 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.002219125162810087s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0027817499358206987s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.004807749995961785s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.0066792918369174s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.006342458073049784s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 0.07164995884522796 seconds.
# Total Social Welfare: 13.839281755534682
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.0010604579001665115s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0011254169512540102s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0009094169363379478s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.0009235420729964972s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0009504170157015324s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.011238249950110912 seconds.
# Total Social Welfare: 13.839281755534682
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.08800570899620652 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.005302333971485496s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.004782999865710735s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.006188708124682307s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.004938459023833275s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.004767999984323978s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.004509166814386845s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.008729707915335894s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.01258291699923575s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.00688908388838172s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.004699833923950791s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 0.3795219580642879 seconds.
# Total Social Welfare: 27.835647440135222
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0033113330136984587s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0044274169486016035s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.002482083160430193s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.0031873330008238554s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.002472999971359968s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.0022097909823060036s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.002182584023103118s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.0022936249151825905s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.0022494171280413866s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.0021745420526713133s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.05602658400312066 seconds.
# Total Social Welfare: 27.835647440135222
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.46132416697219014 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.018496125005185604s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.01761879213154316s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.01776750013232231s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.017863209126517177s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.017935709096491337s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.03226758283562958s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.022096874890848994s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.02211004216223955s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.018013959052041173s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.017407916951924562s): nit=0, nfev=2, njev=1.
# Optimizing producer 10
# Optimization succeeded (overall 0.017433375120162964s): nit=0, nfev=2, njev=1.
# Optimizing producer 11
# Optimization succeeded (overall 0.017472125124186277s): nit=0, nfev=2, njev=1.
# Optimizing producer 12
# Optimization succeeded (overall 0.0176144998986274s): nit=0, nfev=2, njev=1.
# Optimizing producer 13
# Optimization succeeded (overall 0.017350625013932586s): nit=0, nfev=2, njev=1.
# Optimizing producer 14
# Optimization succeeded (overall 0.017468833131715655s): nit=0, nfev=2, njev=1.
# Optimizing producer 15
# Optimization succeeded (overall 0.022329333005473018s): nit=0, nfev=2, njev=1.
# Optimizing producer 16
# Optimization succeeded (overall 0.027843249961733818s): nit=0, nfev=2, njev=1.
# Optimizing producer 17
# Optimization succeeded (overall 0.05871391715481877s): nit=0, nfev=2, njev=1.
# Optimizing producer 18
# Optimization succeeded (overall 0.028190458891913295s): nit=0, nfev=2, njev=1.
# Optimizing producer 19
# Optimization succeeded (overall 0.03407137515023351s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 2.621121458010748 seconds.
# Total Social Welfare: 56.15019595607533
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.014693249948322773s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.012971333926543593s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.00994000001810491s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.010772957932204008s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.01372375013306737s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.014186749933287501s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.012252290965989232s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.011156999971717596s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.010102374944835901s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.010106541914865375s): nit=0, nfev=2, njev=1.
# Optimizing producer 10
# Optimization succeeded (overall 0.009786957874894142s): nit=0, nfev=2, njev=1.
# Optimizing producer 11
# Optimization succeeded (overall 0.009779584128409624s): nit=0, nfev=2, njev=1.
# Optimizing producer 12
# Optimization succeeded (overall 0.00975808291696012s): nit=0, nfev=2, njev=1.
# Optimizing producer 13
# Optimization succeeded (overall 0.010107124922797084s): nit=0, nfev=2, njev=1.
# Optimizing producer 14
# Optimization succeeded (overall 0.010047791991382837s): nit=0, nfev=2, njev=1.
# Optimizing producer 15
# Optimization succeeded (overall 0.009820041945204139s): nit=0, nfev=2, njev=1.
# Optimizing producer 16
# Optimization succeeded (overall 0.009500624844804406s): nit=0, nfev=2, njev=1.
# Optimizing producer 17
# Optimization succeeded (overall 0.009608791908249259s): nit=0, nfev=2, njev=1.
# Optimizing producer 18
# Optimization succeeded (overall 0.009491666918620467s): nit=0, nfev=2, njev=1.
# Optimizing producer 19
# Optimization succeeded (overall 0.009607000043615699s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.3760082090739161 seconds.
# Total Social Welfare: 56.15019595607533
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 3.330945499939844 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing influencer 2
# Optimizing producer 0
# Optimization succeeded (overall 0.0007709590718150139s): nit=5, nfev=12, njev=6.
# Optimizing producer 1
# Optimization succeeded (overall 0.0007229167968034744s): nit=5, nfev=12, njev=6.
# Iteration 0 / 100 done in 0.008445374900475144 seconds.
# Total Social Welfare: 5.463935615798042
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing influencer 2
# Optimizing producer 0
# Optimization succeeded (overall 0.00019212509505450726s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.00018120813183486462s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.003459916915744543 seconds.
# Total Social Welfare: 5.464374186995902
# Consumer rate change: 0.1413514253940598
# Consumer utility change: 8.02600668129925e-05%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.06482130119487858%
# Converged. Optimization took 0.012418291065841913 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.002898833015933633s): nit=5, nfev=20, njev=10.
# Optimizing producer 1
# Optimization succeeded (overall 0.0025962910149246454s): nit=5, nfev=18, njev=9.
# Optimizing producer 2
# Optimization succeeded (overall 0.0017530829645693302s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.002562625100836158s): nit=5, nfev=18, njev=9.
# Optimizing producer 4
# Optimization succeeded (overall 0.002836667001247406s): nit=5, nfev=20, njev=10.
# Iteration 0 / 100 done in 0.08816579193808138 seconds.
# Total Social Welfare: 14.326619563835493
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.000994750065729022s): nit=2, nfev=6, njev=3.
# Optimizing producer 1
# Optimization succeeded (overall 0.001162166940048337s): nit=5, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.0016212500631809235s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.0010722079314291477s): nit=5, nfev=12, njev=6.
# Optimizing producer 4
# Optimization succeeded (overall 0.0012147089000791311s): nit=4, nfev=10, njev=5.
# Iteration 1 / 100 done in 0.03187370812520385 seconds.
# Total Social Welfare: 14.683788087725478
# Consumer rate change: 0.8635703882090574
# Consumer utility change: 0.024323995969988865%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.22476660770190876
# Producer utility change: 0.32620900284250687%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.00031812512315809727s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.00021783309057354927s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0008897080551832914s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.00024200021289288998s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0012259997893124819s): nit=4, nfev=10, njev=5.
# Iteration 2 / 100 done in 0.032402874901890755 seconds.
# Total Social Welfare: 14.688645796324893
# Consumer rate change: 0.1879770590126955
# Consumer utility change: 0.00033071169481607845%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.009517229592981968
# Producer utility change: 0.027371395512821042%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing influencer 5
# Optimizing producer 0
# Optimization succeeded (overall 0.0003958749584853649s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.00021570897661149502s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0007707921322435141s): nit=1, nfev=6, njev=3.
# Optimizing producer 3
# Optimization succeeded (overall 0.00021150009706616402s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0008523750584572554s): nit=2, nfev=6, njev=3.
# Iteration 3 / 100 done in 0.008739750133827329 seconds.
# Total Social Welfare: 14.688650111922454
# Consumer rate change: 0.0
# Consumer utility change: 2.93804812533851e-07%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0004089396980766935
# Producer utility change: 2.5227076244642034e-06%
# Converged. Optimization took 0.16566974995657802 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.005945333978161216s): nit=4, nfev=18, njev=9.
# Optimizing producer 1
# Optimization succeeded (overall 0.006682625040411949s): nit=5, nfev=22, njev=11.
# Optimizing producer 2
# Optimization succeeded (overall 0.005484499968588352s): nit=6, nfev=18, njev=9.
# Optimizing producer 3
# Optimization succeeded (overall 0.004877542145550251s): nit=5, nfev=16, njev=8.
# Optimizing producer 4
# Optimization succeeded (overall 0.004276291001588106s): nit=5, nfev=14, njev=7.
# Optimizing producer 5
# Optimization succeeded (overall 0.004594292026013136s): nit=5, nfev=14, njev=7.
# Optimizing producer 6
# Optimization succeeded (overall 0.00493724993430078s): nit=5, nfev=16, njev=8.
# Optimizing producer 7
# Optimization succeeded (overall 0.006026708986610174s): nit=6, nfev=18, njev=9.
# Optimizing producer 8
# Optimization succeeded (overall 0.008151084184646606s): nit=5, nfev=22, njev=11.
# Optimizing producer 9
# Optimization succeeded (overall 0.017197584034875035s): nit=4, nfev=18, njev=9.
# Iteration 0 / 100 done in 0.6486677080392838 seconds.
# Total Social Welfare: 30.67243450801852
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0005981661379337311s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0022460001055151224s): nit=5, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.002556416904553771s): nit=5, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.003352917032316327s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.003568959189578891s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.002944792155176401s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.002821708098053932s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0034343749284744263s): nit=5, nfev=12, njev=6.
# Optimizing producer 8
# Optimization succeeded (overall 0.003316582879051566s): nit=5, nfev=12, njev=6.
# Optimizing producer 9
# Optimization succeeded (overall 0.0006187090184539557s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.3753522499464452 seconds.
# Total Social Welfare: 32.95475026887262
# Consumer rate change: 1.9474967133965913
# Consumer utility change: 0.06925602681473186%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.22236045300895207
# Producer utility change: 0.41695496228278006%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0016901670023798943s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.002864000154659152s): nit=3, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.0013530829455703497s): nit=2, nfev=6, njev=3.
# Optimizing producer 3
# Optimization succeeded (overall 0.0024363750126212835s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.0023897909559309483s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.002592917066067457s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.0021508748177438974s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.001357333967462182s): nit=2, nfev=6, njev=3.
# Optimizing producer 8
# Optimization succeeded (overall 0.0018721248488873243s): nit=3, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.00048741698265075684s): nit=0, nfev=2, njev=1.
# Iteration 2 / 100 done in 0.22932041715830564 seconds.
# Total Social Welfare: 32.98094745695905
# Consumer rate change: 0.25112315273386365
# Consumer utility change: 0.0007943125399138304%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.017056053817119703
# Producer utility change: 0.025143665911157277%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0005952080246061087s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0011957499664276838s): nit=2, nfev=6, njev=3.
# Optimizing producer 2
# Optimization succeeded (overall 0.0009664588142186403s): nit=1, nfev=4, njev=2.
# Optimizing producer 3
# Optimization succeeded (overall 0.0015838751569390297s): nit=1, nfev=6, njev=3.
# Optimizing producer 4
# Optimization succeeded (overall 0.0022041250485926867s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.0020557090174406767s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.001330000115558505s): nit=1, nfev=6, njev=3.
# Optimizing producer 7
# Optimization succeeded (overall 0.0010337079875171185s): nit=1, nfev=4, njev=2.
# Optimizing producer 8
# Optimization succeeded (overall 0.0016448330134153366s): nit=2, nfev=6, njev=3.
# Optimizing producer 9
# Optimization succeeded (overall 0.00047483318485319614s): nit=0, nfev=2, njev=1.
# Iteration 3 / 100 done in 0.08458637492731214 seconds.
# Total Social Welfare: 32.98108168618475
# Consumer rate change: 0.010167672993476842
# Consumer utility change: 4.069884253024655e-06%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0011153663833345987
# Producer utility change: 0.00048736019462098024%
# Converged. Optimization took 1.372679041000083 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.012882125098258257s): nit=4, nfev=20, njev=10.
# Optimizing producer 1
# Optimization succeeded (overall 0.010777791030704975s): nit=4, nfev=18, njev=9.
# Optimizing producer 2
# Optimization succeeded (overall 0.01260537514463067s): nit=5, nfev=20, njev=10.
# Optimizing producer 3
# Optimization succeeded (overall 0.01275712507776916s): nit=5, nfev=20, njev=10.
# Optimizing producer 4
# Optimization succeeded (overall 0.01285375002771616s): nit=5, nfev=20, njev=10.
# Optimizing producer 5
# Optimization succeeded (overall 0.01249254192225635s): nit=5, nfev=20, njev=10.
# Optimizing producer 6
# Optimization succeeded (overall 0.010439042001962662s): nit=5, nfev=14, njev=7.
# Optimizing producer 7
# Optimization succeeded (overall 0.01619091583415866s): nit=6, nfev=20, njev=10.
# Optimizing producer 8
# Optimization succeeded (overall 0.011432584142312407s): nit=5, nfev=16, njev=8.
# Optimizing producer 9
# Optimization succeeded (overall 0.01036391593515873s): nit=5, nfev=14, njev=7.
# Optimizing producer 10
# Optimization succeeded (overall 0.008419707883149385s): nit=5, nfev=14, njev=7.
# Optimizing producer 11
# Optimization succeeded (overall 0.009853374911472201s): nit=5, nfev=16, njev=8.
# Optimizing producer 12
# Optimization succeeded (overall 0.012398332823067904s): nit=6, nfev=20, njev=10.
# Optimizing producer 13
# Optimization succeeded (overall 0.009050791850313544s): nit=5, nfev=14, njev=7.
# Optimizing producer 14
# Optimization succeeded (overall 0.012434541014954448s): nit=5, nfev=20, njev=10.
# Optimizing producer 15
# Optimization succeeded (overall 0.012700834078714252s): nit=5, nfev=20, njev=10.
# Optimizing producer 16
# Optimization succeeded (overall 0.01263591693714261s): nit=5, nfev=20, njev=10.
# Optimizing producer 17
# Optimization succeeded (overall 0.012610041070729494s): nit=5, nfev=20, njev=10.
# Optimizing producer 18
# Optimization succeeded (overall 0.011004250030964613s): nit=4, nfev=18, njev=9.
# Optimizing producer 19
# Optimization succeeded (overall 0.012095833895727992s): nit=4, nfev=20, njev=10.
# Iteration 0 / 100 done in 4.143732042051852 seconds.
# Total Social Welfare: 64.32589413053196
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.0008534169755876064s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0006991249974817038s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0007378330919891596s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.0007100838702172041s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0007869591936469078s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.005661166971549392s): nit=6, nfev=14, njev=7.
# Optimizing producer 6
# ...
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 492.95316037512384s): nit=2, nfev=112, njev=56.
# Optimizing producer 14
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 433.61150187510066s): nit=2, nfev=82, njev=41.
# Optimizing producer 15
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 438.8062764587812s): nit=1, nfev=94, njev=47.
# Optimizing producer 16
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 775.0088022081181s): nit=1, nfev=96, njev=48.
# Optimizing producer 17
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 496.751745125046s): nit=1, nfev=70, njev=35.
# Optimizing producer 18
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 434.6219043340534s): nit=1, nfev=82, njev=41.
# Optimizing producer 19
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 850.4343826249242s): nit=1, nfev=100, njev=50.
# Iteration 7 / 100 done in 8625.039184832945 seconds.
# Total Social Welfare: 188.93308438776785
# Consumer rate change: 0.10190314243141704
# Consumer utility change: 0.053299030868798385%
# Influencer rate change: 2.986582000480106
# Influencer utility change: 0.07280655449890322%
# Producer topic change: 0.10561290741932608
# Producer utility change: 0.0017697934921077553%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 647.4829612909816s): nit=1, nfev=114, njev=57.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 335.99066212493926s): nit=2, nfev=90, njev=45.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 302.88693641591817s): nit=1, nfev=62, njev=31.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 487.4590635409113s): nit=3, nfev=132, njev=66.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 485.00089733302593s): nit=1, nfev=102, njev=51.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 307.86436258303s): nit=1, nfev=68, njev=34.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 460.6439319169149s): nit=1, nfev=96, njev=48.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 761.4318027910776s): nit=2, nfev=174, njev=87.
# Optimizing producer 8
# Optimization succeeded (overall 66.45139741594903s): nit=2, nfev=32, njev=16.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 413.7313587090466s): nit=1, nfev=86, njev=43.
# Optimizing producer 10
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 463.4125772078987s): nit=1, nfev=46, njev=23.
# Optimizing producer 11
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 372.8261300830636s): nit=1, nfev=60, njev=30.
# Optimizing producer 12
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 449.76010595913976s): nit=4, nfev=192, njev=96.
# Optimizing producer 13
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 364.15196637506597s): nit=1, nfev=82, njev=41.
# Optimizing producer 14
# Optimization succeeded (overall 173.90294599998742s): nit=4, nfev=86, njev=43.
# Optimizing producer 15
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 673.8330593749415s): nit=3, nfev=164, njev=82.
# Optimizing producer 16
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 338.79111587512307s): nit=1, nfev=86, njev=43.
# Optimizing producer 17
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 305.4188972080592s): nit=1, nfev=102, njev=51.
# Optimizing producer 18
# Optimization succeeded (overall 157.2654432079289s): nit=4, nfev=74, njev=37.
# Optimizing producer 19
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 498.5466007918585s): nit=2, nfev=140, njev=70.
# Iteration 8 / 100 done in 8070.092144540977 seconds.
# Total Social Welfare: 195.4429570040537
# Consumer rate change: 0.19291576603757116
# Consumer utility change: 0.03330829644572396%
# Influencer rate change: 3.793019444445061
# Influencer utility change: 0.04636286222611435%
# Producer topic change: 0.13904946740695429
# Producer utility change: 0.004979963460617757%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 442.28462141705677s): nit=1, nfev=86, njev=43.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 492.91487891599536s): nit=1, nfev=88, njev=44.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 514.7267877080012s): nit=1, nfev=98, njev=49.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 597.2260188329965s): nit=2, nfev=142, njev=71.
# Optimizing producer 4
# Optimization succeeded (overall 166.86905141710304s): nit=2, nfev=68, njev=34.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 487.5400913329795s): nit=1, nfev=54, njev=27.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 654.6056231670082s): nit=2, nfev=182, njev=91.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 584.4095580419526s): nit=1, nfev=44, njev=22.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 394.8560670840088s): nit=1, nfev=44, njev=22.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 499.1317681251094s): nit=1, nfev=78, njev=39.
# Optimizing producer 10
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 449.0212795420084s): nit=1, nfev=98, njev=49.
# Optimizing producer 11
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 660.7738926671445s): nit=2, nfev=140, njev=70.
# Optimizing producer 12
# Optimization succeeded (overall 145.4469617079012s): nit=3, nfev=68, njev=34.
# Optimizing producer 13
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 510.3024317091331s): nit=4, nfev=132, njev=66.
# Optimizing producer 14
# Optimization succeeded (overall 130.84001291613095s): nit=3, nfev=62, njev=31.
# Optimizing producer 15
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 480.411874209065s): nit=1, nfev=84, njev=42.
# Optimizing producer 16
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 439.5797713329084s): nit=1, nfev=90, njev=45.
# Optimizing producer 17
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 511.67125212517567s): nit=2, nfev=104, njev=52.
# Optimizing producer 18
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 349.9934679172002s): nit=2, nfev=80, njev=40.
# Optimizing producer 19
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 394.71024183300324s): nit=1, nfev=92, njev=46.
# Iteration 9 / 100 done in 8912.533455083147 seconds.
# Total Social Welfare: 200.86119771596267
# Consumer rate change: 0.09166342422717684
# Consumer utility change: 0.02697504661935743%
# Influencer rate change: 4.128728878585997
# Influencer utility change: 0.03641961438561887%
# Producer topic change: 0.048318519752880554
# Producer utility change: 0.0023387941396349732%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 170.99278045794927s): nit=2, nfev=96, njev=48.
# Optimizing producer 1
# Optimization succeeded (overall 97.33600725000724s): nit=3, nfev=54, njev=27.
# Optimizing producer 2
# Optimization succeeded (overall 109.1005453329999s): nit=4, nfev=60, njev=30.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 340.74013870814815s): nit=1, nfev=70, njev=35.
# Optimizing producer 4
# Optimization succeeded (overall 150.05578725016676s): nit=4, nfev=82, njev=41.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 173.85714412503876s): nit=1, nfev=56, njev=28.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 377.39260795805603s): nit=1, nfev=94, njev=47.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 336.8556709999684s): nit=1, nfev=66, njev=33.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 431.2033124580048s): nit=1, nfev=58, njev=29.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 379.434372499818s): nit=2, nfev=84, njev=42.
# Optimizing producer 10
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 369.9175822918769s): nit=1, nfev=96, njev=48.
# Optimizing producer 11
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 457.18916349997744s): nit=1, nfev=86, njev=43.
# Optimizing producer 12
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 539.3316094579641s): nit=1, nfev=56, njev=28.
# Optimizing producer 13
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 262.309661709005s): nit=3, nfev=78, njev=39.
# Optimizing producer 14
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 455.60871295793913s): nit=2, nfev=124, njev=62.
# Optimizing producer 15
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 380.0029992079362s): nit=2, nfev=114, njev=57.
# Optimizing producer 16
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 445.73489125003107s): nit=2, nfev=128, njev=64.
# Optimizing producer 17
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 397.98518058285117s): nit=1, nfev=96, njev=48.
# Optimizing producer 18
# Optimization succeeded (overall 207.33052837499417s): nit=5, nfev=94, njev=47.
# Optimizing producer 19
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 249.33324708393775s): nit=1, nfev=58, njev=29.
# Iteration 10 / 100 done in 6334.73484345898 seconds.
# Total Social Welfare: 200.92243216309956
# Consumer rate change: 0.06816940238458889
# Consumer utility change: 0.0003047665727630568%
# Influencer rate change: 1.654362794635115
# Influencer utility change: 0.0017077626695888729%
# Producer topic change: 5.187622490463936e-06
# Producer utility change: 0.0%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing consumer 15
# Optimizing consumer 16
# Optimizing consumer 17
# Optimizing consumer 18
# Optimizing consumer 19
# Optimizing influencer 20
# Optimizing producer 0
# Optimization succeeded (overall 0.286044874927029s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.27717016683891416s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.33994754194281995s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.6877184167969972s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.5204706669319421s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.4750097910873592s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.3889942078385502s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.3445524999406189s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.2637746660038829s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.26401829114183784s): nit=0, nfev=2, njev=1.
# Optimizing producer 10
# Optimization succeeded (overall 0.29166195914149284s): nit=0, nfev=2, njev=1.
# Optimizing producer 11
# Optimization succeeded (overall 0.363701457856223s): nit=0, nfev=2, njev=1.
# Optimizing producer 12
# Optimization succeeded (overall 0.33691075001843274s): nit=0, nfev=2, njev=1.
# Optimizing producer 13
# Optimization succeeded (overall 0.2824793749023229s): nit=0, nfev=2, njev=1.
# Optimizing producer 14
# Optimization succeeded (overall 0.3462188341654837s): nit=0, nfev=2, njev=1.
# Optimizing producer 15
# Optimization succeeded (overall 0.2785048340447247s): nit=0, nfev=2, njev=1.
# Optimizing producer 16
# Optimization succeeded (overall 0.28553816699422896s): nit=0, nfev=2, njev=1.
# Optimizing producer 17
# Optimization succeeded (overall 0.3631222080439329s): nit=0, nfev=2, njev=1.
# Optimizing producer 18
# Optimization succeeded (overall 0.32417733292095363s): nit=0, nfev=2, njev=1.
# Optimizing producer 19
# Optimization succeeded (overall 0.29896112508140504s): nit=0, nfev=2, njev=1.
# Iteration 11 / 100 done in 7.468800166156143 seconds.
# Total Social Welfare: 200.92243216309956
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 100382.8157851249 seconds.

# %%
second_param_stats = {}
for i in range(len(second_param_values)):
    second_param_value = second_param_values[i]
    second_param_stats[second_param_value] = {
        'perfect': [first_param_stats[first_param_value]['perfect'][i] for first_param_value in first_param_values],
        'imperfect': [first_param_stats[first_param_value]['imperfect'][i] for first_param_value in first_param_values]
    }

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Total Social Welfare By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Total Social Welfare')
    perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, perfect_social_welfares, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Total Social Welfare By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Total Social Welfare')
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, imperfect_social_welfares, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Total Social Welfare By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Total Social Welfare')
    perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, perfect_social_welfares, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Total Social Welfare By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Total Social Welfare')
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, imperfect_social_welfares, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Cost of Influence By {second_param_x_label}')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Cost of Influence (%)')
        perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]

        costs_of_influence = [(perfect_social_welfare - imperfect_social_welfare) / perfect_social_welfare * 100 for imperfect_social_welfare, perfect_social_welfare in zip(imperfect_social_welfares, perfect_social_welfares)]
        plt.plot(second_param_values, costs_of_influence, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Cost of Influence By {first_param_x_label}')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Cost of Influence (%)')
        perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]

        costs_of_influence = [(perfect_social_welfare - imperfect_social_welfare) / perfect_social_welfare * 100 for imperfect_social_welfare, perfect_social_welfare in zip(imperfect_social_welfares, perfect_social_welfares)]
        plt.plot(first_param_values, costs_of_influence, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-Influencer Follow Proportion By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_influencer_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Average Consumer-Influencer Follow Proportion By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_influencer_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-Influencer Following Rates By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Following rate (%)')
    follow_proportions = [test.average_influencer_follow_proportion[-1] * 100 for test in perfect_info_stats]
    plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Average Consumer-Influencer Following Rates By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Following rate (%)')
        follow_proportions = [test.average_influencer_follow_proportion[-1] * 100 for test in imperfect_info_stats]
        plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-External Follow Proportion By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_external_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Average Consumer-External Follow Proportion By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_external_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-External Follow Proportion By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_external_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Average Consumer-External Follow Proportion By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_external_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_diff = np.linalg.norm(perfect_consumer_stat.following_rates[-1] - imperfect_consumer_stat.following_rates[-1]) / np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * 100
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(second_param_values, avg_follow_rate_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_diff = np.linalg.norm(perfect_consumer_stat.following_rates[-1] - imperfect_consumer_stat.following_rates[-1]) / np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * 100
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(first_param_values, avg_follow_rate_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0:
                    continue
                ending_follow_rate_diff = np.linalg.norm(perfect_influencer_stat.following_rates[-1] - imperfect_influencer_stat.following_rates[-1]) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(second_param_values, avg_follow_rate_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0:
                    continue
                ending_follow_rate_diff = np.linalg.norm(perfect_influencer_stat.following_rates[-1] - imperfect_influencer_stat.following_rates[-1]) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(first_param_values, avg_follow_rate_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Producer Topic Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Topic Difference (% of topic space)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_topic_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            topic_space_size = perfect_stat.market.topics_bounds[0][1] - perfect_stat.market.topics_bounds[0][0]

            avg_topic_diff = 0

            for index in perfect_stat.producer_stats:
                perfect_producer_stat = perfect_stat.producer_stats[index]
                imperfect_producer_stat = imperfect_stat.producer_stats[index]

                # if perfect_producer_stat.topics[-1] == 0:
                #     continue

                ending_topic_diff = np.linalg.norm(perfect_producer_stat.topics[-1] - imperfect_producer_stat.topics[-1]) / topic_space_size * 100
                avg_topic_diff += ending_topic_diff
            
            avg_topic_diff /= len(perfect_stat.producer_stats)
            avg_topic_diffs.append(avg_topic_diff)
        
        plt.plot(second_param_values, avg_topic_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Producer Topic Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Topic Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_topic_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_topic_diff = 0

            for index in perfect_stat.producer_stats:
                perfect_producer_stat = perfect_stat.producer_stats[index]
                imperfect_producer_stat = imperfect_stat.producer_stats[index]

                # if perfect_producer_stat.topics[-1] == 0:
                #     continue

                ending_topic_diff = np.linalg.norm(perfect_producer_stat.topics[-1] - imperfect_producer_stat.topics[-1]) #/ (np.linalg.norm(perfect_producer_stat.topics[-1])) * 100
                avg_topic_diff += ending_topic_diff
            
            avg_topic_diff /= len(perfect_stat.producer_stats)
            avg_topic_diffs.append(avg_topic_diff)
        
        plt.plot(first_param_values, avg_topic_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Producer Topic Standard Deviation By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Topic Standard Deviation')
    std_deviations = [test.producer_topic_standard_deviation[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, std_deviations, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Producer Topic Standard Deviation By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Topic Standard Deviation')
        std_deviations = [test.producer_topic_standard_deviation[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, std_deviations, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Producer Topic Standard Deviation By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Topic Standard Deviation')
    std_deviations = [test.producer_topic_standard_deviation[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, std_deviations, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Producer Topic Standard Deviation By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Topic Standard Deviation')
        std_deviations = [test.producer_topic_standard_deviation[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, std_deviations, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Norm Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0:
                    continue

                ending_follow_rate_norm_diff = (np.linalg.norm(imperfect_influencer_stat.following_rates[-1]) - np.linalg.norm(perfect_influencer_stat.following_rates[-1])) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(first_param_values, avg_follow_rate_norm_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    #plt.ylim(-1, 1)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Norm Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0:
                    continue

                ending_follow_rate_norm_diff = (np.linalg.norm(imperfect_influencer_stat.following_rates[-1]) - np.linalg.norm(perfect_influencer_stat.following_rates[-1])) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(second_param_values, avg_follow_rate_norm_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Ending Influencer Follow Rate Cosine Similarity By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Cosine Similarity")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0 or np.linalg.norm(imperfect_influencer_stat.following_rates[-1]) == 0:
                    avg_follow_rate_sim += 1
                    continue

                ending_follow_rate_sim = np.dot(perfect_influencer_stat.following_rates[-1], imperfect_influencer_stat.following_rates[-1]) / (np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * np.linalg.norm(imperfect_influencer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.influencer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(first_param_values, avg_follow_rate_sims, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Ending Influencer Follow Rate Cosine Similarity By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Cosine Similarity")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0 or np.linalg.norm(imperfect_influencer_stat.following_rates[-1]) == 0:
                    avg_follow_rate_sim += 1
                    continue

                ending_follow_rate_sim = np.dot(perfect_influencer_stat.following_rates[-1], imperfect_influencer_stat.following_rates[-1]) / (np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * np.linalg.norm(imperfect_influencer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.influencer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(second_param_values, avg_follow_rate_sims, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Norm Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_norm_diff = (np.linalg.norm(imperfect_consumer_stat.following_rates[-1]) - np.linalg.norm(perfect_consumer_stat.following_rates[-1])) / np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(first_param_values, avg_follow_rate_norm_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Norm Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_norm_diff = (np.linalg.norm(imperfect_consumer_stat.following_rates[-1]) - np.linalg.norm(perfect_consumer_stat.following_rates[-1])) / np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(second_param_values, avg_follow_rate_norm_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Cosine Similarity By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Cosine Similarity")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_sim = np.dot(perfect_consumer_stat.following_rates[-1], imperfect_consumer_stat.following_rates[-1]) / (np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * np.linalg.norm(imperfect_consumer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.consumer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(first_param_values, avg_follow_rate_sims, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Cosine Similarity By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Cosine Similarity")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_sim = np.dot(perfect_consumer_stat.following_rates[-1], imperfect_consumer_stat.following_rates[-1]) / (np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * np.linalg.norm(imperfect_consumer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.consumer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(second_param_values, avg_follow_rate_sims, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()
