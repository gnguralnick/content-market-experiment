# %%
import numpy as np
from test import test
from util import inverse_decay
import matplotlib.pyplot as plt
import visualize
from stats import *
from agents import *

# %%
topics = np.array([[-1, 1]])

# %%
first_param = 'influencer_attention_bound'
first_param_legend_label = 'Influencer Attention Bound'
first_param_x_label = 'Influencer Attention Bound'
first_param_values = [0, 1, 7, 15, 30, 80, 150]

# %%
second_param = 'consumer_attention_bound'
second_param_legend_label = 'Consumer Attention Bound'
second_param_x_label = 'Consumer Attention Bound'
second_param_values = [0, 1, 7, 15, 30, 80, 150]

# %%
num_influencers = 1

# %%
test_imperfect = True

# %%
first_param_stats = {}

for first_param_value in first_param_values:
    perfect_info_stats, imperfect_info_stats = test(
        topics=topics,
        varied_param=second_param,
        num_influencers=num_influencers,
        num_agents=10,
        producer_topic_interest_func=lambda x: inverse_decay(x, 0.5, 2),
        consumer_topic_interest_func=lambda x: inverse_decay(x, 0.5, 2),
        agent_topic_interest_func=None,
        consumer_attention_bound=second_param_values,
        consumer_external_interest_prob=3,
        consumer_delay_sensitivity=1,
        influencer_attention_bound=first_param_value,
        influencer_delay_sensitivity=1,
        init_following_rates_method='equal',
        init_interest_method='even',
        init_topic_produced_method='farthest',
        production_rate=1,
        external_production_rate=1,
        use_imperfect_information=test_imperfect,
    )
    first_param_stats[first_param_value] = {
        'perfect': perfect_info_stats,
        'imperfect': imperfect_info_stats
    }
# Out:
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.00020341691561043262s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.00013516598846763372s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.00013108295388519764s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.00012058299034833908s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.00011825002729892731s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.00012387498281896114s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.00011816597543656826s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.00011666608043015003s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.00011941709090024233s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.00011841603554785252s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 0.027492083027027547 seconds.
# Total Social Welfare: 0
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0001634169602766633s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.00013591605238616467s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0001289580250158906s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.0001212080242112279s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0001177079975605011s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.00012600002810359s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.00011800008360296488s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.00011666689533740282s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.00011541706044226885s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.00011887506116181612s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.0187811671057716 seconds.
# Total Social Welfare: 0
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.04719233303330839 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0007762090535834432s): nit=1, nfev=4, njev=2.
# Optimizing producer 1
# Optimization succeeded (overall 0.0008466250728815794s): nit=1, nfev=4, njev=2.
# Optimizing producer 2
# Optimization succeeded (overall 0.000714167021214962s): nit=1, nfev=4, njev=2.
# Optimizing producer 3
# Optimization succeeded (overall 0.0007150829769670963s): nit=1, nfev=4, njev=2.
# Optimizing producer 4
# Optimization succeeded (overall 0.0007142500253394246s): nit=1, nfev=4, njev=2.
# Optimizing producer 5
# Optimization succeeded (overall 0.0007081250660121441s): nit=1, nfev=4, njev=2.
# Optimizing producer 6
# Optimization succeeded (overall 0.0007082080701366067s): nit=1, nfev=4, njev=2.
# Optimizing producer 7
# Optimization succeeded (overall 0.0007068329723551869s): nit=1, nfev=4, njev=2.
# Optimizing producer 8
# Optimization succeeded (overall 0.0007103329990059137s): nit=1, nfev=4, njev=2.
# Optimizing producer 9
# Optimization succeeded (overall 0.001760208047926426s): nit=1, nfev=4, njev=2.
# Iteration 0 / 100 done in 0.11183929198887199 seconds.
# Total Social Welfare: 11.036383235143267
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0004133750917389989s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.0003427499905228615s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0002621660241857171s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.000299665960483253s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.0002886250149458647s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.0005266249645501375s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.00038358394522219896s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.0008159159915521741s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.00030625006183981895s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.0004176250658929348s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.021797167020849884 seconds.
# Total Social Welfare: 11.036383235143267
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.13931670901365578 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0033258750336244702s): nit=4, nfev=20, njev=10.
# Optimizing producer 1
# Optimization succeeded (overall 0.0029424160020425916s): nit=4, nfev=18, njev=9.
# Optimizing producer 2
# Optimization succeeded (overall 0.003234375035390258s): nit=5, nfev=20, njev=10.
# Optimizing producer 3
# Optimization succeeded (overall 0.007270458037965s): nit=5, nfev=18, njev=9.
# Optimizing producer 4
# Optimization succeeded (overall 0.006270500016398728s): nit=5, nfev=16, njev=8.
# Optimizing producer 5
# Optimization succeeded (overall 0.0026869160356000066s): nit=5, nfev=16, njev=8.
# Optimizing producer 6
# Optimization succeeded (overall 0.002947916043922305s): nit=5, nfev=18, njev=9.
# Optimizing producer 7
# Optimization succeeded (overall 0.0032490829471498728s): nit=5, nfev=20, njev=10.
# Optimizing producer 8
# Optimization succeeded (overall 0.002907833084464073s): nit=4, nfev=18, njev=9.
# Optimizing producer 9
# Optimization succeeded (overall 0.003228166955523193s): nit=4, nfev=20, njev=10.
# Iteration 0 / 100 done in 0.4858031660551205 seconds.
# Total Social Welfare: 26.983246402785465
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.
): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 283.0632777499268 seconds.
# Total Social Welfare: 62.32215904095451
# Consumer rate change: 11.0451659342798
# Consumer utility change: 0.03174518055084539%
# Influencer rate change: 22.505726832666273
# Influencer utility change: 0.026582684182280998%
# Producer topic change: 1.8282596154939323e-06
# Producer utility change: 0.0%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.031616541906259954s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.04295975004788488s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.030378167051821947s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.030375916976481676s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.030569042079150677s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.030663708923384547s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.030582915991544724s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.03058366698678583s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.04169166600331664s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.031150666996836662s): nit=0, nfev=2, njev=1.
# Iteration 2 / 100 done in 0.38257870892994106 seconds.
# Total Social Welfare: 62.32215904095451
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 532.2276089580264 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.254063457949087s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 5.701908207964152s): nit=2, nfev=40, njev=20.
# Optimizing producer 2
# Optimization succeeded (overall 3.7311705000465736s): nit=1, nfev=30, njev=15.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 71.49060041701887s): nit=1, nfev=76, njev=38.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 46.32851941592526s): nit=2, nfev=146, njev=73.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 64.44894845795352s): nit=1, nfev=90, njev=45.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 59.391875667031854s): nit=1, nfev=78, njev=39.
# Optimizing producer 7
# Optimization succeeded (overall 0.5577981249662116s): nit=1, nfev=4, njev=2.
# Optimizing producer 8
# Optimization succeeded (overall 0.25607020896859467s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.25508299993816763s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 253.3445171250496 seconds.
# Total Social Welfare: 70.09233118653839
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 11.696746709058061s): nit=2, nfev=54, njev=27.
# Optimizing producer 1
# Optimization succeeded (overall 0.42764158302452415s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 56.7125284159556s): nit=1, nfev=84, njev=42.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 27.964616125100292s): nit=1, nfev=60, njev=30.
# Optimizing producer 4
# Optimization succeeded (overall 23.499514790950343s): nit=5, nfev=114, njev=57.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 16.526607083971612s): nit=1, nfev=42, njev=21.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 78.6930684580002s): nit=3, nfev=218, njev=109.
# Optimizing producer 7
# Optimization succeeded (overall 0.42426179198082536s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.42134783300571144s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 62.76888779096771s): nit=2, nfev=152, njev=76.
# Iteration 1 / 100 done in 280.9400229169987 seconds.
# Total Social Welfare: 73.04263843062716
# Consumer rate change: 24.039199384361478
# Consumer utility change: 0.04039156995917035%
# Influencer rate change: 18.080113943466248
# Influencer utility change: 0.06043997169173261%
# Producer topic change: 0.049627051811238665
# Producer utility change: 0.0008075425393819216%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.5573767500463873s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 117.35338283295278s): nit=4, nfev=168, njev=84.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 52.69525733299088s): nit=1, nfev=98, njev=49.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 83.53385691705626s): nit=1, nfev=60, njev=30.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 45.75325683399569s): nit=1, nfev=86, njev=43.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 44.272085750009865s): nit=1, nfev=52, njev=26.
# Optimizing producer 6
# Optimization succeeded (overall 16.234653917024843s): nit=2, nfev=58, njev=29.
# Optimizing producer 7
# Optimization succeeded (overall 0.5695440419949591s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 45.52414550003596s): nit=1, nfev=48, njev=24.
# Optimizing producer 9
# Optimization succeeded (overall 0.574273084057495s): nit=0, nfev=2, njev=1.
# Iteration 2 / 100 done in 407.65480408398435 seconds.
# Total Social Welfare: 87.50922263799984
# Consumer rate change: 2.4699027759520984
# Consumer utility change: 0.1653149475920642%
# Influencer rate change: 4.52344921185727
# Influencer utility change: 0.2583028525901139%
# Producer topic change: 0.3488592921674772
# Producer utility change: 0.0028185524676059507%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 16.34712837508414s): nit=1, nfev=40, njev=20.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 62.29465620801784s): nit=1, nfev=76, njev=38.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 119.23164825001732s): nit=3, nfev=194, njev=97.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 74.569808500004s): nit=2, nfev=140, njev=70.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 93.97120770905167s): nit=3, nfev=144, njev=72.
# Optimizing producer 5
# Optimization succeeded (overall 14.243394958088174s): nit=1, nfev=34, njev=17.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 65.18690424994566s): nit=2, nfev=118, njev=59.
# Optimizing producer 7
# Optimization succeeded (overall 15.686246917000972s): nit=2, nfev=38, njev=19.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 86.50560041703284s): nit=1, nfev=86, njev=43.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 39.0469848329667s): nit=1, nfev=54, njev=27.
# Iteration 3 / 100 done in 588.7209546670783 seconds.
# Total Social Welfare: 88.84884462909805
# Consumer rate change: 12.433518923303819
# Consumer utility change: 0.015077538103225726%
# Influencer rate change: 16.103998964678627
# Influencer utility change: 0.00890773499312216%
# Producer topic change: 2.607426340731772e-06
# Producer utility change: 0.0%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.034802707959897816s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.03536712494678795s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.03082575008738786s): nit=0, nfev=2, njev=1.
# Optimizing producer 3
# Optimization succeeded (overall 0.030553958960808814s): nit=0, nfev=2, njev=1.
# Optimizing producer 4
# Optimization succeeded (overall 0.030630707973614335s): nit=0, nfev=2, njev=1.
# Optimizing producer 5
# Optimization succeeded (overall 0.030459083034656942s): nit=0, nfev=2, njev=1.
# Optimizing producer 6
# Optimization succeeded (overall 0.030480582965537906s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization succeeded (overall 0.03547924989834428s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.034733207896351814s): nit=0, nfev=2, njev=1.
# Optimizing producer 9
# Optimization succeeded (overall 0.03250866604503244s): nit=0, nfev=2, njev=1.
# Iteration 4 / 100 done in 0.3777290410362184 seconds.
# Total Social Welfare: 88.84884462909805
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 1540.6933042079909 seconds.

# %%
second_param_stats = {}
for i in range(len(second_param_values)):
    second_param_value = second_param_values[i]
    second_param_stats[second_param_value] = {
        'perfect': [first_param_stats[first_param_value]['perfect'][i] for first_param_value in first_param_values],
        'imperfect': [first_param_stats[first_param_value]['imperfect'][i] for first_param_value in first_param_values]
    }

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Total Social Welfare By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Total Social Welfare')
    perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, perfect_social_welfares, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Total Social Welfare By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Total Social Welfare')
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, imperfect_social_welfares, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Total Social Welfare By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Total Social Welfare')
    perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, perfect_social_welfares, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Total Social Welfare By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Total Social Welfare')
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, imperfect_social_welfares, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Cost of Influence By {second_param_x_label}')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Cost of Influence (%)')
        perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]

        costs_of_influence = []
        for imperfect_social_welfare, perfect_social_welfare in zip(imperfect_social_welfares, perfect_social_welfares):
            if perfect_social_welfare == 0:
                costs_of_influence.append(0)
            else:
                costs_of_influence.append((perfect_social_welfare - imperfect_social_welfare) / perfect_social_welfare * 100)
        plt.plot(second_param_values, costs_of_influence, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Cost of Influence By {first_param_x_label}')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Cost of Influence (%)')
        perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]

        costs_of_influence = []
        for imperfect_social_welfare, perfect_social_welfare in zip(imperfect_social_welfares, perfect_social_welfares):
            if perfect_social_welfare == 0:
                costs_of_influence.append(0)
            else:
                costs_of_influence.append((perfect_social_welfare - imperfect_social_welfare) / perfect_social_welfare * 100)
        plt.plot(first_param_values, costs_of_influence, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-Influencer Follow Proportion By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_influencer_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Average Consumer-Influencer Follow Proportion By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_influencer_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()
# Out:
# /Users/gabeguralnick/git/content-market-experiment/stats.py:58: RuntimeWarning: invalid value encountered in scalar divide
#   return [follow[i] / self.attention_used[i] for i in range(len(follow))]

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-Influencer Following Rates By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Following rate (%)')
    follow_proportions = [test.average_influencer_follow_proportion[-1] * 100 for test in perfect_info_stats]
    plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Average Consumer-Influencer Following Rates By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Following rate (%)')
        follow_proportions = [test.average_influencer_follow_proportion[-1] * 100 for test in imperfect_info_stats]
        plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-External Follow Proportion By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_external_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Average Consumer-External Follow Proportion By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_external_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-External Follow Proportion By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_external_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Average Consumer-External Follow Proportion By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_external_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Difference")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                if np.linalg.norm(perfect_consumer_stat.following_rates[-1]) == 0:
                    continue
                ending_follow_rate_diff = np.linalg.norm(perfect_consumer_stat.following_rates[-1] - imperfect_consumer_stat.following_rates[-1])
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(second_param_values, avg_follow_rate_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Difference")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                if np.linalg.norm(perfect_consumer_stat.following_rates[-1]) == 0:
                    continue
                ending_follow_rate_diff = np.linalg.norm(perfect_consumer_stat.following_rates[-1] - imperfect_consumer_stat.following_rates[-1])
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(first_param_values, avg_follow_rate_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Difference")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0:
                    continue
                ending_follow_rate_diff = np.linalg.norm(perfect_influencer_stat.following_rates[-1] - imperfect_influencer_stat.following_rates[-1])
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(second_param_values, avg_follow_rate_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Difference")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0:
                    continue
                ending_follow_rate_diff = np.linalg.norm(perfect_influencer_stat.following_rates[-1] - imperfect_influencer_stat.following_rates[-1])
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(first_param_values, avg_follow_rate_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Producer Topic Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Topic Difference (% of topic space)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_topic_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            topic_space_size = perfect_stat.market.topics_bounds[0][1] - perfect_stat.market.topics_bounds[0][0]

            avg_topic_diff = 0

            for index in perfect_stat.producer_stats:
                perfect_producer_stat = perfect_stat.producer_stats[index]
                imperfect_producer_stat = imperfect_stat.producer_stats[index]

                # if perfect_producer_stat.topics[-1] == 0:
                #     continue

                ending_topic_diff = np.linalg.norm(perfect_producer_stat.topics[-1] - imperfect_producer_stat.topics[-1]) / topic_space_size * 100
                avg_topic_diff += ending_topic_diff
            
            avg_topic_diff /= len(perfect_stat.producer_stats)
            avg_topic_diffs.append(avg_topic_diff)
        
        plt.plot(second_param_values, avg_topic_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Producer Topic Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Topic Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_topic_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_topic_diff = 0

            topic_space_size = perfect_stat.market.topics_bounds[0][1] - perfect_stat.market.topics_bounds[0][0]

            for index in perfect_stat.producer_stats:
                perfect_producer_stat = perfect_stat.producer_stats[index]
                imperfect_producer_stat = imperfect_stat.producer_stats[index]

                # if perfect_producer_stat.topics[-1] == 0:
                #     continue

                ending_topic_diff = np.linalg.norm(perfect_producer_stat.topics[-1] - imperfect_producer_stat.topics[-1]) / topic_space_size * 100
                avg_topic_diff += ending_topic_diff
            
            avg_topic_diff /= len(perfect_stat.producer_stats)
            avg_topic_diffs.append(avg_topic_diff)
        
        plt.plot(first_param_values, avg_topic_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Producer Topic Standard Deviation By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Topic Standard Deviation')
    std_deviations = [test.producer_topic_standard_deviation[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, std_deviations, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Producer Topic Standard Deviation By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Topic Standard Deviation')
        std_deviations = [test.producer_topic_standard_deviation[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, std_deviations, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Producer Topic Standard Deviation By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Topic Standard Deviation')
    std_deviations = [test.producer_topic_standard_deviation[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, std_deviations, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Producer Topic Standard Deviation By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Topic Standard Deviation')
        std_deviations = [test.producer_topic_standard_deviation[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, std_deviations, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Norm Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0:
                    continue

                ending_follow_rate_norm_diff = (np.linalg.norm(imperfect_influencer_stat.following_rates[-1]) - np.linalg.norm(perfect_influencer_stat.following_rates[-1])) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(first_param_values, avg_follow_rate_norm_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    #plt.ylim(-1, 1)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Norm Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0:
                    continue

                ending_follow_rate_norm_diff = (np.linalg.norm(imperfect_influencer_stat.following_rates[-1]) - np.linalg.norm(perfect_influencer_stat.following_rates[-1])) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(second_param_values, avg_follow_rate_norm_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Ending Influencer Follow Rate Cosine Similarity By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Cosine Similarity")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0 or np.linalg.norm(imperfect_influencer_stat.following_rates[-1]) == 0:
                    avg_follow_rate_sim += 1
                    continue

                ending_follow_rate_sim = np.dot(perfect_influencer_stat.following_rates[-1], imperfect_influencer_stat.following_rates[-1]) / (np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * np.linalg.norm(imperfect_influencer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.influencer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(first_param_values, avg_follow_rate_sims, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Ending Influencer Follow Rate Cosine Similarity By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Cosine Similarity")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                if np.linalg.norm(perfect_influencer_stat.following_rates[-1]) == 0 or np.linalg.norm(imperfect_influencer_stat.following_rates[-1]) == 0:
                    avg_follow_rate_sim += 1
                    continue

                ending_follow_rate_sim = np.dot(perfect_influencer_stat.following_rates[-1], imperfect_influencer_stat.following_rates[-1]) / (np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * np.linalg.norm(imperfect_influencer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.influencer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(second_param_values, avg_follow_rate_sims, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Norm Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_norm_diff = (np.linalg.norm(imperfect_consumer_stat.following_rates[-1]) - np.linalg.norm(perfect_consumer_stat.following_rates[-1]))
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(first_param_values, avg_follow_rate_norm_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Norm Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_norm_diff = (np.linalg.norm(imperfect_consumer_stat.following_rates[-1]) - np.linalg.norm(perfect_consumer_stat.following_rates[-1]))
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(second_param_values, avg_follow_rate_norm_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Cosine Similarity By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Cosine Similarity")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                if np.linalg.norm(perfect_consumer_stat.following_rates[-1]) == 0 or np.linalg.norm(imperfect_consumer_stat.following_rates[-1]) == 0:
                    avg_follow_rate_sim += 1
                    continue
                ending_follow_rate_sim = np.dot(perfect_consumer_stat.following_rates[-1], imperfect_consumer_stat.following_rates[-1]) / (np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * np.linalg.norm(imperfect_consumer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.consumer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(first_param_values, avg_follow_rate_sims, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Cosine Similarity By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Cosine Similarity")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                if np.linalg.norm(perfect_consumer_stat.following_rates[-1]) == 0 or np.linalg.norm(imperfect_consumer_stat.following_rates[-1]) == 0:
                    avg_follow_rate_sim += 1
                    continue
                ending_follow_rate_sim = np.dot(perfect_consumer_stat.following_rates[-1], imperfect_consumer_stat.following_rates[-1]) / (np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * np.linalg.norm(imperfect_consumer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.consumer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(second_param_values, avg_follow_rate_sims, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()
