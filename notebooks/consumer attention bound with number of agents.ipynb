# %%
import numpy as np
from test import test
from util import inverse_decay
import matplotlib.pyplot as plt
import visualize
from stats import *
from agents import *

# %%
topics = np.array([[-1, 1]])

# %%
first_param = 'consumer_attention_bound'
first_param_legend_label = 'Consumer Attention Bound'
first_param_x_label = 'Consumer Attention Bound'
first_param_values = list(np.linspace(10, 150, 5))

# %%
second_param = 'num_agents'
second_param_legend_label = 'Number of Agents'
second_param_x_label = 'Number of Agents'
second_param_values = [1, 3, 8, 10, 15]

# %%
num_influencers = 1

# %%
test_imperfect = True

# %%
first_param_stats = {}

for first_param_value in first_param_values:
    perfect_info_stats, imperfect_info_stats = test(
        topics=topics,
        varied_param=second_param,
        num_influencers=num_influencers,
        num_agents=second_param_values,
        producer_topic_interest_func=lambda x: inverse_decay(x, 0.5, 2),
        consumer_topic_interest_func=lambda x: inverse_decay(x, 0.5, 2),
        agent_topic_interest_func=None,
        consumer_attention_bound=10,
        consumer_external_interest_prob=3,
        consumer_delay_sensitivity=1,
        influencer_attention_bound=first_param_value,
        influencer_delay_sensitivity=1,
        init_following_rates_method='equal',
        init_interest_method='even',
        production_rate=1,
        external_production_rate=1,
        use_imperfect_information=test_imperfect,
    )
    first_param_stats[first_param_value] = {
        'perfect': perfect_info_stats,
        'imperfect': imperfect_info_stats
    }
# Out:
# Optimizing consumer 0
# Optimizing influencer 1
# Optimizing producer 0
# Optimization succeeded (overall 0.000207458040677011s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 0.005043290962930769 seconds.
# Total Social Welfare: 2.7145122541078788
# Optimizing consumer 0
# Optimizing influencer 1
# Optimizing producer 0
# Optimization succeeded (overall 0.0007301670266315341s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.0016833330155350268 seconds.
# Total Social Welfare: 2.7145122541078788
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.007154166989494115 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeeded (overall 0.0013277499820105731s): nit=5, nfev=12, njev=6.
# Optimizing producer 1
# Optimization succeeded (overall 0.00028325000312179327s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0012032920494675636s): nit=5, nfev=12, njev=6.
# Iteration 0 / 100 done in 0.04567316599423066 seconds.
# Total Social Welfare: 9.20592332493177
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeeded (overall 0.0008526670280843973s): nit=3, nfev=8, njev=4.
# Optimizing producer 1
# Optimization succeeded (overall 0.0002566670300439s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.0006506249774247408s): nit=3, nfev=8, njev=4.
# Iteration 1 / 100 done in 0.012765459017828107 seconds.
# Total Social Welfare: 9.213624176434857
# Consumer rate change: 0.2056262640488662
# Consumer utility change: 0.000835811060684292%
# Influencer rate change: 0.4378661009608756
# Influencer utility change: 0.027186660146722493%
# Producer topic change: 0.012166732598947258
# Producer utility change: 0.031362633889631425%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeeded (overall 0.0005869999877177179s): nit=2, nfev=6, njev=3.
# Optimizing producer 1
# Optimization succeeded (overall 0.00027408398455008864s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 0.00064354098867625s): nit=2, nfev=6, njev=3.
# Iteration 2 / 100 done in 0.005772707983851433 seconds.
# Total Social Welfare: 9.213642079079893
# Consumer rate change: 0.007333043825210971
# Consumer utility change: 1.94305781077874e-06%
# Influencer rate change: 0.0
# Influencer utility change: 0.002421311454525295%
# Producer topic change: 0.0003313392847223244
# Producer utility change: 0.0004784333952518637%
# Converged. Optimization took 0.0660776249715127 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization succeeded (overall 0.004055166966281831s): nit=5, nfev=14, njev=7.
# Optimizing producer 1
# Optimization succeeded (overall 0.0032882089726626873s): nit=4, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.003665708005428314s): nit=3, nfev=10, njev=5.
# Optimizing producer 3
# Optimization succeeded (overall 0.005586792016401887s): nit=2, nfev=8, njev=4.
# Optimizing producer 4
# Optimization succeeded (overall 0.0022218330414034426s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.002612082986161113s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.003670374979265034s): nit=4, nfev=12, njev=6.
# Optimizing producer 7
# Optimization succeeded (overall 0.006359125021845102s): nit=5, nfev=14, njev=7.
# Iteration 0 / 100 done in 0.3311729159904644 seconds.
# Total Social Welfare: 35.17353325234663
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization succeeded (overall 0.002298792009241879s): nit=3, nfev=10, njev=5.
# Optimizing producer 1
# Optimization succeeded (overall 0.0023428749991580844s): nit=3, nfev=10, njev=5.
# Optimizing producer 2
# Optimization succeeded (overall 0.002477999951224774s): nit=3, nfev=10, njev=5.
# Optimizing producer 3
# Optimization succeeded (overall 0.002466582984197885s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.002459582989104092s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.004255541949532926s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.0023224580218084157s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.002039666986092925s): nit=3, nfev=10, njev=5.
# Iteration 1 / 100 done in 0.20164579199627042 seconds.
# Total Social Welfare: 35.27511123841657
# Consumer rate change: 0.18662748868110987
# Consumer utility change: 0.002879592989704668%
# Influencer rate change: 0.16499683754807304
# Influencer utility change: 0.004492277509910619%
# Producer topic change: 0.04541315643726532
# Producer utility change: 0.008649728279873588%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization succeeded (overall 0.0022080420167185366s): nit=2, nfev=8, njev=4.
# Optimizing producer 1
# Optimization succeeded (overall 0.0022097500041127205s): nit=2, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.0018192080315202475s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.0015063750324770808s): nit=1, nfev=6, njev=3.
# Optimizing producer 4
# Optimization succeeded (overall 0.001498833007644862s): nit=1, nfev=6, njev=3.
# Optimizing producer 5
# Optimization succeeded (overall 0.002003125031478703s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.0020859999931417406s): nit=2, nfev=8, njev=4.
# Optimizing producer 7
# Optimization succeeded (overall 0.0019178339862264693s): nit=2, nfev=8, njev=4.
# Iteration 2 / 100 done in 0.16814141697250307 seconds.
# Total Social Welfare: 35.279419571693246
# Consumer rate change: 0.08459355842808622
# Consumer utility change: 0.00012212027159229878%
# Influencer rate change: 0.005280050916462298
# Influencer utility change: -0.0004931590319707585%
# Producer topic change: 0.0038904091423601524
# Producer utility change: 0.00075713017881075%
# Converged. Optimization took 0.7161825830116868 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.004462000040803105s): nit=5, nfev=14, njev=7.
# Optimizing producer 1
# Optimization succeeded (overall 0.004110374953597784s): nit=4, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.003115875006187707s): nit=3, nfev=10, njev=5.
# Optimizing producer 3
# Optimization succeeded (overall 0.003831750014796853s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.002696417039260268s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.0024962080060504377s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.0030272090225480497s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.003242042032070458s): nit=3, nfev=10, njev=5.
# Optimizing producer 8
# Optimization succeeded (overall 0.0038821669877506793s): nit=4, nfev=12, njev=6.
# Optimizing producer 9
# Optimization succeeded (overall 0.0045034579816274345s): nit=5, nfev=14, njev=7.
# Iteration 0 / 100 done in 0.5688548749894835 seconds.
# Total Social Welfare: 45.65625315489085
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.004677833989262581s): nit=3, nfev=10, njev=5.
# Optimizing producer 1
# Optimization succeeded (overall 0.007496875012293458s): nit=4, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.003422958019655198s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.007894666981883347s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.005508167028892785s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.003614042012486607s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.002966292027849704s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0037257499643601477s): nit=4, nfev=12, njev=6.
# Optimizing producer 8
# Optimization succeeded (overall 0.010653291014023125s): nit=4, nfev=12, njev=6.
# Optimizing producer 9
# Optimization succeeded (overall 0.012953833036590368s): nit=3, nfev=10, njev=5.
# Iteration 1 / 100 done in 0.3711327920318581 seconds.
# Total Social Welfare: 45.85712099972823
# Consumer rate change: 0.21181938768794306
# Consumer utility change: 0.004380296814438012%
# Influencer rate change: 0.16970341522267368
# Influencer utility change: 0.001198874111815772%
# Producer topic change: 0.053079033440910736
# Producer utility change: 0.011353459314569138%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0022674589999951422s): nit=2, nfev=8, njev=4.
# Optimizing producer 1
# Optimization succeeded (overall 0.0024040830321609974s): nit=2, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.0022511660354211926s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.001793457951862365s): nit=1, nfev=6, njev=3.
# Optimizing producer 4
# Optimization succeeded (overall 0.0023569579934701324s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.002599625033326447s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.0018831249908544123s): nit=1, nfev=6, njev=3.
# Optimizing producer 7
# Optimization succeeded (overall 0.0023479999508708715s): nit=2, nfev=8, njev=4.
# Optimizing producer 8
# Optimization succeeded (overall 0.0032572089694440365s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.0022174580371938646s): nit=2, nfev=8, njev=4.
# Iteration 2 / 100 done in 0.3488085839780979 seconds.
# Total Social Welfare: 46.01439642883218
# Consumer rate change: 0.2025416763273566
# Consumer utility change: 0.00341796061951172%
# Influencer rate change: 0.009213094790430811
# Influencer utility change: 0.0036510023953747893%
# Producer topic change: 0.0052748929409386774
# Producer utility change: 0.004599606410740523%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.001643249997869134s): nit=1, nfev=6, njev=3.
# Optimizing producer 1
# Optimization succeeded (overall 0.004016666964162141s): nit=2, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.0027025419985875487s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.0021820419933646917s): nit=2, nfev=8, njev=4.
# Optimizing producer 4
# Optimization succeeded (overall 0.002703124948311597s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.003043500008061528s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.0023900000378489494s): nit=2, nfev=8, njev=4.
# Optimizing producer 7
# Optimization succeeded (overall 0.0027312919846735895s): nit=2, nfev=8, njev=4.
# Optimizing producer 8
# Optimization succeeded (overall 0.0026424999814480543s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.0015322919934988022s): nit=1, nfev=6, njev=3.
# Iteration 3 / 100 done in 0.2045914589543827 seconds.
# Total Social Welfare: 46.016562927576885
# Consumer rate change: 0.011116739081846242
# Consumer utility change: 4.7080836465516416e-05%
# Influencer rate change: 0.006510568107366185
# Influencer utility change: -0.000497361293075387%
# Producer topic change: 0.0038421712687597446
# Producer utility change: 0.00016621747113716373%
# Converged. Optimization took 1.5307869999669492 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing influencer 15
# Optimizing producer 0
# Optimization succeeded (overall 0.015279541024938226s): nit=5, nfev=14, njev=7.
# Optimizing producer 1
# Optimization succeeded (overall 0.006770125008188188s): nit=4, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.0074555829633027315s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.004990416986402124s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.005243792023975402s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.0062752499943599105s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.003671291982755065s): nit=2, nfev=8, njev=4.
# Optimizing producer 7
# Optimization succeeded (overall 0.0009659169591031969s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.003882374963723123s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.004852624959312379s): nit=3, nfev=10, njev=5.
# Optimizing producer 10
# Optimization succeeded (overall 0.005541208025533706s): nit=3, nfev=10, njev=5.
# Optimizing producer 11
# Optimization succeeded (overall 0.004925834015011787s): nit=3, nfev=10, njev=5.
# Optimizing producer 12
# Optimization succeeded (overall 0.005840707977768034s): nit=4, nfev=12, njev=6.
# Optimizing producer 13
# Optimization succeeded (overall 0.006057500024326146s): nit=4, nfev=12, njev=6.
# Optimizing producer 14
# Optimization succeeded (overall 0.006720666016917676s): nit=5, nfev=14, njev=7.
# Iteration 0 / 100 done in 2.2008813340216875 seconds.
# Total Social Welfare: 73.38515059030703
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing influencer 15
# Optimizing producer 0
# Optimization succeeded (overall 0.0023416249896399677s): nit=3, nfev=10, njev=5.
# Optimizing producer 1
# Optimization succeeded (overall 0.004043375025503337s): nit=3, nfev=10, njev=5.
# Optimizing producer 2
# Optimization succeeded (overall 0.008965749992057681s): nit=4, nfev=12, njev=6.
# Optimizing producer 3
# Optimization succeeded (overall 0.005200165964197367s): nit=4, nfev=12, njev=6.
# Optimizing producer 4
# Optimization succeeded (overall 0.004719415970612317s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.008834709005896002s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.005670665996149182s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0010248339967802167s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.004244540992658585s): nit=3, nfev=10, njev=5.
# Optimizing producer 9
# Optimization succeeded (overall 0.005442333000246435s): nit=3, nfev=10, njev=5.
# Optimizing producer 10
# Optimization succeeded (overall 0.004440207965672016s): nit=3, nfev=10, njev=5.
# Optimizing producer 11
# Optimization succeeded (overall 0.005748666997533292s): nit=4, nfev=12, njev=6.
# Optimizing producer 12
# Optimization succeeded (overall 0.004731749999336898s): nit=4, nfev=12, njev=6.
# Optimizing producer 13
# Optimization succeeded (overall 0.0015538749867118895s): nit=3, nfev=10, njev=5.
# Optimizing producer 14
# Optimization succeeded (overall 0.0018214999581687152s): nit=3, nfev=10, njev=5.
# Iteration 1 / 100 done in 0.8965241249534301 seconds.
# Total Social Welfare: 73.96122142696268
# Consumer rate change: 0.2628880356126081
# Consumer utility change: 0.007788821070136091%
# Influencer rate change: 0.0532550165988187
# Influencer utility change: 0.04746680189182454%
# Producer topic change: 0.06780140315529136
# Producer utility change: 0.015746080491171304%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing influencer 15
# Optimizing producer 0
# Optimization succeeded (overall 0.004130915971472859s): nit=2, nfev=8, njev=4.
# Optimizing producer 1
# Optimization succeeded (overall 0.003254625014960766s): nit=2, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.003310500003863126s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.0034307920141145587s): nit=2, nfev=8, njev=4.
# Optimizing producer 4
# Optimization succeeded (overall 0.0035361250047571957s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.003691999998409301s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.0032879579812288284s): nit=2, nfev=8, njev=4.
# Optimizing producer 7
# Optimization succeeded (overall 0.00109570799395442s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.003550749970600009s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.003671583952382207s): nit=2, nfev=8, njev=4.
# Optimizing producer 10
# Optimization succeeded (overall 0.003543625003658235s): nit=2, nfev=8, njev=4.
# Optimizing producer 11
# Optimization succeeded (overall 0.0034050000249408185s): nit=2, nfev=8, njev=4.
# Optimizing producer 12
# Optimization succeeded (overall 0.0028480420005507767s): nit=2, nfev=8, njev=4.
# Optimizing producer 13
# Optimization succeeded (overall 0.003062915988266468s): nit=2, nfev=8, njev=4.
# Optimizing producer 14
# Optimization succeeded (overall 0.003269667038694024s): nit=2, nfev=8, njev=4.
# Iteration 2 / 100 done in 0.8869355000206269 seconds.
# Total Social Welfare: 73.98118766742193
# Consumer rate change: 0.10120113412786577
# Consumer utility change: 0.00026988261530469385%
# Influencer rate change: 0.015519568118131004
# Influencer utility change: -0.004144053574201837%
# Producer topic change: 0.0049314848177767325
# Producer utility change: 0.0027994111913527864%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing influencer 15
# Optimizing producer 0
# Optimization succeeded (overall 0.0029534580535255373s): nit=1, nfev=6, njev=3.
# Optimizing producer 1
# Optimization succeeded (overall 0.0035100000095553696s): nit=2, nfev=8, njev=4.
# Optimizing producer 2
# Optimization succeeded (overall 0.003449957992415875s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.0032013749587349594s): nit=2, nfev=8, njev=4.
# Optimizing producer 4
# Optimization succeeded (overall 0.003176958009134978s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.003497583034913987s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.0027716250042431056s): nit=1, nfev=6, njev=3.
# Optimizing producer 7
# Optimization succeeded (overall 0.0009867909830063581s): nit=0, nfev=2, njev=1.
# Optimizing producer 8
# Optimization succeeded (overall 0.0028245419962331653s): nit=1, nfev=6, njev=3.
# Optimizing producer 9
# Optimization succeeded (overall 0.0040134580340236425s): nit=2, nfev=8, njev=4.
# Optimizing producer 10
# Optimization succeeded (overall 0.003545083978679031s): nit=2, nfev=8, njev=4.
# Optimizing producer 11
# Optimization succeeded (overall 0.0035089169978164136s): nit=2, nfev=8, njev=4.
# Optimizing producer 12
# Optimization succeeded (overall 0.0033187500084750354s): nit=2, nfev=8, njev=4.
# Optimizing producer 13
# Optimization succeeded (overall 0.003184833039995283s): nit=2, nfev=8, njev=4.
# Optimizing producer 14
# Optimization succeeded (overall 0.0025785419857129455s): nit=1, nfev=6, njev=3.
# Iteration 3 / 100 done in 0.4922412500018254 seconds.
# Total Social Welfare: 73.98208935802553
# Consumer rate change: 0.008791771320965508
# Consumer utility change: 1.2187955606523411e-05%
# Influencer rate change: 0.003337099376538788
# Influencer utility change: -0.00020308568442332022%
# Producer topic change: 0.0025442794960966555
# Producer utility change: -5.869240989353276e-05%
# Converged. Optimization took 4.540843833994586 seconds.
# Optimizing consumer 0
# Optimizing influencer 1
# Optimizing producer 0
# Optimization succeeded (overall 0.0007488330011256039s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 0.0020822910009883344 seconds.
# Total Social Welfare: 2.7145122541078788
# Optimizing consumer 0
# Optimizing influencer 1
# Optimizing producer 0
# Optimization succeeded (overall 0.0007256249664351344s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 0.001416333019733429 seconds.
# Total Social Welfare: 2.7145122541078788
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.004353167023509741 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeeded (overall 0.14107324997894466s): nit=2, nfev=36, njev=18.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 0.955005333002191s): nit=2, nfev=118, njev=59.
# Optimizing producer 2
# Optimization succeeded (overall 0.0078016670304350555s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 1.1280255420133471 seconds.
# Total Social Welfare: 9.049099335322083
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 1.3984557500225492s): nit=1, nfev=86, njev=43.
# Optimizing producer 1
# Optimization succeeded (overall 0.5069020409719087s): nit=4, nfev=124, njev=62.
# Optimizing producer 2
# Optimization succeeded (overall 0.009002957958728075s): nit=0, nfev=2, njev=1.
# Iteration 1 / 100 done in 1.9298650420387276 seconds.
# Total Social Welfare: 9.104790766775311
# Consumer rate change: 0.08131931809187473
# Consumer utility change: 0.0061167153128119205%
# Influencer rate change: 0.20713362687481313
# Influencer utility change: 0.04500017770601442%
# Producer topic change: 0.13715944751548953
# Producer utility change: 5.739002933756657e-05%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeeded (overall 0.006223958043847233s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 0.8948728329851292s): nit=3, nfev=160, njev=80.
# Optimizing producer 2
# Optimization succeeded (overall 0.009105000004637986s): nit=0, nfev=2, njev=1.
# Iteration 2 / 100 done in 0.923029666999355 seconds.
# Total Social Welfare: 9.105799709716944
# Consumer rate change: 0.06402220473334087
# Consumer utility change: 0.00011080219655492784%
# Influencer rate change: 0.18986390272362128
# Influencer utility change: 0.0088009973790074%
# Producer topic change: 5.304775278195421e-06
# Producer utility change: 0.0%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeeded (overall 0.

# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 17.458873874973506s): nit=1, nfev=70, njev=35.
# Optimizing producer 9
# Optimization succeeded (overall 10.771909041970503s): nit=5, nfev=118, njev=59.
# Iteration 0 / 100 done in 148.86951891699573 seconds.
# Total Social Welfare: 45.56250897218668
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 4.617827625013888s): nit=6, nfev=92, njev=46.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 10.986012334004045s): nit=1, nfev=68, njev=34.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 14.415773916000035s): nit=2, nfev=130, njev=65.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 9.383539541973732s): nit=1, nfev=72, njev=36.
# Optimizing producer 4
# Optimization succeeded (overall 4.456872457987629s): nit=5, nfev=82, njev=41.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 10.55304625001736s): nit=1, nfev=66, njev=33.
# Optimizing producer 6
# Optimization succeeded (overall 2.143045542004984s): nit=3, nfev=42, njev=21.
# Optimizing producer 7
# Optimization succeeded (overall 2.9101992920041084s): nit=3, nfev=50, njev=25.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 4.717321582953446s): nit=1, nfev=48, njev=24.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 10.67429295904003s): nit=1, nfev=74, njev=37.
# Iteration 1 / 100 done in 75.22887804202037 seconds.
# Total Social Welfare: 45.826371573088714
# Consumer rate change: 0.2876126852933034
# Consumer utility change: 0.005757875525939378%
# Influencer rate change: 0.1719562075554158
# Influencer utility change: 0.012326783871637784%
# Producer topic change: 0.013872833493842569
# Producer utility change: 8.281944475263408e-05%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 4.871887332992628s): nit=3, nfev=86, njev=43.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 5.44799279194558s): nit=1, nfev=68, njev=34.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 5.302289000013843s): nit=2, nfev=100, njev=50.
# Optimizing producer 3
# Optimization succeeded (overall 2.095441583020147s): nit=5, nfev=58, njev=29.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 8.652761792007368s): nit=2, nfev=134, njev=67.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 9.408899082976859s): nit=2, nfev=172, njev=86.
# Optimizing producer 6
# Optimization succeeded (overall 0.07733812497463077s): nit=0, nfev=2, njev=1.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 7.436986208951566s): nit=1, nfev=96, njev=48.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 4.2280221250257455s): nit=2, nfev=86, njev=43.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 5.472140332974959s): nit=1, nfev=80, njev=40.
# Iteration 2 / 100 done in 53.15601620898815 seconds.
# Total Social Welfare: 45.82477066370019
# Consumer rate change: 0.03737218896014681
# Consumer utility change: -3.4935451197953765e-05%
# Influencer rate change: 0.00792346970618759
# Influencer utility change: 0.0001790408467776697%
# Producer topic change: 0.001359349088465929
# Producer utility change: 6.239350352409954e-06%
# Converged. Optimization took 278.56305708299624 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing influencer 15
# Optimizing producer 0
# Optimization succeeded (overall 1.0526777079794556s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 1.0102151660248637s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization succeeded (overall 13.81699474999914s): nit=1, nfev=28, njev=14.
# Optimizing producer 3
# Optimization succeeded (overall 27.85970695799915s): nit=4, nfev=58, njev=29.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 107.74109191598836s): nit=2, nfev=50, njev=25.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 67.784174374945s): nit=1, nfev=84, njev=42.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 88.78571245900821s): nit=1, nfev=70, njev=35.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 131.3712330419803s): nit=1, nfev=56, njev=28.
# Optimizing producer 8
# Optimization succeeded (overall 52.77728329098318s): nit=7, nfev=96, njev=48.
# Optimizing producer 9
# Optimization succeeded (overall 28.04422349995002s): nit=2, nfev=54, njev=27.
# Optimizing producer 10
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 77.63489591702819s): nit=1, nfev=50, njev=25.
# Optimizing producer 11
# Optimization succeeded (overall 21.27314620796824s): nit=2, nfev=44, njev=22.
# Optimizing producer 12
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 114.01942020800197s): nit=1, nfev=50, njev=25.
# Optimizing producer 13
# Optimization succeeded (overall 0.8746303749503568s): nit=0, nfev=2, njev=1.
# Optimizing producer 14
# Optimization succeeded (overall 0.9758764999569394s): nit=0, nfev=2, njev=1.
# Iteration 0 / 100 done in 737.0608044169494 seconds.
# Total Social Welfare: 73.6166320830608
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing consumer 10
# Optimizing consumer 11
# Optimizing consumer 12
# Optimizing consumer 13
# Optimizing consumer 14
# Optimizing influencer 15
# Optimizing producer 0
# Optimization succeeded (overall 0.2019200840150006s): nit=0, nfev=2, njev=1.
# Optimizing producer 1
# Optimization succeeded (overall 0.1909402500023134s): nit=0, nfev=2, njev=1.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 31.325005041027907s): nit=3, nfev=170, njev=85.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 31.573600624979008s): nit=2, nfev=104, njev=52.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 18.69297670800006s): nit=2, nfev=94, njev=47.
# Optimizing producer 5
# Optimization succeeded (overall 8.331653625005856s): nit=4, nfev=82, njev=41.
# Optimizing producer 6
# Optimization succeeded (overall 7.043611166998744s): nit=2, nfev=72, njev=36.
# Optimizing producer 7
# Optimization succeeded (overall 2.977470582991373s): nit=2, nfev=30, njev=15.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeeded (overall 20.455202875018585s): nit=2, nfev=176, njev=88.
# Optimizing producer 9
# Optimization succeeded (overall 5.355609665974043s): nit=3, nfev=58, njev=29.
# Optimizing producer 10
# Optimization succeeded (overall 10.62340908398619s): nit=5, nfev=90, njev=45.
# Optimizing producer 11
# Optimization succeeded (overall 7.334418083017226s): nit=5, nfev=66, njev=33.
# Optimizing producer 12
# Optimization succeeded (overall 4.838829999964219s): nit=2, nfev=40, njev=20.
# ...
# Optimizing producer 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/gabeguralnick/git/content-market-experiment/notebooks/consumer attention bound with number of agents.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> first_param_stats = {}
#       <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> for first_param_value in first_param_values:
# ----> <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     perfect_info_stats, imperfect_info_stats = test(
#       <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>         topics=topics,
#       <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>         varied_param=second_param,
#       <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>         num_influencers=num_influencers,
#       <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>         num_agents=second_param_values,
#       <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>         producer_topic_interest_func=lambda x: inverse_decay(x, 0.5, 2),
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>         consumer_topic_interest_func=lambda x: inverse_decay(x, 0.5, 2),
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a>         agent_topic_interest_func=None,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>         consumer_attention_bound=10,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a>         consumer_external_interest_prob=3,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a>         consumer_delay_sensitivity=1,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a>         influencer_attention_bound=first_param_value,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a>         influencer_delay_sensitivity=1,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a>         init_following_rates_method='equal',
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a>         init_interest_method='even',
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a>         production_rate=1,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a>         external_production_rate=1,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a>         use_imperfect_information=test_imperfect,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a>     )
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=22'>23</a>     first_param_stats[first_param_value] = {
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=23'>24</a>         'perfect': perfect_info_stats,
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=24'>25</a>         'imperfect': imperfect_info_stats
#      <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/consumer%20attention%20bound%20with%20number%20of%20agents.ipynb#W6sZmlsZQ%3D%3D?line=25'>26</a>     }
#
# File ~/git/content-market-experiment/test.py:80, in test(topics, varied_param, num_agents, num_influencers, producer_topic_interest_func, consumer_topic_interest_func, agent_topic_interest_func, consumer_attention_bound, consumer_external_interest_prob, consumer_delay_sensitivity, influencer_attention_bound, influencer_delay_sensitivity, init_following_rates_method, init_interest_method, production_rate, external_production_rate, use_imperfect_information)
#      78         market.finalize(method=init_interest_method)
#      79         # run the market
# ---> 80         test_stats = market.optimize()
#      81         imperfect_info_stats.append(test_stats)
#      83 return perfect_info_stats, imperfect_info_stats
#
# File ~/git/content-market-experiment/content_market.py:214, in ContentMarket.optimize(self, max_iterations, converge_tol)
#     211 prod_start_time = timer()
#     213 print(f"Optimizing producer {producer.index}")
# --> 214 result = minimize_with_retry(
#     215     fun=producer.minimization_utility,
#     216     x0=producer.topic_produced,
#     217     args=(self.production_rate, self.external_production_rate, OptimizationTargets.PRODUCER),
#     218     bounds=self.topics_bounds,
#     219     num_retry=2
#     220 )
#     222 if not result.success:
#     223     raise RuntimeError("Optimization failed", result)
#
# File ~/git/content-market-experiment/util.py:24, in minimize_with_retry(fun, x0, args, constraints, bounds, tol, num_retry)
#      23 def minimize_with_retry(fun, x0, args, constraints=None, bounds=None, tol=None, num_retry=1):
# ---> 24     result = opt.minimize(
#      25         fun=fun,
#      26         x0=x0,
#      27         args=args,
#      28         constraints=constraints,
#      29         bounds=bounds,
#      30         #options={'maxiter': 1000},
#      31         tol=tol
#      32     )
#      34     retries = 0
#      35     while not result.success and retries < num_retry:
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_minimize.py:710, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     707     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     708                              **options)
#     709 elif meth == 'l-bfgs-b':
# --> 710     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     711                            callback=callback, **options)
#     712 elif meth == 'tnc':
#     713     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     714                         **options)
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:365, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     359 task_str = task.tobytes()
#     360 if task_str.startswith(b'FG'):
#     361     # The minimization routine wants f and g at the current x.
#     362     # Note that interruptions due to maxfun are postponed
#     363     # until the completion of the current minimization iteration.
#     364     # Overwrite f and g:
# --> 365     f, g = func_and_grad(x)
#     366 elif task_str.startswith(b'NEW_X'):
#     367     # new iteration
#     368     n_iterations += 1
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:286, in ScalarFunction.fun_and_grad(self, x)
#     284     self._update_x_impl(x)
#     285 self._update_fun()
# --> 286 self._update_grad()
#     287 return self.f, self.g
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:173, in ScalarFunction.__init__.<locals>.update_grad()
#     171 self._update_fun()
#     172 self.ngev += 1
# --> 173 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     174                            **finite_diff_options)
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/git/content-market-experiment/agents/agent.py:88, in Agent.minimization_utility(self, x, *args)
#      81 def minimization_utility(self, x: np.ndarray, *args) -> float:
#      82     """
#      83     Return the utility of the agent.
#      84     x should be a vector of whatever input is needed for the utility function.
#      85     For example, for a producer, x could be the topic produced.
#      86     For a consumer, x could be the following rate vector.
#      87     """
# ---> 88     return -1 * self.utility(x, *args)
#
# File ~/git/content-market-experiment/agents/imperfect_consumer_producer.py:17, in ImperfectConsumerProducer.utility(self, x, *args)
#      15     return ConsumerProducer.utility(self, x, *args)
#      16 elif optimization_target == OptimizationTargets.PRODUCER:
# ---> 17     return ImperfectInformationProducer.utility(self, x, *args)
#      18 else:
#      19     raise ValueError("Unknown optimization target.")
#
# File ~/git/content-market-experiment/agents/imperfect_producer.py:30, in ImperfectInformationProducer.utility(self, topic, *args)
#      27 attention_constraint = LinearConstraint(np.ones(self.market.num_agents + 1), lb=0, ub=influencer.attention_bound)
#      29 #print("Optimizing for influencer", influencer.index, "under imperfect producer", self.index)
# ---> 30 result = minimize_with_retry(
#      31     fun=influencer.minimization_utility,
#      32     x0=influencer.get_following_rate_vector(),
#      33     args=(production_rate, external_production_rate, OptimizationTargets.INFLUENCER),
#      34     constraints=attention_constraint,
#      35     bounds=influencer.get_following_rate_bounds(),
#      36 )
#      38 if not result.success:
#      39     raise RuntimeError(f"Optimization of influencer {influencer.index} under imperfect producer {self.index} failed", result.message)
#
# File ~/git/content-market-experiment/util.py:24, in minimize_with_retry(fun, x0, args, constraints, bounds, tol, num_retry)
#      23 def minimize_with_retry(fun, x0, args, constraints=None, bounds=None, tol=None, num_retry=1):
# ---> 24     result = opt.minimize(
#      25         fun=fun,
#      26         x0=x0,
#      27         args=args,
#      28         constraints=constraints,
#      29         bounds=bounds,
#      30         #options={'maxiter': 1000},
#      31         tol=tol
#      32     )
#      34     retries = 0
#      35     while not result.success and retries < num_retry:
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     717                            bounds=bounds, **options)
#     718 elif meth == 'slsqp':
# --> 719     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     720                           constraints, callback=callback, **options)
#     721 elif meth == 'trust-constr':
#     722     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     723                                        bounds, constraints,
#     724                                        callback=callback, **options)
#
# File ~/git/content-market-experiment/venv/lib/python3.10/site-packages/scipy/optimize/_slsqp_py.py:422, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     418 a = _eval_con_normals(x, cons, la, n, m, meq, mieq)
#     420 while 1:
#     421     # Call SLSQP
# --> 422     slsqp(m, meq, x, xl, xu, fx, c, g, a, acc, majiter, mode, w, jw,
#     423           alpha, f0, gs, h1, h2, h3, h4, t, t0, tol,
#     424           iexact, incons, ireset, itermx, line,
#     425           n1, n2, n3)
#     427     if mode == 1:  # objective and constraint evaluation required
#     428         fx = wrapped_fun(x)
#
# KeyboardInterrupt:

# %%
second_param_stats = {}
for i in range(len(second_param_values)):
    second_param_value = second_param_values[i]
    second_param_stats[second_param_value] = {
        'perfect': [first_param_stats[first_param_value]['perfect'][i] for first_param_value in first_param_values],
        'imperfect': [first_param_stats[first_param_value]['imperfect'][i] for first_param_value in first_param_values]
    }

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Total Social Welfare By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Total Social Welfare')
    perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, perfect_social_welfares, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Total Social Welfare By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Total Social Welfare')
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, imperfect_social_welfares, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Total Social Welfare By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Total Social Welfare')
    perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, perfect_social_welfares, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Total Social Welfare By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Total Social Welfare')
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, imperfect_social_welfares, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Cost of Influence By {second_param_x_label}')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Cost of Influence (%)')
        perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]

        costs_of_influence = [(perfect_social_welfare - imperfect_social_welfare) / perfect_social_welfare * 100 for imperfect_social_welfare, perfect_social_welfare in zip(imperfect_social_welfares, perfect_social_welfares)]
        plt.plot(second_param_values, costs_of_influence, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Cost of Influence By {first_param_x_label}')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Cost of Influence (%)')
        perfect_social_welfares = [test.total_social_welfare[-1] for test in perfect_info_stats]
        imperfect_social_welfares = [test.total_social_welfare[-1] for test in imperfect_info_stats]

        costs_of_influence = [(perfect_social_welfare - imperfect_social_welfare) / perfect_social_welfare * 100 for imperfect_social_welfare, perfect_social_welfare in zip(imperfect_social_welfares, perfect_social_welfares)]
        plt.plot(first_param_values, costs_of_influence, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-Influencer Follow Proportion By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_influencer_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Average Consumer-Influencer Follow Proportion By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_influencer_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-Influencer Follow Proportion By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_influencer_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Average Consumer-Influencer Follow Proportion By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_influencer_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-External Follow Proportion By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_external_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Average Consumer-External Follow Proportion By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_external_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, follow_proportions, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Average Consumer-External Follow Proportion By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Follow Proportion')
    follow_proportions = [test.average_external_follow_proportion[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = second_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Average Consumer-External Follow Proportion By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Follow Proportion')
        follow_proportions = [test.average_external_follow_proportion[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, follow_proportions, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_diff = np.linalg.norm(perfect_consumer_stat.following_rates[-1] - imperfect_consumer_stat.following_rates[-1]) / np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * 100
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(second_param_values, avg_follow_rate_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_diff = np.linalg.norm(perfect_consumer_stat.following_rates[-1] - imperfect_consumer_stat.following_rates[-1]) / np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * 100
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(first_param_values, avg_follow_rate_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Follow Rate Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                ending_follow_rate_diff = np.linalg.norm(perfect_influencer_stat.following_rates[-1] - imperfect_influencer_stat.following_rates[-1]) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(second_param_values, avg_follow_rate_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                ending_follow_rate_diff = np.linalg.norm(perfect_influencer_stat.following_rates[-1] - imperfect_influencer_stat.following_rates[-1]) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_diff += ending_follow_rate_diff
            
            avg_follow_rate_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_diffs.append(avg_follow_rate_diff)
        
        plt.plot(first_param_values, avg_follow_rate_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Producer Topic Difference By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Topic Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_topic_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_topic_diff = 0

            for index in perfect_stat.producer_stats:
                perfect_producer_stat = perfect_stat.producer_stats[index]
                imperfect_producer_stat = imperfect_stat.producer_stats[index]

                if perfect_producer_stat.topics[-1] == 0:
                    continue

                ending_topic_diff = np.linalg.norm(perfect_producer_stat.topics[-1] - imperfect_producer_stat.topics[-1]) / (np.linalg.norm(perfect_producer_stat.topics[-1])) * 100
                avg_topic_diff += ending_topic_diff
            
            avg_topic_diff /= len(perfect_stat.producer_stats)
            avg_topic_diffs.append(avg_topic_diff)
        
        plt.plot(second_param_values, avg_topic_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Producer Topic Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Topic Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_topic_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_topic_diff = 0

            for index in perfect_stat.producer_stats:
                perfect_producer_stat = perfect_stat.producer_stats[index]
                imperfect_producer_stat = imperfect_stat.producer_stats[index]

                if perfect_producer_stat.topics[-1] == 0:
                    continue

                ending_topic_diff = np.linalg.norm(perfect_producer_stat.topics[-1] - imperfect_producer_stat.topics[-1]) / (np.linalg.norm(perfect_producer_stat.topics[-1])) * 100
                avg_topic_diff += ending_topic_diff
            
            avg_topic_diff /= len(perfect_stat.producer_stats)
            avg_topic_diffs.append(avg_topic_diff)
        
        plt.plot(first_param_values, avg_topic_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
plt.figure()
for first_param_value in first_param_values:
    perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Producer Topic Standard Deviation By {second_param_x_label} (perfect)')
    plt.xlabel(second_param_x_label)
    plt.ylabel('Topic Standard Deviation')
    std_deviations = [test.producer_topic_standard_deviation[-1] for test in perfect_info_stats]
    plt.plot(second_param_values, std_deviations, label=f'{first_param_legend_label} = {first_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for first_param_value in first_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']
        plt.title(f'Producer Topic Standard Deviation By {second_param_x_label} (imperfect)')
        plt.xlabel(second_param_x_label)
        plt.ylabel('Topic Standard Deviation')
        std_deviations = [test.producer_topic_standard_deviation[-1] for test in imperfect_info_stats]
        plt.plot(second_param_values, std_deviations, label=f'{first_param_legend_label} = {first_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
plt.figure()
for second_param_value in second_param_values:
    perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
    #imperfect_info_stats = stats[first_param_value]['imperfect']
    plt.title(f'Producer Topic Standard Deviation By {first_param_x_label} (perfect)')
    plt.xlabel(first_param_x_label)
    plt.ylabel('Topic Standard Deviation')
    std_deviations = [test.producer_topic_standard_deviation[-1] for test in perfect_info_stats]
    plt.plot(first_param_values, std_deviations, label=f'{second_param_legend_label} = {second_param_value}')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

if test_imperfect:
    plt.figure()
    for second_param_value in second_param_values:
        #perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']
        plt.title(f'Producer Topic Standard Deviation By {first_param_x_label} (imperfect)')
        plt.xlabel(first_param_x_label)
        plt.ylabel('Topic Standard Deviation')
        std_deviations = [test.producer_topic_standard_deviation[-1] for test in imperfect_info_stats]
        plt.plot(first_param_values, std_deviations, label=f'{second_param_legend_label} = {second_param_value}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Norm Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                ending_follow_rate_norm_diff = (np.linalg.norm(perfect_influencer_stat.following_rates[-1]) - np.linalg.norm(imperfect_influencer_stat.following_rates[-1])) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(first_param_values, avg_follow_rate_norm_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.ylim(-1, 1)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Norm Difference By {second_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                ending_follow_rate_norm_diff = (np.linalg.norm(perfect_influencer_stat.following_rates[-1]) - np.linalg.norm(imperfect_influencer_stat.following_rates[-1])) / np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.influencer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(second_param_values, avg_follow_rate_norm_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Cosine Similarity By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Cosine Similarity")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                ending_follow_rate_sim = np.dot(perfect_influencer_stat.following_rates[-1], imperfect_influencer_stat.following_rates[-1]) / (np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * np.linalg.norm(imperfect_influencer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.influencer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(first_param_values, avg_follow_rate_sims, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Influencer Follow Rate Cosine Similarity By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Cosine Similarity")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.influencer_stats:
                perfect_influencer_stat = perfect_stat.influencer_stats[index]
                imperfect_influencer_stat = imperfect_stat.influencer_stats[index]

                ending_follow_rate_sim = np.dot(perfect_influencer_stat.following_rates[-1], imperfect_influencer_stat.following_rates[-1]) / (np.linalg.norm(perfect_influencer_stat.following_rates[-1]) * np.linalg.norm(imperfect_influencer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.influencer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(second_param_values, avg_follow_rate_sims, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Norm Difference By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_norm_diff = (np.linalg.norm(perfect_consumer_stat.following_rates[-1]) - np.linalg.norm(imperfect_consumer_stat.following_rates[-1])) / np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(first_param_values, avg_follow_rate_norm_diffs, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Norm Difference By {second_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Follow Rate Norm Difference (%)")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_norm_diffs = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_norm_diff = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_norm_diff = (np.linalg.norm(perfect_consumer_stat.following_rates[-1]) - np.linalg.norm(imperfect_consumer_stat.following_rates[-1])) / np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * 100
                avg_follow_rate_norm_diff += ending_follow_rate_norm_diff
            
            avg_follow_rate_norm_diff /= len(perfect_stat.consumer_stats)
            avg_follow_rate_norm_diffs.append(avg_follow_rate_norm_diff)
        
        plt.plot(second_param_values, avg_follow_rate_norm_diffs, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Cosine Similarity By {first_param_x_label}")
    plt.xlabel(first_param_x_label)
    plt.ylabel("Average Cosine Similarity")
    for second_param_value in second_param_values:
        perfect_info_stats: list[TestStats] = second_param_stats[second_param_value]['perfect']
        imperfect_info_stats = second_param_stats[second_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_sim = np.dot(perfect_consumer_stat.following_rates[-1], imperfect_consumer_stat.following_rates[-1]) / (np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * np.linalg.norm(imperfect_consumer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.consumer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(first_param_values, avg_follow_rate_sims, label=f'{second_param_legend_label} = {second_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()

# %%
if test_imperfect:
    plt.figure()
    plt.title(f"Average Ending Consumer Follow Rate Cosine Similarity By {second_param_x_label}")
    plt.xlabel(second_param_x_label)
    plt.ylabel("Average Cosine Similarity")
    for first_param_value in first_param_values:
        perfect_info_stats: list[TestStats] = first_param_stats[first_param_value]['perfect']
        imperfect_info_stats = first_param_stats[first_param_value]['imperfect']

        avg_follow_rate_sims = []

        for i in range(len(perfect_info_stats)):
            perfect_stat: TestStats = perfect_info_stats[i]
            imperfect_stat: TestStats = imperfect_info_stats[i]

            avg_follow_rate_sim = 0

            for index in perfect_stat.consumer_stats:
                perfect_consumer_stat = perfect_stat.consumer_stats[index]
                imperfect_consumer_stat = imperfect_stat.consumer_stats[index]

                ending_follow_rate_sim = np.dot(perfect_consumer_stat.following_rates[-1], imperfect_consumer_stat.following_rates[-1]) / (np.linalg.norm(perfect_consumer_stat.following_rates[-1]) * np.linalg.norm(imperfect_consumer_stat.following_rates[-1]))
                avg_follow_rate_sim += ending_follow_rate_sim
            
            avg_follow_rate_sim /= len(perfect_stat.consumer_stats)
            avg_follow_rate_sims.append(avg_follow_rate_sim)
        
        plt.plot(second_param_values, avg_follow_rate_sims, label=f'{first_param_legend_label} = {first_param_value}')
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.show()
