# %%
import numpy as np
from test import test
from util import exponential_decay, inverse_decay, tanh_decay
import matplotlib.pyplot as plt
import visualize

# %%
topics = np.array([[-1, 1]])

# %%
varied_param = 'num_agents'
varied_param_legend_label = 'Agents'
varied_param_x_label = 'Number of Consumer/Producer Agents'

# %%
num_influencers = 1
#num_agents = [1, 3, 8, 10, 15, 20, 30, 50, 70, 100]
num_agents = [1, 3, 8, 10]

varied_param_values = num_agents

# %%
perfect_info_stats, imperfect_info_stats = test(
    topics=topics,
    varied_param=varied_param,
    num_influencers=num_influencers,
    num_agents=num_agents,
    producer_topic_interest_func=lambda x: inverse_decay(x, 1, 2),
    consumer_topic_interest_func=lambda x: inverse_decay(x, 1, 2),
    consumer_attention_bound=10,
    consumer_external_interest_prob=3,
    consumer_delay_sensitivity=1,
    influencer_attention_bound=20,
    influencer_delay_sensitivity=1,
    init_following_rates_method='equal',
    init_interest_method='even',
    production_rate=1,
    external_production_rate=1,
    use_imperfect_information=True,
)
# Out:
# Optimizing consumer 0
# Optimizing influencer 1
# Optimizing producer 0
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 0 / 100 done in 0.003931666986318305 seconds.
# Total Social Welfare: 2.7145122541078788
# Optimizing consumer 0
# Optimizing influencer 1
# Optimizing producer 0
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 1 / 100 done in 0.002541458001360297 seconds.
# Total Social Welfare: 2.7145122541078788
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.006736333001754247 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeed using 4 iterations and 10 function evaluations.
# Optimizing producer 1
# Optimization succeed using 4 iterations and 10 function evaluations.
# Optimizing producer 2
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 0 / 100 done in 0.024743791000219062 seconds.
# Total Social Welfare: 14.650107305964795
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeed using 2 iterations and 6 function evaluations.
# Optimizing producer 1
# Optimization succeed using 2 iterations and 6 function evaluations.
# Optimizing producer 2
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 1 / 100 done in 0.018303292003110982 seconds.
# Total Social Welfare: 14.765991291624966
# Consumer rate change: 0.2952724882656143
# Consumer utility change: 0.0010171051599255465%
# Influencer rate change: 0.8062409768953305
# Influencer utility change: 0.017345587513997507%
# Producer topic change: 0.0030669941654183166
# Producer utility change: 0.026715244486509884%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeed using 2 iterations and 6 function evaluations.
# Optimizing producer 1
# Optimization succeed using 2 iterations and 6 function evaluations.
# Optimizing producer 2
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 2 / 100 done in 0.006726166000589728 seconds.
# Total Social Welfare: 14.76599708060673
# Consumer rate change: 0.0
# Consumer utility change: 9.231240375715994e-08%
# Influencer rate change: 0.0
# Influencer utility change: 2.5620063705438686e-06%
# Producer topic change: 0.0005289834482552491
# Producer utility change: 3.207929940584485e-07%
# Converged. Optimization took 0.051703000004636124 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization succeed using 4 iterations and 12 function evaluations.
# Optimizing producer 1
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 2
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 3
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 4
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 5
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 6
# Optimization succeed using 4 iterations and 12 function evaluations.
# Optimizing producer 7
# Optimization succeed using 3 iterations and 10 function evaluations.
# Iteration 0 / 100 done in 0.32145541699719615 seconds.
# Total Social Welfare: 87.86175760446363
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 1
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 2
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 3
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 4
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 5
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 6
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 7
# Optimization succeed using 3 iterations and 10 function evaluations.
# Iteration 1 / 100 done in 0.16221491699980106 seconds.
# Total Social Welfare: 88.15139064744675
# Consumer rate change: 0.16100860903883005
# Consumer utility change: 0.0019381078444349648%
# Influencer rate change: 0.21830511383535314
# Influencer utility change: 0.003757369175051576%
# Producer topic change: 0.043886514833470926
# Producer utility change: 0.005169529135691364%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization succeed using 1 iterations and 6 function evaluations.
# Optimizing producer 1
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 2
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 3
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 4
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 5
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 6
# Optimization succeed using 1 iterations and 6 function evaluations.
# Optimizing producer 7
# Optimization succeed using 2 iterations and 8 function evaluations.
# Iteration 2 / 100 done in 0.1331069169973489 seconds.
# Total Social Welfare: 88.1587815449924
# Consumer rate change: 0.05285619698131025
# Consumer utility change: 6.458846991289027e-05%
# Influencer rate change: 0.006734668647459316
# Influencer utility change: -0.0002070734474750616%
# Producer topic change: 0.004617155265478347
# Producer utility change: 0.0002964021830974739%
# Converged. Optimization took 0.6299560830084374 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeed using 4 iterations and 12 function evaluations.
# Optimizing producer 1
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 2
# Optimization succeed using 4 iterations and 12 function evaluations.
# Optimizing producer 3
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 4
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 5
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 6
# Optimization succeed using 4 iterations and 12 function evaluations.
# Optimizing producer 7
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 8
# Optimization succeed using 4 iterations and 12 function evaluations.
# Optimizing producer 9
# Optimization succeed using 3 iterations and 10 function evaluations.
# Iteration 0 / 100 done in 0.4329472499957774 seconds.
# Total Social Welfare: 123.86789490497873
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 1
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 2
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 3
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 4
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 5
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 6
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 7
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 8
# Optimization succeed using 3 iterations and 10 function evaluations.
# Optimizing producer 9
# Optimization succeed using 3 iterations and 10 function evaluations.
# Iteration 1 / 100 done in 0.29337741700874176 seconds.
# Total Social Welfare: 124.3139735553505
# Consumer rate change: 0.16661675898777173
# Consumer utility change: 0.0026442704053875944%
# Influencer rate change: 0.182126303261502
# Influencer utility change: 0.003044187396798699%
# Producer topic change: 0.050408433651204954
# Producer utility change: 0.005363015403320355%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeed using 1 iterations and 6 function evaluations.
# Optimizing producer 1
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 2
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 3
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 4
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 5
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 6
# Optimization succeed using 1 iterations and 6 function evaluations.
# Optimizing producer 7
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 8
# Optimization succeed using 2 iterations and 8 function evaluations.
# Optimizing producer 9
# Optimization succeed using 2 iterations and 8 function evaluations.
# Iteration 2 / 100 done in 0.25054095800442155 seconds.
# Total Social Welfare: 124.32793843282097
# Consumer rate change: 0.06386989892687442
# Consumer utility change: 8.48857697668399e-05%
# Influencer rate change: 0.006111737774233319
# Influencer utility change: -0.0007660575602328386%
# Producer topic change: 0.003824053425471018
# Producer utility change: 0.0007167461420788907%
# Converged. Optimization took 0.996511624995037 seconds.
# Optimizing consumer 0
# Optimizing influencer 1
# Optimizing producer 0
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 0 / 100 done in 0.0021336669888114557 seconds.
# Total Social Welfare: 3.665741678608593
# Optimizing consumer 0
# Optimizing influencer 1
# Optimizing producer 0
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 1 / 100 done in 0.0012038340064464137 seconds.
# Total Social Welfare: 3.665741678608593
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 0.004044208995765075 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 98 function evaluations.
# Optimizing producer 1
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 58 function evaluations.
# Iteration 0 / 100 done in 1.732918082998367 seconds.
# Total Social Welfare: 14.057382722380702
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 66 function evaluations.
# Optimizing producer 1
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 64 function evaluations.
# Iteration 1 / 100 done in 1.6644881660031388 seconds.
# Total Social Welfare: 14.077854668081635
# Consumer rate change: 0.1827655885141831
# Consumer utility change: 0.0006423111934525257%
# Influencer rate change: 0.7303140358035636
# Influencer utility change: 0.009962020771171939%
# Producer topic change: 0.0011456324226106953
# Producer utility change: 0.0%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing influencer 3
# Optimizing producer 0
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 1
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 2
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 2 / 100 done in 0.007521792009356432 seconds.
# Total Social Welfare: 14.077854668081635
# Consumer rate change: 0.0
# Consumer utility change: 0.0%
# Influencer rate change: 0.0
# Influencer utility change: 0.0%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 3.4196807499974966 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 54 function evaluations.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 84 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 136 function evaluations.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 58 function evaluations.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 86 function evaluations.
# Optimizing producer 5
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 80 function evaluations.
# Optimizing producer 7
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 0 / 100 done in 55.63165433400718 seconds.
# Total Social Welfare: 65.03458854575211
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 60 function evaluations.
# Optimizing producer 1
# Optimization succeed using 4 iterations and 54 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 70 function evaluations.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 4 iterations and 160 function evaluations.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 88 function evaluations.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 156 function evaluations.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 62 function evaluations.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 104 function evaluations.
# Iteration 1 / 100 done in 55.85650229199382 seconds.
# Total Social Welfare: 66.03578336106696
# Consumer rate change: 0.1319475716946772
# Consumer utility change: 0.011784476209049764%
# Influencer rate change: 0.08398030505375412
# Influencer utility change: 0.028316441970382928%
# Producer topic change: 0.08903615307961478
# Producer utility change: 0.001442848241258824%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 3 iterations and 122 function evaluations.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 56 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 3 iterations and 130 function evaluations.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 3 iterations and 226 function evaluations.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 94 function evaluations.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 58 function evaluations.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 170 function evaluations.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 104 function evaluations.
# Iteration 2 / 100 done in 57.08745716699923 seconds.
# Total Social Welfare: 66.11561776176103
# Consumer rate change: 0.07182288541076931
# Consumer utility change: 0.0003006050110774469%
# Influencer rate change: 0.2351025196676696
# Influencer utility change: 0.003942333547461555%
# Producer topic change: 0.0003694939341833386
# Producer utility change: 0.0%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing influencer 8
# Optimizing producer 0
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 1
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 2
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 3
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 4
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 5
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 6
# Optimization succeed using 0 iterations and 2 function evaluations.
# Optimizing producer 7
# Optimization succeed using 0 iterations and 2 function evaluations.
# Iteration 3 / 100 done in 0.1648538340086816 seconds.
# Total Social Welfare: 66.11709653060669
# Consumer rate change: 0.003777978611280497
# Consumer utility change: 5.445961648399756e-07%
# Influencer rate change: 0.0
# Influencer utility change: 8.604572279100445e-05%
# Producer topic change: 0.0
# Producer utility change: 0.0%
# Converged. Optimization took 169.3189813749923 seconds.
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 56 function evaluations.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 88 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 164 function evaluations.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 3 iterations and 114 function evaluations.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 44 function evaluations.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 100 function evaluations.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 108 function evaluations.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 76 function evaluations.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 54 function evaluations.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 78 function evaluations.
# Iteration 0 / 100 done in 150.7153588749934 seconds.
# Total Social Welfare: 89.85595283355008
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 126 function evaluations.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 70 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 76 function evaluations.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 150 function evaluations.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 66 function evaluations.
# Optimizing producer 5
# Optimization succeed using 3 iterations and 50 function evaluations.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 102 function evaluations.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 3 iterations and 116 function evaluations.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 60 function evaluations.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 64 function evaluations.
# Iteration 1 / 100 done in 111.20247379099601 seconds.
# Total Social Welfare: 90.03670140030579
# Consumer rate change: 0.16204151677987583
# Consumer utility change: 0.0005512646254836167%
# Influencer rate change: 0.12450549934284813
# Influencer utility change: 0.005937466681294898%
# Producer topic change: 0.00954447212888129
# Producer utility change: -2.6695541228045868e-05%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 96 function evaluations.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 52 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 66 function evaluations.
# Optimizing producer 3
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 88 function evaluations.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 218 function evaluations.
# Optimizing producer 5
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 84 function evaluations.
# Optimizing producer 6
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 78 function evaluations.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 2 iterations and 146 function evaluations.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 52 function evaluations.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 82 function evaluations.
# Iteration 2 / 100 done in 96.84017862500332 seconds.
# Total Social Welfare: 90.57415829085042
# Consumer rate change: 0.04098874562254943
# Consumer utility change: 0.0051101983592457675%
# Influencer rate change: 0.012500315624426725
# Influencer utility change: 0.009162501965206784%
# Producer topic change: 0.05136374789733611
# Producer utility change: 0.0005522581470735274%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 66 function evaluations.
# Optimizing producer 1
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 56 function evaluations.
# Optimizing producer 2
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 84 function evaluations.
# Optimizing producer 3
# Optimization succeed using 4 iterations and 144 function evaluations.
# Optimizing producer 4
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 94 function evaluations.
# Optimizing producer 5
# Optimization succeed using 1 iterations and 42 function evaluations.
# Optimizing producer 6
# Optimization succeed using 3 iterations and 66 function evaluations.
# Optimizing producer 7
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 84 function evaluations.
# Optimizing producer 8
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 72 function evaluations.
# Optimizing producer 9
# Optimization failed: ABNORMAL_TERMINATION_IN_LNSRCH Retrying...
# Optimization succeed using 1 iterations and 86 function evaluations.
# Iteration 3 / 100 done in 74.237798999995 seconds.
# Total Social Welfare: 90.61831333243722
# Consumer rate change: 0.0900512472556081
# Consumer utility change: 0.0005724758558914103%
# Influencer rate change: 0.09153130898954946
# Influencer utility change: 0.000403881745898196%
# Producer topic change: 0.002264407809760731
# Producer utility change: 0.0%
# Converged. Optimization took 434.74777479200566 seconds.

# %%
import importlib
importlib.reload(visualize)
# Out:
# <module 'visualize' from '/Users/gabeguralnick/git/content-market-experiment/visualize.py'>

# %%
visualize.plot_ending_value_by_test(f"Total Social Welfare By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'total_social_welfare', varied_param_values, varied_param_x_label, 'Total Social Welfare')

# %%
visualize.plot_cost_of_influence_by_test(f"Cost of Influence By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, varied_param_values, varied_param_x_label, 'Cost of Influence')

# %%
visualize.plot_ending_value_by_test(f"Average Agent Utility By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_agent_utility', varied_param_values, varied_param_x_label, 'Average Agent Utility')

# %%
if len(perfect_info_stats) > 0:
    visualize.plot_value_by_iteration_by_test(f"Average Agent Utility By Iteration By {varied_param_x_label} (Perfect)", perfect_info_stats, 'average_agent_utility', varied_param_legend_label, varied_param_values, 'Average Agent Utility')

# %%
if len(imperfect_info_stats) > 0:
    visualize.plot_value_by_iteration_by_test(f"Average Agent Utility By Iteration By {varied_param_x_label} (Imperfect)", imperfect_info_stats, 'average_agent_utility', varied_param_legend_label, varied_param_values, 'Average Agent Utility')

# %%
visualize.plot_ending_value_by_test(f"Average Producer Utility By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_producer_utility', varied_param_values, varied_param_x_label, 'Average Producer Utility')

# %%
visualize.plot_ending_value_by_test(f"Average Consumer Utility By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_consumer_utility', varied_param_values, varied_param_x_label, 'Average Consumer Utility')

# %%
visualize.plot_ending_value_by_test(f"Average Influencer Utility By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_influencer_utility', varied_param_values, varied_param_x_label, 'Average Influencer Utility')

# %%
visualize.plot_ending_value_by_test(f"Average Consumer-Influencer Follow Proportion By {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'average_influencer_follow_proportion', varied_param_values, varied_param_x_label, 'Average Influencer Follow Proportion')

# %%
visualize.plot_value_by_test(f"Optimization time by {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'optimization_time', varied_param_values, varied_param_x_label, 'Optimization Time (s)')

# %%
visualize.plot_value_by_test(f"Number of Iterations by {varied_param_x_label}", perfect_info_stats, imperfect_info_stats, 'num_iterations', varied_param_values, varied_param_x_label, 'Number of Iterations')

# %%
visualize.plot_value_by_iteration_by_test(f"Time per iteration by {varied_param_x_label} (Perfect)", perfect_info_stats, 'optimization_times', varied_param_legend_label, varied_param_values, 'Time (s)')

# %%
visualize.plot_value_by_iteration_by_test(f"Time per iteration by {varied_param_x_label} (Imperfect)", imperfect_info_stats, 'optimization_times', varied_param_legend_label, varied_param_values, 'Time (s)')

# %%
last_test_perfect_info_stats = perfect_info_stats[-1]
last_test_imperfect_info_stats = imperfect_info_stats[-1]

# %%
visualize.plot_producer_topic_distance_from_main_interest_by_iteration(f"Producer Topic Distance from Main Interest by Iteration (Perfect)", last_test_perfect_info_stats.producer_stats, 'Producer', 'Topic Distance from Main Interest')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/gabeguralnick/git/content-market-experiment/notebooks/impact of num agents.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/Users/gabeguralnick/git/content-market-experiment/notebooks/impact%20of%20num%20agents.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> visualize.plot_producer_topic_distance_from_main_interest_by_iteration(f"Producer Topic Distance from Main Interest by Iteration (Perfect)", last_test_perfect_info_stats, 'Producer', 'Topic Distance from Main Interest')
#
# File ~/git/content-market-experiment/visualize.py:257, in plot_producer_topic_distance_from_main_interest_by_iteration(title, producers, agent_colors, agent_stats)
#     256 def plot_producer_topic_distance_from_main_interest_by_iteration(title, producers: list[Producer], agent_colors, agent_stats: dict[int, ProducerStats]):
# --> 257     if len(producers) == 0:
#     258         return
#     259     plt.figure()
#
# TypeError: object of type 'TestStats' has no len()
