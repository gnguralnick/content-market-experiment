# %%
from agents import ConsumerProducer, Influencer, ImperfectConsumerProducer
from content_market import ContentMarket
import numpy as np
from stats import TestStats

# %%
num_influencers = 1
num_consumer_producers = 10

production_rate = 1
external_production_rate = 1

topics = [[-1, 1]]
topics = np.array(topics)

# %%
content_market = ContentMarket(topics, production_rate, external_production_rate)

# %%
from util import exponential_decay, inverse_decay, tanh_decay

# %%
agent_colors = dict()

for i in range(num_consumer_producers):
    cons_func = lambda x: inverse_decay(x, 0.00001, 2)
    prod_func = lambda x: inverse_decay(x, 1, 2)
    consumer_producer = ConsumerProducer(prod_func, cons_func, 10, 3, 1, init_following_rates_method='equal')
    #consumer_producer = ImperfectConsumerProducer(prod_func, cons_func, 10, 3, 1, init_following_rates_method='equal')
    content_market.add_agent(consumer_producer)

    color = np.random.rand(3,)
    agent_colors[consumer_producer.index] = color

for i in range(num_influencers):
    influencer = Influencer(20, 1, init_following_rates_method='equal')
    content_market.add_agent(influencer)

    color = np.random.rand(3,)
    agent_colors[influencer.index] = color

# %%
import matplotlib.pyplot as plt
import visualize

# %%
content_market.finalize(method='even')

# %%
visualize.plot_topic_distribution_histogram("Consumer/Producer Topic Distribution", content_market.consumers, -1, 1)

# %%
visualize.plot_consumer_topic_interest_distributions("Consumer Topic Interest Distributions", content_market.consumers, -1, 1, agent_colors)

# %%
visualize.plot_producer_topic_probability_distributions("Producer Topic Probability Distributions", content_market.producers, -1, 1, agent_colors)

# %%
stats: TestStats = content_market.optimize(100)
# Out:
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.006663709005806595s): nit=4, nfev=12, njev=6.
# Optimizing producer 1
# Optimization succeeded (overall 0.0039712919970043s): nit=4, nfev=12, njev=6.
# Optimizing producer 2
# Optimization succeeded (overall 0.0026997920067515224s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.003279042022768408s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.004156749986577779s): nit=4, nfev=12, njev=6.
# Optimizing producer 5
# Optimization succeeded (overall 0.0037710409960709512s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.0030856250086799264s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0030368750158231705s): nit=3, nfev=10, njev=5.
# Optimizing producer 8
# Optimization succeeded (overall 0.002423792000627145s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.004363915999419987s): nit=4, nfev=12, njev=6.
# Iteration 0 / 100 done in 0.5614161250123288 seconds.
# Total Social Welfare: 123.86789366820116
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0029390839918050915s): nit=3, nfev=10, njev=5.
# Optimizing producer 1
# Optimization succeeded (overall 0.0028176670020911843s): nit=3, nfev=10, njev=5.
# Optimizing producer 2
# Optimization succeeded (overall 0.002878416999010369s): nit=3, nfev=10, njev=5.
# Optimizing producer 3
# Optimization succeeded (overall 0.0027545830234885216s): nit=3, nfev=10, njev=5.
# Optimizing producer 4
# Optimization succeeded (overall 0.003471166011877358s): nit=3, nfev=10, njev=5.
# Optimizing producer 5
# Optimization succeeded (overall 0.0028777499974239618s): nit=3, nfev=10, njev=5.
# Optimizing producer 6
# Optimization succeeded (overall 0.0029550420003943145s): nit=3, nfev=10, njev=5.
# Optimizing producer 7
# Optimization succeeded (overall 0.0029003329982515424s): nit=3, nfev=10, njev=5.
# Optimizing producer 8
# Optimization succeeded (overall 0.002879833016777411s): nit=3, nfev=10, njev=5.
# Optimizing producer 9
# Optimization succeeded (overall 0.003871583001455292s): nit=3, nfev=10, njev=5.
# Iteration 1 / 100 done in 0.3101471250120085 seconds.
# Total Social Welfare: 124.31397351666206
# Consumer rate change: 0.16661684647775496
# Consumer utility change: 0.0026442741773035185%
# Influencer rate change: 0.18212641805702773
# Influencer utility change: 0.0030442179588002515%
# Producer topic change: 0.050408438667248534
# Producer utility change: 0.005363020460820281%
# Optimizing consumer 0
# Optimizing consumer 1
# Optimizing consumer 2
# Optimizing consumer 3
# Optimizing consumer 4
# Optimizing consumer 5
# Optimizing consumer 6
# Optimizing consumer 7
# Optimizing consumer 8
# Optimizing consumer 9
# Optimizing influencer 10
# Optimizing producer 0
# Optimization succeeded (overall 0.0017459579976275563s): nit=1, nfev=6, njev=3.
# Optimizing producer 1
# Optimization succeeded (overall 0.0016916249878704548s): nit=1, nfev=6, njev=3.
# Optimizing producer 2
# Optimization succeeded (overall 0.002656625001691282s): nit=2, nfev=8, njev=4.
# Optimizing producer 3
# Optimization succeeded (overall 0.0024139579909387976s): nit=2, nfev=8, njev=4.
# Optimizing producer 4
# Optimization succeeded (overall 0.0022744580055586994s): nit=2, nfev=8, njev=4.
# Optimizing producer 5
# Optimization succeeded (overall 0.0035651660000439733s): nit=2, nfev=8, njev=4.
# Optimizing producer 6
# Optimization succeeded (overall 0.002566375012975186s): nit=2, nfev=8, njev=4.
# Optimizing producer 7
# Optimization succeeded (overall 0.002624334010761231s): nit=2, nfev=8, njev=4.
# Optimizing producer 8
# Optimization succeeded (overall 0.002685124985873699s): nit=2, nfev=8, njev=4.
# Optimizing producer 9
# Optimization succeeded (overall 0.002277166990097612s): nit=2, nfev=8, njev=4.
# Iteration 2 / 100 done in 0.2533409999741707 seconds.
# Total Social Welfare: 124.32793853938759
# Consumer rate change: 0.06386998030611285
# Consumer utility change: 8.488545269800193e-05%
# Influencer rate change: 0.00611052367673504
# Influencer utility change: -0.0007660472846751779%
# Producer topic change: 0.0038240548817975394
# Producer utility change: 0.0007167437149172556%
# Converged. Optimization took 1.1476294169842731 seconds.

# %%
visualize.plot_agent_utility_by_iteration("Consumer Utility by Iteration", content_market.consumers, agent_colors, stats.consumer_stats, stats.average_consumer_utility)

# %%
visualize.plot_agent_utility_change_by_iteration("Consumer Utility Change by Iteration", content_market.consumers, agent_colors, stats.consumer_stats, stats.average_consumer_utility_change)

# %%
visualize.plot_agent_utility_by_iteration("Producer Utility by Iteration", content_market.producers, agent_colors, stats.producer_stats, stats.average_producer_utility)

# %%
visualize.plot_agent_utility_change_by_iteration("Producer Utility Change by Iteration", content_market.producers, agent_colors, stats.producer_stats, stats.average_producer_utility_change)

# %%
visualize.plot_agent_utility_by_iteration("Influencer Utility by Iteration", content_market.influencers, agent_colors, stats.influencer_stats, stats.average_influencer_utility)

# %%
visualize.plot_following_rate_change_by_iteration("Consumer Average following rate change by Iteration", content_market.consumers, agent_colors, stats.consumer_stats, stats.average_consumer_rate_change)

# %%
visualize.plot_following_rate_change_by_iteration("Influencer Average following rate change by Iteration", content_market.influencers, agent_colors, stats.influencer_stats, stats.average_influencer_rate_change)

# %%
visualize.plot_following_rates_by_iteration(content_market.influencers, content_market.producers, agent_colors, stats.influencer_stats)

# %%
visualize.plot_follows_by_iteration(content_market.influencers, content_market.consumers, agent_colors, stats.consumer_stats)

# %%
visualize.plot_producer_topic_produced_by_iteration("Producer Topic Produced by Iteration", content_market.producers, content_market.consumers, agent_colors, stats.producer_stats)

# %%
visualize.plot_producer_topic_change_by_iteration("Producer Average topic change by Iteration", content_market.producers, agent_colors, stats.producer_stats, stats.average_producer_topic_change)

# %%
visualize.plot_total_social_welfare_by_iteration("Total Social Welfare by Iteration", stats)

# %%
visualize.plot_following_rate_by_main_interest_closeness("Following rate by Main Interest Closeness", content_market.consumers, content_market.producers, agent_colors, stats.consumer_stats)

# %%
visualize.plot_producer_topic_distance_from_main_interest_by_iteration("Producer topic distance from main interest by Iteration", content_market.producers, agent_colors, stats.producer_stats, stats.average_producer_topic_distance_from_main_interest)

# %%
visualize.plot_following_rates_by_iteration(content_market.consumers, sorted(list(set(content_market.producers + content_market.influencers)), key=lambda x: x.index), agent_colors, stats.consumer_stats)

# %%
stats.to_dict()
# Out:
# {'num_iterations': 3,
#  'total_consumer_utility': [0,
#   59.39519655617347,
#   59.55267017053763,
#   59.557725755898936],
#  'total_producer_utility': [0,
#   39.23066319811497,
#   39.44219253734254,
#   39.47048276495652],
#  'total_influencer_utility': [0,
#   25.242033913912728,
#   25.319110808781893,
#   25.299730018532134],
#  'total_social_welfare': [0,
#   123.86789366820116,
#   124.31397351666206,
#   124.32793853938759],
#  'average_consumer_rate_change': [0,
#   3.0604391515615714,
#   0.16661684647775496,
#   0.06386998030611285],
#  'average_producer_topic_change': [0,
#   0.16467722040936042,
#   0.050408438667248534,
#   0.0038240548817975394],
#  'average_influencer_rate_change': [0,
#   0.533756888473685,
#   0.18212641805702773,
#   0.00611052367673504],
#  'average_consumer_utility_change': [0,
#   5.939519655617347,
#   0.015747361436416796,
#   0.0005055585361307457],
#  'average_producer_utility_change': [0,
#   3.923066319811496,
#   0.021152933922758566,
#   0.00282902276139696],
#  'average_influencer_utility_change': [0,
#   25.242033913912728,
#   0.07707689486916536,
#   -0.019380790249758917],
#  'consumer_stats': {0: {'utilities': [0,
#     5.063182153333273,
#     5.168807812544401,
#     5.160883700534939],
#    'utility_change': [0,
#     5.063182153333273,
#     0.10562565921112821,
#     -0.007924112009462192],
#    'optimization_times': [0.07407150001381524,
#     0.023116916010621935,
#     0.021157250012038276],
#    'following_rates': [array([0.        , 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([0.        , 0.        , 0.        , 1.1978086 , 1.33624806,
#            1.00851188, 0.        , 0.        , 0.78918126, 0.        ,
#            2.76782579, 2.90042442]),
#     array([0.00000000e+00, 1.83656864e-16, 1.68103611e-16, 1.11471647e+00,
#            1.20992139e+00, 9.85612234e-01, 2.25792444e-17, 4.81872630e-17,
#            8.32247924e-01, 0.00000000e+00, 2.83068417e+00, 3.02681781e+00]),
#     array([0.00000000e+00, 0.00000000e+00, 1.76765386e-17, 1.15110621e+00,
#            1.24870528e+00, 1.00867800e+00, 8.68470818e-17, 2.96512280e-17,
#            8.21346945e-01, 0.00000000e+00, 2.80356643e+00, 2.96659713e+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000001439,
#     10.000000000000002,
#     10.0],
#    'rate_change': [0,
#     3.441310782390219,
#     0.21252840432966902,
#     0.08855034698255017]},
#   1: {'utilities': [0,
#     5.063182301309454,
#     5.1688077908041805,
#     5.160883780281129],
#    'utility_change': [0,
#     5.063182301309454,
#     0.10562548949472639,
#     -0.007924010523051805],
#    'optimization_times': [0.04940970899770036,
#     0.0260571249818895,
#     0.021303499990608543],
#    'following_rates': [array([0.90909091, 0.        , 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([0.        , 0.        , 0.7891804 , 0.        , 0.        ,
#            0.        , 1.00851123, 1.19780793, 0.        , 1.3362472 ,
#            2.76782738, 2.90042586]),
#     array([3.32739029e-16, 0.00000000e+00, 8.32247709e-01, 1.63886180e-16,
#            2.24554834e-16, 1.12488774e-16, 9.85612299e-01, 1.11471649e+00,
#            1.64353560e-16, 1.20992168e+00, 2.83068410e+00, 3.02681773e+00]),
#     array([4.54839826e-17, 0.00000000e+00, 8.21347031e-01, 0.00000000e+00,
#            1.83083516e-16, 5.58157992e-17, 1.00867792e+00, 1.15110632e+00,
#            0.00000000e+00, 1.24870512e+00, 2.80356639e+00, 2.96659722e+00])],
#    'attention_used': [9.999999999999998, 10.00000000000092, 10.0, 10.0],
#    'rate_change': [0,
#     3.44131232400371,
#     0.21252611938158558,
#     0.08855000039256344]},
#   2: {'utilities': [0, 6.55409100927804, 6.466116975859338, 6.474680869146371],
#    'utility_change': [0,
#     6.55409100927804,
#     -0.08797403341870247,
#     0.00856389328703333],
#    'optimization_times': [0.03951183400931768,
#     0.021189499995671213,
#     0.01425658300286159],
#    'following_rates': [array([0.90909091, 0.90909091, 0.        , 0.90909091, 0.90909091,
#            0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([0.        , 0.        , 0.        , 0.62257919, 0.        ,
#            0.84438013, 0.97843776, 0.84438013, 0.97843776, 0.62257919,
#            2.77611491, 2.33309093]),
#     array([0.00000000e+00, 2.41762938e-16, 0.00000000e+00, 6.84179525e-01,
#            0.00000000e+00, 8.29462823e-01, 9.32922748e-01, 8.52438332e-01,
#            9.21039465e-01, 7.20365890e-01, 2.82284678e+00, 2.23674443e+00]),
#     array([0.        , 0.        , 0.        , 0.66001161, 0.        ,
#            0.81974316, 0.9417838 , 0.8506155 , 0.93104576, 0.71328638,
#            2.8207156 , 2.26279819])],
#    'attention_used': [9.999999999999998,
#     10.000000000000178,
#     9.999999999999998,
#     10.0],
#    'rate_change': [0,
#     2.8592069526621975,
#     0.1745766225846027,
#     0.03992476391859215]},
#   3: {'utilities': [0, 6.11070778247932, 6.136125795628792, 6.136386980702209],
#    'utility_change': [0,
#     6.11070778247932,
#     0.025418013149471896,
#     0.00026118507341710284],
#    'optimization_times': [0.0390051249996759,
#     0.017606375011382625,
#     0.014672124991193414],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.        , 0.90909091,
#            0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([9.37220872e-01, 3.86923231e-13, 7.41836687e-01, 0.00000000e+00,
#            1.06995692e+00, 1.06995702e+00, 3.26499951e-12, 6.27542852e-13,
#            9.37220872e-01, 4.52728703e-13, 2.76808307e+00, 2.47572456e+00]),
#     array([9.96049697e-01, 0.00000000e+00, 7.59739267e-01, 0.00000000e+00,
#            1.05573700e+00, 1.00617225e+00, 2.32198507e-16, 4.69284378e-17,
#            9.03836752e-01, 1.03002236e-16, 2.81852121e+00, 2.45994382e+00]),
#     array([9.99606817e-01, 1.37936429e-16, 7.27572790e-01, 0.00000000e+00,
#            1.06926683e+00, 1.03364914e+00, 0.00000000e+00, 0.00000000e+00,
#            9.13918122e-01, 1.46189802e-16, 2.80714021e+00, 2.44884610e+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000000377,
#     10.000000000000004,
#     10.0],
#    'rate_change': [0,
#     3.0491458323722385,
#     0.10935983476618155,
#     0.048370359159136594]},
#   4: {'utilities': [0,
#     5.586979377487156,
#     5.662953143970079,
#     5.659552953901793],
#    'utility_change': [0,
#     5.586979377487156,
#     0.07597376648292364,
#     -0.0034001900682865127],
#    'optimization_times': [0.04224304098170251,
#     0.02068420799332671,
#     0.023034166981233284],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.        ,
#            0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([1.14953336e+00, 1.61003728e-14, 5.33720021e-01, 1.14953336e+00,
#            0.00000000e+00, 1.01725464e+00, 4.18235972e-14, 2.81036228e-14,
#            8.28593455e-01, 1.78818911e-14, 2.72128008e+00, 2.60008510e+00]),
#     array([1.11786866e+00, 1.95738723e-16, 6.34238852e-01, 1.06420273e+00,
#            0.00000000e+00, 9.62047269e-01, 0.00000000e+00, 1.15141988e-16,
#            8.22116364e-01, 0.00000000e+00, 2.75895686e+00, 2.64056926e+00]),
#     array([1.13769997e+00, 2.09853963e-16, 5.71025907e-01, 1.10248558e+00,
#            0.00000000e+00, 9.95491249e-01, 0.00000000e+00, 9.24864129e-18,
#            8.30465592e-01, 4.02453871e-17, 2.74998241e+00, 2.61284929e+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000000014,
#     9.999999999999998,
#     9.999999999999998],
#    'rate_change': [0,
#     3.1183302798404546,
#     0.15664072658871248,
#     0.08883625636454132]},
#   5: {'utilities': [0,
#     6.382637861099097,
#     6.342331319771837,
#     6.3473582986693025],
#    'utility_change': [0,
#     6.382637861099097,
#     -0.04030654132725964,
#     0.005026978897465284],
#    'optimization_times': [0.04688983300002292,
#     0.021149167005205527,
#     0.019778207992203534],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.        , 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([6.30309594e-01, 1.45740110e-13, 8.49138206e-01, 9.82991560e-01,
#            8.49138206e-01, 0.00000000e+00, 6.30309594e-01, 7.68457902e-13,
#            9.82991753e-01, 1.78487652e-13, 2.73247242e+00, 2.34264867e+00]),
#     array([0.75773004, 0.        , 0.81386865, 0.94813852, 0.87856509,
#            0.        , 0.65620744, 0.        , 0.9145577 , 0.        ,
#            2.76739601, 2.26353655]),
#     array([7.61868579e-01, 2.25745313e-16, 8.07140358e-01, 9.61274078e-01,
#            8.83915671e-01, 0.00000000e+00, 6.11530238e-01, 5.25766135e-17,
#            9.35360347e-01, 0.00000000e+00, 2.76254905e+00, 2.27636168e+00])],
#    'attention_used': [9.999999999999998,
#     10.0000000000001,
#     9.999999999999996,
#     10.000000000000002],
#    'rate_change': [0,
#     2.8342011497264172,
#     0.17998024795281994,
#     0.053668876921553664]},
#   6: {'utilities': [0,
#     6.3826379068031915,
#     6.342331298932667,
#     6.347358295150389],
#    'utility_change': [0,
#     6.3826379068031915,
#     -0.04030660787052476,
#     0.0050269962177225125],
#    'optimization_times': [0.03732533298898488,
#     0.020714374986710027,
#     0.017827000003308058],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.        , 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([1.29289981e-13, 6.30309647e-01, 9.82992022e-01, 6.47413164e-13,
#            1.46484417e-13, 6.30309647e-01, 0.00000000e+00, 9.82992022e-01,
#            8.49138029e-01, 8.49138058e-01, 2.73247207e+00, 2.34264850e+00]),
#     array([0.        , 0.75772997, 0.91455776, 0.        , 0.        ,
#            0.65620729, 0.        , 0.94813856, 0.8138686 , 0.8785651 ,
#            2.76739596, 2.26353676]),
#     array([0.00000000e+00, 7.61868414e-01, 9.35360881e-01, 0.00000000e+00,
#            1.12875893e-16, 6.11531043e-01, 0.00000000e+00, 9.61274392e-01,
#            8.07139760e-01, 8.83915547e-01, 2.76254867e+00, 2.27636129e+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000000085,
#     9.999999999999998,
#     10.0],
#    'rate_change': [0,
#     2.834200859782902,
#     0.17998018404237792,
#     0.05366827428097194]},
#   7: {'utilities': [0, 6.110707791600335, 6.13612577165005, 6.136386987410746],
#    'utility_change': [0,
#     6.110707791600335,
#     0.025417980049715183,
#     0.00026121576069559893],
#    'optimization_times': [0.03764429100556299,
#     0.02047762498841621,
#     0.01053683299687691],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091, 0.        , 0.90909091, 0.90909091,
#            0.90909091, 0.90909091]),
#     array([5.44445382e-14, 9.37220839e-01, 9.37220839e-01, 7.54480296e-14,
#            5.74731561e-14, 4.04496203e-13, 1.06995703e+00, 0.00000000e+00,
#            7.41836696e-01, 1.06995703e+00, 2.76808299e+00, 2.47572457e+00]),
#     array([2.00585471e-16, 9.96050104e-01, 9.03836589e-01, 2.71449495e-17,
#            0.00000000e+00, 5.56546975e-18, 1.00617259e+00, 0.00000000e+00,
#            7.59739506e-01, 1.05573679e+00, 2.81852026e+00, 2.45994416e+00]),
#     array([0.00000000e+00, 9.99606548e-01, 9.13918270e-01, 1.69501910e-17,
#            0.00000000e+00, 5.15103720e-17, 1.03364922e+00, 0.00000000e+00,
#            7.27572675e-01, 1.06926694e+00, 2.80714000e+00, 2.44884635e+00])],
#    'attention_used': [9.999999999999998, 10.000000000000055, 10.0, 10.0],
#    'rate_change': [0,
#     3.049145796784478,
#     0.10935954829971958,
#     0.04837039547335811]},
#   8: {'utilities': [0,
#     6.554090921359607,
#     6.466116996110899,
#     6.474680967815761],
#    'utility_change': [0,
#     6.554090921359607,
#     -0.08797392524870773,
#     0.008563971704862006],
#    'optimization_times': [0.04320416701375507,
#     0.022594209003727883,
#     0.014004166994709522],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091, 0.90909091, 0.        , 0.90909091,
#            0.90909091, 0.90909091]),
#     array([1.15660840e-13, 6.68681421e-14, 9.78437722e-01, 8.44380179e-01,
#            6.22578980e-01, 9.78437745e-01, 8.44380179e-01, 6.22578827e-01,
#            0.00000000e+00, 1.09296498e-13, 2.77611532e+00, 2.33309105e+00]),
#     array([4.48798752e-16, 0.00000000e+00, 9.21039277e-01, 8.52438434e-01,
#            7.20365895e-01, 9.32922640e-01, 8.29462891e-01, 6.84179422e-01,
#            0.00000000e+00, 2.08423255e-16, 2.82284650e+00, 2.23674494e+00]),
#     array([0.00000000e+00, 2.96244803e-16, 9.31045704e-01, 8.50615436e-01,
#            7.13286378e-01, 9.41783922e-01, 8.19743144e-01, 6.60011604e-01,
#            0.00000000e+00, 0.00000000e+00, 2.82071553e+00, 2.26279828e+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000000036,
#     10.000000000000004,
#     9.999999999999998],
#    'rate_change': [0,
#     2.8592073315535598,
#     0.17457650907938876,
#     0.03992453190959991]},
#   9: {'utilities': [0, 5.586979451423991, 5.662953265265388, 5.6595529222863],
#    'utility_change': [0,
#     5.586979451423991,
#     0.07597381384139723,
#     -0.003400342979087867],
#    'optimization_times': [0.030755917017813772,
#     0.019442541000898927,
#     0.019870165997417644],
#    'following_rates': [array([0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.90909091,
#            0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.        ,
#            0.90909091, 0.90909091]),
#     array([0.        , 1.14953352, 0.82859318, 0.        , 0.        ,
#            0.        , 1.01725468, 1.14953345, 0.53372014, 0.        ,
#            2.72127989, 2.60008514]),
#     array([0.00000000e+00, 1.11786856e+00, 8.22116402e-01, 0.00000000e+00,
#            4.11657826e-17, 8.92867022e-17, 9.62047475e-01, 1.06420319e+00,
#            6.34238694e-01, 0.00000000e+00, 2.75895653e+00, 2.64056915e+00]),
#     array([0.00000000e+00, 1.13769993e+00, 8.30465484e-01, 2.23584934e-17,
#            0.00000000e+00, 2.85360926e-17, 9.95491388e-01, 1.10248582e+00,
#            5.71025944e-01, 0.00000000e+00, 2.74998234e+00, 2.61284910e+00])],
#    'attention_used': [9.999999999999998,
#     10.000000000000059,
#     10.0,
#     10.000000000000002],
#    'rate_change': [0,
#     3.118330206499537,
#     0.15664026775249218,
#     0.08883599765826118]}},
#  'producer_stats': {0: {'utilities': [0,
#     2.864286179981463,
#     3.009696022717603,
#     3.016109601970476],
#    'utility_change': [0,
#     2.864286179981463,
#     0.14540984273613988,
#     0.006413579252873003],
#    'optimization_times': [0.006663709005806595,
#     0.0029390839918050915,
#     0.0017459579976275563],
#    'topics': [array([1.]),
#     array([0.68427984]),
#     array([0.73512163]),
#     array([0.7324175])],
#    'topic_change': [0,
#     0.31572016055318686,
#     0.05084178609289913,
#     0.00270412108905993],
#    'topic_distance': [0.0,
#     0.31572016055318686,
#     0.2648783744602877,
#     0.26758249554934765]},
#   1: {'utilities': [0,
#     2.8642862739906567,
#     3.0096963051686836,
#     3.016109187979819],
#    'utility_change': [0,
#     2.8642862739906567,
#     0.14541003117802687,
#     0.00641288281113539],
#    'optimization_times': [0.0039712919970043,
#     0.0028176670020911843,
#     0.0016916249878704548],
#    'topics': [array([-1.]),
#     array([-0.68427984]),
#     array([-0.73512164]),
#     array([-0.73241751])],
#    'topic_change': [0,
#     0.3157201566504738,
#     0.05084179382875187,
#     0.0027041297025702793],
#    'topic_distance': [0.0,
#     0.3157201566504738,
#     0.26487836282172195,
#     0.2675824925242922]},
#   2: {'utilities': [0, 4.7290075126904, 4.684830876480961, 4.6664689405219555],
#    'utility_change': [0,
#     4.7290075126904,
#     -0.044176636209438236,
#     -0.018361935959005926],
#    'optimization_times': [0.0026997920067515224,
#     0.002878416999010369,
#     0.002656625001691282],
#    'topics': [array([-0.11111111]),
#     array([-0.08159737]),
#     array([-0.1043603]),
#     array([-0.10199558])],
#    'topic_change': [0,
#     0.029513736682085512,
#     0.02276292525031824,
#     0.0023647226002629362],
#    'topic_distance': [0.0,
#     0.029513736682085512,
#     0.00675081143176727,
#     0.009115534032030206]},
#   3: {'utilities': [0,
#     4.0558886732738095,
#     4.047132861424977,
#     4.058788062606555],
#    'utility_change': [0,
#     4.0558886732738095,
#     -0.008755811848832451,
#     0.011655201181578256],
#    'optimization_times': [0.003279042022768408,
#     0.0027545830234885216,
#     0.0024139579909387976],
#    'topics': [array([0.55555556]),
#     array([0.39890854]),
#     array([0.4613624]),
#     array([0.45591714])],
#    'topic_change': [0,
#     0.15664701853425606,
#     0.06245386733916408,
#     0.0054452661161844],
#    'topic_distance': [0.0,
#     0.15664701853425606,
#     0.09419315119509197,
#     0.09963841731127637]},
#   4: {'utilities': [0,
#     3.5308841711032333,
#     3.597767799754593,
#     3.6071586032143603],
#    'utility_change': [0,
#     3.5308841711032333,
#     0.06688362865135966,
#     0.009390803459767394],
#    'optimization_times': [0.004156749986577779,
#     0.003471166011877358,
#     0.0022744580055586994],
#    'topics': [array([0.77777778]),
#     array([0.54667556]),
#     array([0.61054699]),
#     array([0.60465683])],
#    'topic_change': [0,
#     0.23110222168330152,
#     0.06387143233517467,
#     0.005890159109198434],
#    'topic_distance': [0.0,
#     0.23110222168330152,
#     0.16723078934812685,
#     0.17312094845732529]},
#   5: {'utilities': [0, 4.435264518800632, 4.38166833690377, 4.386716714039009],
#    'utility_change': [0,
#     4.435264518800632,
#     -0.05359618189686177,
#     0.0050483771352389795],
#    'optimization_times': [0.0037710409960709512,
#     0.0028777499974239618,
#     0.0035651660000439733],
#    'topics': [array([0.33333333]),
#     array([0.24293036]),
#     array([0.29504255]),
#     array([0.29232652])],
#    'topic_change': [0,
#     0.09040297705092193,
#     0.052112195853058985,
#     0.0027160286151032276],
#    'topic_distance': [0.0,
#     0.09040297705092193,
#     0.038290781197862944,
#     0.04100680981296617]},
#   6: {'utilities': [0,
#     4.43526449828385,
#     4.3816689011188075,
#     4.386716543345601],
#    'utility_change': [0,
#     4.43526449828385,
#     -0.053595597165042363,
#     0.005047642226793769],
#    'optimization_times': [0.0030856250086799264,
#     0.0029550420003943145,
#     0.002566375012975186],
#    'topics': [array([-0.33333333]),
#     array([-0.24293038]),
#     array([-0.29504254]),
#     array([-0.29232652])],
#    'topic_change': [0,
#     0.09040295310924434,
#     0.05211216243137573,
#     0.002716025559381885],
#    'topic_distance': [0.0,
#     0.09040295310924434,
#     0.038290790677868614,
#     0.0410068162372505]},
#   7: {'utilities': [0,
#     4.0558891256161225,
#     4.047133231562713,
#     4.058788417829157],
#    'utility_change': [0,
#     4.0558891256161225,
#     -0.008755894053409818,
#     0.01165518626644424],
#    'optimization_times': [0.0030368750158231705,
#     0.0029003329982515424,
#     0.002624334010761231],
#    'topics': [array([-0.55555556]),
#     array([-0.39890854]),
#     array([-0.46136242]),
#     array([-0.45591714])],
#    'topic_change': [0,
#     0.15664701263860376,
#     0.062453879933506096,
#     0.005445280669410024],
#    'topic_distance': [0.0,
#     0.15664701263860376,
#     0.09419313270509766,
#     0.09963841337450768]},
#   8: {'utilities': [0,
#     4.729008018281462,
#     4.684830888534972,
#     4.666467814958819],
#    'utility_change': [0,
#     4.729008018281462,
#     -0.04417712974649035,
#     -0.018363073576153077],
#    'optimization_times': [0.002423792000627145,
#     0.002879833016777411,
#     0.002685124985873699],
#    'topics': [array([0.11111111]),
#     array([0.08159736]),
#     array([0.1043603]),
#     array([0.10199559])],
#    'topic_change': [0,
#     0.029513752750805478,
#     0.02276293669955709,
#     0.0023647013641798775],
#    'topic_distance': [0.0,
#     0.029513752750805478,
#     0.006750816051248387,
#     0.009115517415428265]},
#   9: {'utilities': [0,
#     3.5308842260933355,
#     3.5977673136754698,
#     3.6071588784907673],
#    'utility_change': [0,
#     3.5308842260933355,
#     0.06688308758213424,
#     0.00939156481529757],
#    'optimization_times': [0.004363915999419987,
#     0.003871583001455292,
#     0.002277166990097612],
#    'topics': [array([-0.77777778]),
#     array([-0.54667556]),
#     array([-0.61054697]),
#     array([-0.60465686])],
#    'topic_change': [0,
#     0.23110221444072498,
#     0.06387140690867943,
#     0.005890113992624402],
#    'topic_distance': [0.0,
#     0.23110221444072498,
#     0.16723080753204556,
#     0.17312092152466996]}},
#  'influencer_stats': {10: {'utilities': [0,
#     25.242033913912728,
#     25.319110808781893,
#     25.299730018532134],
#    'utility_change': [0,
#     25.242033913912728,
#     0.07707689486916536,
#     -0.019380790249758917],
#    'optimization_times': [0.08372279099421576,
#     0.06663295900216326,
#     0.05226116700214334],
#    'following_rates': [array([2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 0., 0.]),
#     array([1.72011287, 1.72011298, 2.18387846, 2.04847499, 1.90796375,
#            2.139569  , 2.13956911, 2.04847586, 2.18387903, 1.90796396,
#            0.        , 0.        ]),
#     array([1.81664525, 1.81664563, 2.12246695, 2.02964144, 1.93860046,
#            2.09264577, 2.09264621, 2.02964188, 2.12246668, 1.93859972,
#            0.        , 0.        ]),
#     array([1.81624069, 1.81624031, 2.1259641 , 2.0278482 , 1.93689731,
#            2.09304995, 2.09305015, 2.0278484 , 2.12596304, 1.93689784,
#            0.        , 0.        ])],
#    'attention_used': [20.0, 20.0, 20.00000000000001, 19.999999999999996],
#    'rate_change': [0,
#     0.533756888473685,
#     0.18212641805702773,
#     0.00611052367673504]}},
#  'optimization_time': 1.1476294169842731,
#  'optimization_times': [0.5614161250123288,
#   0.3101471250120085,
#   0.2533409999741707]}
